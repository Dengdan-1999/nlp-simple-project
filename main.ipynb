# %%
import paddle
import numpy as np
import paddlenlp
import pandas as pd
import re
from functools import partial
from paddlenlp.transformers import LinearDecayWithWarmup

from paddlenlp.data import Stack,Tuple,Pad
import warnings
warnings.filterwarnings('ignore')

import warnings
warnings.filterwarnings('ignore')
import paddle.nn.functional as F
# from utils import evaluate
from paddlenlp.datasets import MapDataset

# Train_path = '/home/dengdan/data/test_data.csv'             # 远程服务器上面的绝对路径
# Test_path='/home/dengdan/data/test_data.csv'

Train_path = './data/data103654/train.txt'             # 远程服务器上面的绝对路径
Test_path='./data/data103654/test.txt'
Valid_path='./data/data103654/dev.txt'

Label_list=['教育', '社会', '星座', '房产', '彩票', '体育', '游戏', '财经', '股票', '时政', '科技', '娱乐', '时尚', '家居']
id2label_list=[{0: '教育'}, {1: '社会'}, {2: '星座'}, {3: '房产'}, {4: '彩票'}, {5: '体育'}, {6: '游戏'},
               {7: '财经'}, {8: '股票'}, {9: '时政'}, {10: '科技'}, {11: '娱乐'}, {12: '时尚'}, {13: '家居'}]


class MyDataSet(paddle.io.Dataset):
    def __init__(self,path):
        self.data_dict_list=self.__load_data(path)


    def __load_data(self,path):
        with open(path,'r',encoding='utf-8') as f:
            data=f.readlines()
            data_dict_list=[]
            # label_dict_list=[]
            for line in data:
                message=line.strip('\n')
                label=message[-2:]
                for i in range(len(Label_list)):
                    if Label_list[i]==label:
                        label=i
                text=message[:-3]
                temp={'text':text,'label':label}
                data_dict_list.append(temp)
        return data_dict_list

    def __getitem__(self, idx):
        return self.data_dict_list[idx]

    def __len__(self):
        return len(self.data_dict_list)

# %%
batch_size = 32
max_seq_len = 64
lr = 5e-5
epochs = 1
MODEL_NAME = 'ernie-tiny'

# tokenizer作用为将原始输入文本转化成模型model可以接受的输入数据形式。
tokenizer = paddlenlp.transformers.ErnieTokenizer.from_pretrained(MODEL_NAME)


# 该函数作用为将数据转换为ernie所需要的输入数据格式
def convert_example(example, tokenizer, max_seq_length=128, is_test=False):
    encoded_inputs = tokenizer(text=example['text'], max_seq_len=max_seq_length)
    input_ids = encoded_inputs['input_ids']
    token_type_ids = encoded_inputs['token_type_ids']

    if is_test:
        print('进入了test:')
        return input_ids, token_type_ids
    else:
        label = np.array([example['label']], dtype='int64')
        return input_ids, token_type_ids, label


def create_dataloader(dataset, batch_size=1,
                      batchify_fn=None, trans_fn=None):
    # trans_fn对应前边的covert_example函数，使用该函数处理每个样本为期望的格式
    if trans_fn:
        dataset = dataset.map(trans_fn)

    # 定义并初始化数据读取器
    return paddle.io.DataLoader(dataset, batch_size=batch_size,
                                shuffle=False, collate_fn=batchify_fn,
                                num_workers=1, drop_last=False, return_list=True)


trans_func = partial(
    convert_example,
    tokenizer=tokenizer,
    max_seq_length=max_seq_len)

trans_func02 = partial(
    convert_example,
    tokenizer=tokenizer,
    max_seq_length=max_seq_len,
    is_test=True)

batchify_fn = lambda samples, fn=Tuple(
    Pad(axis=0, pad_val=tokenizer.pad_token_id),
    Pad(axis=0, pad_val=tokenizer.pad_token_type_id),
    Stack(dtype='int64')
): [data for data in fn(samples)]

train_dataset = MyDataSet(Train_path)

train_set = MapDataset(train_dataset)

train_data_loader = create_dataloader(
    train_set,
    batch_size=batch_size,
    batchify_fn=batchify_fn,
    trans_fn=trans_func
)


# 检测是否可以使用gpu,如果可以优先使用gpu
use_gpu = True if paddle.get_device().startswith("gpu") else False
if use_gpu:
    paddle.set_device('gpu:0')

dropout_rate = None

# 学习率预热比例
warmup_propotion = 0.1
# 权重衰减系数，类似模型正则项策略，避免模型过拟合
weight_decay = 0.01

num_training_steps = len(train_data_loader) * epochs

lr_scheduler = LinearDecayWithWarmup(lr, num_training_steps, warmup_propotion)
# Out:
# [2023-01-13 20:13:21,552] [    INFO] - Downloading https://bj.bcebos.com/paddlenlp/models/transformers/ernie_tiny/vocab.txt and saved to /home/aistudio/.paddlenlp/models/ernie-tiny
# [2023-01-13 20:13:21,555] [    INFO] - Downloading vocab.txt from https://bj.bcebos.com/paddlenlp/models/transformers/ernie_tiny/vocab.txt
# 100%|██████████| 459k/459k [00:00<00:00, 2.82MB/s]
# [2023-01-13 20:13:21,915] [    INFO] - tokenizer config file saved in /home/aistudio/.paddlenlp/models/ernie-tiny/tokenizer_config.json
# [2023-01-13 20:13:21,918] [    INFO] - Special tokens file saved in /home/aistudio/.paddlenlp/models/ernie-tiny/special_tokens_map.json

# %%
# 构建网络
class ErnieForSequenceClassification(paddle.nn.Layer):
    def __init__(self, num_class=14, dropout=None):
        super(ErnieForSequenceClassification, self).__init__()
        # 加载预训练好的ernie
        self.ernie = paddlenlp.transformers.ErnieModel.from_pretrained(MODEL_NAME)
        # self.dropout=paddle.nn.Dropout(dropout)
        self.dropout = paddle.nn.Dropout(dropout if dropout is not None else self.ernie.config['hidden_dropout_prob'])
        self.classifier = paddle.nn.Linear(self.ernie.config['hidden_size'], num_class)

    def forward(self, input_ids, token_type_ids=None):
        sequence_output, pooled_output = self.ernie(
            input_ids,
            token_type_ids)
        # print("在网络里面~")
        # print('pooled_output:{}'.format(pooled_output))
        pooled_output = self.dropout(pooled_output)
        logits = self.classifier(pooled_output)
        return logits


# 加载预训练模型ERNIE
# 加载用于文本分类的fune-tuning网络
model = ErnieForSequenceClassification(num_class=14,
                                       dropout=dropout_rate)

# 定义统计指标
metric = paddle.metric.Accuracy()

optimizer = paddle.optimizer.AdamW(
    learning_rate=lr_scheduler,
    parameters=model.parameters(),
    weight_decay=weight_decay,
    apply_decay_param_fun=lambda x: x in [
        p.name for n, p in model.named_parameters()
        if not any(nd in n for nd in ['bias', 'norm'])
    ])
# Out:
# [2023-01-13 20:13:29,436] [    INFO] - Downloading https://bj.bcebos.com/paddlenlp/models/transformers/ernie_tiny/ernie_tiny.pdparams and saved to /home/aistudio/.paddlenlp/models/ernie-tiny
# [2023-01-13 20:13:29,439] [    INFO] - Downloading ernie_tiny.pdparams from https://bj.bcebos.com/paddlenlp/models/transformers/ernie_tiny/ernie_tiny.pdparams
# 100%|██████████| 346M/346M [00:11<00:00, 32.0MB/s]
# W0113 20:13:40.858995   286 gpu_resources.cc:61] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.2, Runtime API Version: 11.2
# W0113 20:13:40.862972   286 gpu_resources.cc:91] device: 0, cuDNN Version: 8.2.

# %%
def evaluate(model, metric, data_loader):
    model.eval()
    # 每次使用测试集进行评估时，先重置掉之前的metric的累计数据，保证只是针对本次评估。
    metric.reset()
    losses = []
    # logits_list=[]
    # labels_list=[]
    acc_list = []
    total_acc = 0

    for step, batch in enumerate(data_loader):
        input_ids, segment_ids, labels = batch
        logits = model(input_ids, segment_ids)
        # logits_list.extend(logits)
        # labels_list.extend(labels)
        loss = F.cross_entropy(input=logits, label=labels)
        loss = paddle.mean(loss)
        losses.append(loss.numpy())
        correct = metric.compute(logits, labels)
        metric.update(correct)
        acc = metric.accumulate()
        acc_list.append(acc)
        total_acc += acc

    print('eval loss:%.5f,acc:%.5f' % (np.mean(losses), acc))
    print('acc_list={}'.format(acc_list))
    print('ave_acc={}'.format(np.mean(acc_list)))
    print('total_acc={},ave_acc={}'.format(total_acc, total_acc / len(acc_list)))
    metric.reset()


def train(model):
    global_step = 0
    for epoch in range(1, epochs + 1):
        print('epoch={}'.format(epoch))
        model.train()
        for step, batch in enumerate(train_data_loader, start=1):
            if (step == 100):
                print("step={}".format(step))
            input_ids, segment_ids, labels = batch
            logits = model(input_ids, segment_ids)

            loss = F.cross_entropy(input=logits, label=labels)

            probs = F.softmax(logits, axis=1)
            correct = metric.compute(probs, labels)
            # if step<5:
            #     print('probs.shape:{}'.format(probs.shape))
            #     pred_labels=np.argmax(probs,axis=1)
            #     true_labels=labels
            #     print('step:{},pred_labels:{},true_labels:{}'.format(step,pred_labels,true_labels))
            #     # print('step:{},correct:{}'.format(step,correct))

            metric.update(correct)
            acc = metric.accumulate()
            print('step:{},acc:{}'.format(step, acc))

            global_step += 1

            # print("global step %d,epoch:%d,batch:%d,loss:%.5f,acc:%.5f"%(
            #     global_step,epoch,step,loss,acc))
            # if global_step % 10==0:
            #     print('batch:{}'.format(batch))
            # print('probs:{}\nlabels={}'.format(probs,labels))
            loss.backward()
            optimizer.step()
            lr_scheduler.step()
            optimizer.clear_grad()

        # evaluate(model,metric,test_data_loader)

# %%
train(model)
# Out:
# step:22517,acc:0.9034993005284896
# step:22518,acc:0.9035021982414069
# step:22519,acc:0.9035023202628891
# step:22520,acc:0.9035052175843694
# step:22521,acc:0.9035067270547489
# step:22522,acc:0.9035110114554658
# step:22523,acc:0.903511133063979
# step:22524,acc:0.9035112546616942
# step:22525,acc:0.903515538290788
# step:22526,acc:0.9035184342537512
# step:22527,acc:0.9035199427353842
# step:22528,acc:0.9035228382457386
# step:22529,acc:0.9035271206001154
# step:22530,acc:0.9035300155348425
# step:22531,acc:0.9035342971905375
# step:22532,acc:0.9035371915497958
# step:22533,acc:0.903534538232814
# step:22534,acc:0.9035332719446171
# step:22535,acc:0.9035347792323053
# step:22536,acc:0.9035362863862265
# step:22537,acc:0.9035391800150863
# step:22538,acc:0.9035434599343332
# step:22539,acc:0.9035394205599183
# step:22540,acc:0.9035423136645963
# step:22541,acc:0.9035424337873209
# step:22542,acc:0.9035467128027682
# step:22543,acc:0.9035496051989531
# step:22544,acc:0.9035511111603974
# step:22545,acc:0.9035512308715902
# step:22546,acc:0.9035555087376919
# step:22547,acc:0.9035528562558212
# step:22548,acc:0.9035557477381586
# step:22549,acc:0.9035600248348042
# step:22550,acc:0.9035601441241685
# step:22551,acc:0.9035588776550929
# step:22552,acc:0.9035589969847464
# step:22553,acc:0.9035632731787345
# step:22554,acc:0.9035661634299903
# step:22555,acc:0.9035704389270671
# step:22556,acc:0.9035719431636815
# step:22557,acc:0.9035748326461852
# step:22558,acc:0.9035777218725064
# step:22559,acc:0.9035778403298018
# step:22560,acc:0.9035793439716312
# step:22561,acc:0.9035794623465272
# step:22562,acc:0.9035837359276659
# step:22563,acc:0.9035880091299916
# step:22564,acc:0.9035881271051232
# step:22565,acc:0.9035896299578994
# step:22566,acc:0.9035911326774794
# step:22567,acc:0.9035940200292463
# step:22568,acc:0.9035955224211273
# step:22569,acc:0.9035956400372191
# step:22570,acc:0.903598526805494
# step:22571,acc:0.9036014133179744
# step:22572,acc:0.9036056840333156
# step:22573,acc:0.9036085699729766
# step:22574,acc:0.9036128399929122
# step:22575,acc:0.9036171096345514
# step:22576,acc:0.9036199946846208
# step:22577,acc:0.9036228794791159
# step:22578,acc:0.9036257640180707
# step:22579,acc:0.903630032330927
# step:22580,acc:0.9036315323294951
# step:22581,acc:0.903635800008857
# step:22582,acc:0.9036331480825436
# step:22583,acc:0.9036332639596156
# step:22584,acc:0.9036333798264258
# step:22585,acc:0.9036348793446978
# step:22586,acc:0.903630844328345
# step:22587,acc:0.9036323438260947
# step:22588,acc:0.9036352266690278
# step:22589,acc:0.9036367258400106
# step:22590,acc:0.9036368415227977
# step:22591,acc:0.9036383404895755
# step:22592,acc:0.9036398393236544
# step:22593,acc:0.9036399548532731
# step:22594,acc:0.903642836593786
# step:22595,acc:0.9036443350298738
# step:22596,acc:0.9036472163214728
# step:22597,acc:0.9036514802849935
# step:22598,acc:0.9036529781396584
# step:22599,acc:0.903653093057215
# step:22600,acc:0.9036545907079646
# step:22601,acc:0.9036547055440025
# step:22602,acc:0.9036548203698788
# step:22603,acc:0.903656317745432
# step:22604,acc:0.9036605799858433
# step:22605,acc:0.9036593120990931
# step:22606,acc:0.9036594267008758
# step:22607,acc:0.90365954129252
# step:22608,acc:0.9036582736199575
# step:22609,acc:0.9036597704453978
# step:22610,acc:0.9036612671384343
# step:22611,acc:0.9036627636990845
# step:22612,acc:0.9036614961082611
# step:22613,acc:0.9036643744748596
# step:22614,acc:0.9036644888122402
# step:22615,acc:0.9036646031395091
# step:22616,acc:0.9036660992217899
# step:22617,acc:0.9036675951717734
# step:22618,acc:0.9036677093465382
# step:22619,acc:0.9036678235112074
# step:22620,acc:0.9036693191865606
# step:22621,acc:0.9036694332699704
# step:22622,acc:0.9036736915392096
# step:22623,acc:0.9036765680944172
# step:22624,acc:0.9036780631188119
# step:22625,acc:0.9036754143646409
# step:22626,acc:0.9036741469990277
# step:22627,acc:0.9036770230255889
# step:22628,acc:0.9036798987979494
# step:22629,acc:0.903681393344823
# step:22630,acc:0.9036828877596111
# step:22631,acc:0.9036830011930538
# step:22632,acc:0.9036858761930011
# step:22633,acc:0.9036818473026113
# step:22634,acc:0.903683341433242
# step:22635,acc:0.9036862160371106
# step:22636,acc:0.9036877098427284
# step:22637,acc:0.9036905839996466
# step:22638,acc:0.9036948383249404
# step:22639,acc:0.903696331551747
# step:22640,acc:0.9036964443462897
# step:22641,acc:0.9036979373702575
# step:22642,acc:0.9036980500839148
# step:22643,acc:0.9037009230225677
# step:22644,acc:0.9037024156509451
# step:22645,acc:0.9037052881430779
# step:22646,acc:0.9037095403161707
# step:22647,acc:0.9037096524926039
# step:22648,acc:0.90370562522077
# step:22649,acc:0.903708497063888
# step:22650,acc:0.9037127483443709
# step:22651,acc:0.9037156196194428
# step:22652,acc:0.9037157315027371
# step:22653,acc:0.9037130843596874
# step:22654,acc:0.9037145757923546
# step:22655,acc:0.9037160670933568
# step:22656,acc:0.9037189375882768
# step:22657,acc:0.903719049300437
# step:22658,acc:0.9037205402065496
# step:22659,acc:0.9037220309810671
# step:22660,acc:0.9037221425419241
# step:22661,acc:0.9037250121353868
# step:22662,acc:0.9037278814755979
# step:22663,acc:0.9037293716630631
# step:22664,acc:0.9037294828803388
# step:22665,acc:0.9037309728656518
# step:22666,acc:0.9037352201535339
# step:22667,acc:0.9037380884104645
# step:22668,acc:0.9037395778189519
# step:22669,acc:0.903738310026909
# step:22670,acc:0.9037397992942214
# step:22671,acc:0.903744045256054
# step:22672,acc:0.9037455341390261
# step:22673,acc:0.9037456445993032
# step:22674,acc:0.9037485115109818
# step:22675,acc:0.9037527563395811
# step:22676,acc:0.9037556226847768
# step:22677,acc:0.9037557326806896
# step:22678,acc:0.9037572206543787
# step:22679,acc:0.9037587084968473
# step:22680,acc:0.9037601962081129
# step:22681,acc:0.9037644393986156
# step:22682,acc:0.9037673044705052
# step:22683,acc:0.9037701692897765
# step:22684,acc:0.9037702786104743
# step:22685,acc:0.9037717654837999
# step:22686,acc:0.9037732522260425
# step:22687,acc:0.9037747388372196
# step:22688,acc:0.9037789800775741
# step:22689,acc:0.9037790889858521
# step:22690,acc:0.903780575143235
# step:22691,acc:0.9037806839716187
# step:22692,acc:0.9037821699277279
# step:22693,acc:0.903785032829507
# step:22694,acc:0.9037878954789812
# step:22695,acc:0.9037866270103547
# step:22696,acc:0.9037826048642933
# step:22697,acc:0.903784090408424
# step:22698,acc:0.9037869525949422
# step:22699,acc:0.9037884378166439
# step:22700,acc:0.9037926762114538
# step:22701,acc:0.9037927844588344
# step:22702,acc:0.9037942692273808
# step:22703,acc:0.903795753865128
# step:22704,acc:0.9037958619626497
# step:22705,acc:0.903793217353006
# step:22706,acc:0.9037933255527173
# step:22707,acc:0.9037906812877087
# step:22708,acc:0.9037949180905408
# step:22709,acc:0.9037936500946762
# step:22710,acc:0.9037951343020696
# step:22711,acc:0.90379937034917
# step:22712,acc:0.9038036060232476
# step:22713,acc:0.9038050895962665
# step:22714,acc:0.9038065730386545
# step:22715,acc:0.9038080563504293
# step:22716,acc:0.9038109152139461
# step:22717,acc:0.9038110225822071
# step:22718,acc:0.903809754379787
# step:22719,acc:0.9038112372903737
# step:22720,acc:0.9038072183098591
# step:22721,acc:0.9038100765811364
# step:22722,acc:0.9038074333245313
# step:22723,acc:0.9038075408176737
# step:22724,acc:0.9038076483013554
# step:22725,acc:0.9038077557755776
# step:22726,acc:0.9038106133943501
# step:22727,acc:0.903812095745149
# step:22728,acc:0.9038094530975008
# step:22729,acc:0.903809560473404
# step:22730,acc:0.9038124175098988
# step:22731,acc:0.9038152742950156
# step:22732,acc:0.9038195055428471
# step:22733,acc:0.9038182378040733
# step:22734,acc:0.9038197193630685
# step:22735,acc:0.9038184517264131
# step:22736,acc:0.9038213076178747
# step:22737,acc:0.9038241632581255
# step:22738,acc:0.9038215212419738
# step:22739,acc:0.9038230023307973
# step:22740,acc:0.9038272317502198
# step:22741,acc:0.9038300866276768
# step:22742,acc:0.9038329412540673
# step:22743,acc:0.9038330475311085
# step:22744,acc:0.9038372757650369
# step:22745,acc:0.903838755770499
# step:22746,acc:0.903838861777895
# step:22747,acc:0.9038403415835056
# step:22748,acc:0.9038418212590118
# step:22749,acc:0.903843300804431
# step:22750,acc:0.9038461538461539
# step:22751,acc:0.9038448859390796
# step:22752,acc:0.9038477386603375
# step:22753,acc:0.9038492176855799
# step:22754,acc:0.903850696580821
# step:22755,acc:0.9038535486706218
# step:22756,acc:0.9038564005097557
# step:22757,acc:0.9038592520982555
# step:22758,acc:0.9038621034361544
# step:22759,acc:0.9038649545234853
# step:22760,acc:0.9038664323374341
# step:22761,acc:0.9038692829840517
# step:22762,acc:0.903872133380195
# step:22763,acc:0.9038749835258972
# step:22764,acc:0.9038778334211913
# step:22765,acc:0.9038806830661102
# step:22766,acc:0.9038780418167442
# step:22767,acc:0.9038808912021786
# step:22768,acc:0.9038809952565003
# step:22769,acc:0.9038838442619351
# step:22770,acc:0.9038853205972771
# step:22771,acc:0.9038867968029511
# step:22772,acc:0.9038882728789742
# step:22773,acc:0.9038856321081983
# step:22774,acc:0.9038871081057346
# step:22775,acc:0.9038872118551042
# step:22776,acc:0.9038900597119776
# step:22777,acc:0.90389016332265
# step:22778,acc:0.9038930107998946
# step:22779,acc:0.9038944861495237
# step:22780,acc:0.9038973331870062
# step:22781,acc:0.9038933211887099
# step:22782,acc:0.9038947963304363
# step:22783,acc:0.9038935280691743
# step:22784,acc:0.9038977462254213
# step:22785,acc:0.9038964779460171
# step:22786,acc:0.9038993241464057
# step:22787,acc:0.9039007987010137
# step:22788,acc:0.9039022731262067
# step:22789,acc:0.9039051186976172
# step:22790,acc:0.9039079640193067
# step:22791,acc:0.9039066956254662
# step:22792,acc:0.9039081695331695
# step:22793,acc:0.903909643311543
# step:22794,acc:0.9039111169606037
# step:22795,acc:0.90390984865102
# step:22796,acc:0.9039113221617827
# step:22797,acc:0.9039155371320787
# step:22798,acc:0.9039197517326081
# step:22799,acc:0.9039212246151147
# step:22800,acc:0.903922697368421
# step:22801,acc:0.9039227994386211
# step:22802,acc:0.9039201605122358
# step:22803,acc:0.9039243739858791
# step:22804,acc:0.9039272167163656
# step:22805,acc:0.9039273185704889
# step:22806,acc:0.9039287906691221
# step:22807,acc:0.9039302626386636
# step:22808,acc:0.9039303643458436
# step:22809,acc:0.9039345762637555
# step:22810,acc:0.9039360477860587
# step:22811,acc:0.9039347792731577
# step:22812,acc:0.9039348807645099
# step:22813,acc:0.9039377219129444
# step:22814,acc:0.903936453493469
# step:22815,acc:0.9039379246110015
# step:22816,acc:0.9039393955995793
# step:22817,acc:0.903940866459219
# step:22818,acc:0.9039382285914629
# step:22819,acc:0.903935590954906
# step:22820,acc:0.903932953549518
# step:22821,acc:0.9039344244336357
# step:22822,acc:0.9039345258960652
# step:22823,acc:0.9039346273496035
# step:22824,acc:0.9039388363126534
# step:22825,acc:0.9039416757940855
# step:22826,acc:0.9039431459738895
# step:22827,acc:0.9039418780391641
# step:22828,acc:0.9039419791484142
# step:22829,acc:0.9039434491217311
# step:22830,acc:0.9039449189662725
# step:22831,acc:0.9039477574350664
# step:22832,acc:0.9039505956552207
# step:22833,acc:0.903954802259887
# step:22834,acc:0.903957639922922
# step:22835,acc:0.9039577403109262
# step:22836,acc:0.9039605775967771
# step:22837,acc:0.9039620462407496
# step:22838,acc:0.903962146422629
# step:22839,acc:0.9039663514164368
# step:22840,acc:0.9039705560420315
# step:22841,acc:0.9039733921457029
# step:22842,acc:0.9039707556256019
# step:22843,acc:0.9039749595061944
# step:22844,acc:0.9039764270705656
# step:22845,acc:0.9039765265922521
# step:22846,acc:0.9039793618138843
# step:22847,acc:0.9039808289928656
# step:22848,acc:0.903985031512605
# step:22849,acc:0.903989233664493
# step:22850,acc:0.9039893326039388
# step:22851,acc:0.9039921666447858
# step:22852,acc:0.9039963679327849
# step:22853,acc:0.9039978339824093
# step:22854,acc:0.9039979325282226
# step:22855,acc:0.9039980310654124
# step:22856,acc:0.9039953950822541
# step:22857,acc:0.9039982281139257
# step:22858,acc:0.9039942252165544
# step:22859,acc:0.9039956909751082
# step:22860,acc:0.9039985236220472
# step:22861,acc:0.9040027229779974
# step:22862,acc:0.9040028212754789
# step:22863,acc:0.9040042864016096
# step:22864,acc:0.9040057513995802
# step:22865,acc:0.9040072162694074
# step:22866,acc:0.9040100476690283
# step:22867,acc:0.9040101456246994
# step:22868,acc:0.9040116101101977
# step:22869,acc:0.9040130744676199
# step:22870,acc:0.9040159051158724
# step:22871,acc:0.9040173691574483
# step:22872,acc:0.9040201993704092
# step:22873,acc:0.9040175643772133
# step:22874,acc:0.9040190281542363
# step:22875,acc:0.9040204918032787
# step:22876,acc:0.9040205892638573
# step:22877,acc:0.9040220527167023
# step:22878,acc:0.904023516041612
# step:22879,acc:0.904026345119979
# step:22880,acc:0.9040305397727273
# step:22881,acc:0.9040333682968402
# step:22882,acc:0.904036196573726
# step:22883,acc:0.9040390246034173
# step:22884,acc:0.9040404868030064
# step:22885,acc:0.9040419488748088
# step:22886,acc:0.9040447762824434
# step:22887,acc:0.9040476034430026
# step:22888,acc:0.9040463343236631
# step:22889,acc:0.904047795884486
# step:22890,acc:0.9040478920926168
# step:22891,acc:0.9040493534576908
# step:22892,acc:0.9040494495893762
# step:22893,acc:0.9040536408509151
# step:22894,acc:0.9040551017733904
# step:22895,acc:0.9040579274950863
# step:22896,acc:0.9040580232354997
# step:22897,acc:0.9040622133904005
# step:22898,acc:0.904065038431304
# step:22899,acc:0.904066498537054
# step:22900,acc:0.9040679585152839
# step:22901,acc:0.9040694183660102
# step:22902,acc:0.9040736071085494
# step:22903,acc:0.9040750665851636
# step:22904,acc:0.9040765259343346
# step:22905,acc:0.9040779851560795
# step:22906,acc:0.9040698943508251
# step:22907,acc:0.9040686253110403
# step:22908,acc:0.9040700846865724
# step:22909,acc:0.9040742721201275
# step:22910,acc:0.9040743670886076
# step:22911,acc:0.9040771899960718
# step:22912,acc:0.9040800126571229
# step:22913,acc:0.9040814712172129
# step:22914,acc:0.9040842934450555
# step:22915,acc:0.9040857516910321
# step:22916,acc:0.9040844824576715
# step:22917,acc:0.9040859405681372
# step:22918,acc:0.904087398551357
# step:22919,acc:0.9040915834024172
# step:22920,acc:0.9040930410122164
# step:22921,acc:0.9040958618733912
# step:22922,acc:0.9040959558502748
# step:22923,acc:0.9041001395977839
# step:22924,acc:0.9041015965800034
# step:22925,acc:0.9041003271537623
# step:22926,acc:0.9041017840006979
# step:22927,acc:0.9041059667640773
# step:22928,acc:0.9041060602756456
# step:22929,acc:0.9041088795848052
# step:22930,acc:0.9041103358046227
# step:22931,acc:0.9041117918974314
# step:22932,acc:0.9041105224140938
# step:22933,acc:0.9041092530414686
# step:22934,acc:0.9041107089910178
# step:22935,acc:0.9041108022672771
# step:22936,acc:0.9041081705615626
# step:22937,acc:0.9041109887953961
# step:22938,acc:0.9041138067835034
# step:22939,acc:0.9041152622171847
# step:22940,acc:0.9041126307759372
# step:22941,acc:0.9041140861339959
# step:22942,acc:0.9041155413651818
# step:22943,acc:0.9041197206119513
# step:22944,acc:0.9041211754707112
# step:22945,acc:0.9041226302026585
# step:22946,acc:0.9041227229146692
# step:22947,acc:0.9041255392861812
# step:22948,acc:0.9041269936377898
# step:22949,acc:0.9041230010022223
# step:22950,acc:0.9041258169934641
# step:22951,acc:0.9041299943357588
# step:22952,acc:0.9041328097769258
# step:22953,acc:0.9041329020171656
# step:22954,acc:0.9041370785048357
# step:22955,acc:0.9041398932694402
# step:22956,acc:0.9041413464889354
# step:22957,acc:0.9041441608224071
# step:22958,acc:0.9041469749107065
# step:22959,acc:0.9041484276318655
# step:22960,acc:0.9041512412891987
# step:22961,acc:0.9041526936980097
# step:22962,acc:0.9041541459803153
# step:22963,acc:0.904155598136132
# step:22964,acc:0.9041597718167567
# step:22965,acc:0.9041585020683649
# step:22966,acc:0.9041599538448141
# step:22967,acc:0.9041614054948405
# step:22968,acc:0.9041642176071055
# step:22969,acc:0.9041656689450999
# step:22970,acc:0.9041657596865477
# step:22971,acc:0.9041658504200949
# step:22972,acc:0.9041673014974752
# step:22973,acc:0.9041687524485266
# step:22974,acc:0.9041702032732655
# step:22975,acc:0.9041716539717084
# step:22976,acc:0.9041717444289693
# step:22977,acc:0.9041731949340645
# step:22978,acc:0.9041760053094264
# step:22979,acc:0.9041774555028504
# step:22980,acc:0.904178905570061
# step:22981,acc:0.9041830751490362
# step:22982,acc:0.9041858846053433
# step:22983,acc:0.9041859744158726
# step:22984,acc:0.9041860642185868
# step:22985,acc:0.9041888731781597
# step:22986,acc:0.9041916818933263
# step:22987,acc:0.904191771436029
# step:22988,acc:0.9041918609709414
# step:22989,acc:0.9041946691896124
# step:22990,acc:0.9041974771639844
# step:22991,acc:0.9041989256665651
# step:22992,acc:0.9041976557063326
# step:22993,acc:0.9041977449658591
# step:22994,acc:0.904201911368183
# step:22995,acc:0.9042060774081322
# step:22996,acc:0.9042048073578014
# step:22997,acc:0.9042048962908206
# step:22998,acc:0.9042063440299156
# step:22999,acc:0.9042091503978433
# step:23000,acc:0.9042092391304348
# step:23001,acc:0.9042120451284726
# step:23002,acc:0.904214850882532
# step:23003,acc:0.9042190149110986
# step:23004,acc:0.904220461658842
# step:23005,acc:0.9042205498804607
# step:23006,acc:0.9042192797531079
# step:23007,acc:0.9042193680184292
# step:23008,acc:0.9042221727225312
# step:23009,acc:0.9042222608544482
# step:23010,acc:0.9042237070838766
# step:23011,acc:0.9042278692799096
# step:23012,acc:0.9042306731270642
# step:23013,acc:0.9042307608742884
# step:23014,acc:0.9042322064830104
# step:23015,acc:0.9042322941559853
# step:23016,acc:0.904235097323601
# step:23017,acc:0.9042338271712212
# step:23018,acc:0.9042379876618298
# step:23019,acc:0.9042407902167774
# step:23020,acc:0.904240877497828
# step:23021,acc:0.9042396073150601
# step:23022,acc:0.9042396946399096
# step:23023,acc:0.9042384246188594
# step:23024,acc:0.9042425838255733
# step:23025,acc:0.9042413137893593
# step:23026,acc:0.9042441153478676
# step:23027,acc:0.9042469166630477
# step:23028,acc:0.9042497177349313
# step:23029,acc:0.9042538755482218
# step:23030,acc:0.9042526052974381
# step:23031,acc:0.904256762624289
# step:23032,acc:0.9042609195901354
# step:23033,acc:0.9042582924499631
# step:23034,acc:0.9042624489884519
# step:23035,acc:0.9042652485348383
# step:23036,acc:0.904269404410488
# step:23037,acc:0.9042681338715979
# step:23038,acc:0.9042709328066673
# step:23039,acc:0.9042750878944399
# step:23040,acc:0.9042792426215278
# step:23041,acc:0.9042820407100386
# step:23042,acc:0.9042834823366027
# step:23043,acc:0.9042862799982642
# step:23044,acc:0.9042850091130012
# step:23045,acc:0.9042864504230853
# step:23046,acc:0.9042851796407185
# step:23047,acc:0.9042839089686293
# step:23048,acc:0.9042880618708782
# step:23049,acc:0.904289502798386
# step:23050,acc:0.9042895878524946
# step:23051,acc:0.9042910285887814
# step:23052,acc:0.9042924692000694
# step:23053,acc:0.9042939096863749
# step:23054,acc:0.904292639021428
# step:23055,acc:0.9042886575580135
# step:23056,acc:0.9042900980222068
# step:23057,acc:0.904290183024678
# step:23058,acc:0.9042943338537601
# step:23059,acc:0.9042957738843835
# step:23060,acc:0.9042972137901127
# step:23061,acc:0.904298653570964
# step:23062,acc:0.9042960280981701
# step:23063,acc:0.9042974678055761
# step:23064,acc:0.9042989073881373
# step:23065,acc:0.9043017017125515
# step:23066,acc:0.9043044957946762
# step:23067,acc:0.9043059348853341
# step:23068,acc:0.9043073738512225
# step:23069,acc:0.9043088126923577
# step:23070,acc:0.9043116059817945
# step:23071,acc:0.9043130445147588
# step:23072,acc:0.9043144829230236
# step:23073,acc:0.9043186300004334
# step:23074,acc:0.9043214223801681
# step:23075,acc:0.9043242145178765
# step:23076,acc:0.9043256521927544
# step:23077,acc:0.9043270897430342
# step:23078,acc:0.9043298812722073
# step:23079,acc:0.9043326725594697
# step:23080,acc:0.9043341096187175
# step:23081,acc:0.9043382544083879
# step:23082,acc:0.9043396911012911
# step:23083,acc:0.9043438352900403
# step:23084,acc:0.9043479791197366
# step:23085,acc:0.9043507688975525
# step:23086,acc:0.9043508511652083
# step:23087,acc:0.9043536405769481
# step:23088,acc:0.9043537227130977
# step:23089,acc:0.9043551583004894
# step:23090,acc:0.9043538869640537
# step:23091,acc:0.904356675761119
# step:23092,acc:0.9043567577516023
# step:23093,acc:0.9043581929589053
# step:23094,acc:0.9043623343725643
# step:23095,acc:0.9043637692141157
# step:23096,acc:0.9043665569795636
# step:23097,acc:0.9043679915140495
# step:23098,acc:0.9043721317863018
# step:23099,acc:0.9043735659552361
# step:23100,acc:0.904375
# step:23101,acc:0.9043791394311934
# step:23102,acc:0.9043805731105532
# step:23103,acc:0.9043833593039865
# step:23104,acc:0.9043874978358726
# step:23105,acc:0.9043916360095218
# step:23106,acc:0.9043876590495975
# step:23107,acc:0.9043917968580949
# step:23108,acc:0.9043959343084647
# step:23109,acc:0.904400071400753
# step:23110,acc:0.904402855906534
# step:23111,acc:0.9044042880013846
# step:23112,acc:0.904407072083766
# step:23113,acc:0.9044098559252369
# step:23114,acc:0.9044112875313662
# step:23115,acc:0.9044140709495998
# step:23116,acc:0.9044127984945493
# step:23117,acc:0.9044169334256175
# step:23118,acc:0.904418364477896
# step:23119,acc:0.9044197954063757
# step:23120,acc:0.9044212262110727
# step:23121,acc:0.904425360062281
# step:23122,acc:0.9044281420292363
# step:23123,acc:0.9044268693508628
# step:23124,acc:0.904428299602145
# step:23125,acc:0.9044283783783784
# step:23126,acc:0.9044244032690478
# step:23127,acc:0.9044244822069443
# step:23128,acc:0.9044272634901418
# step:23129,acc:0.904428693415193
# step:23130,acc:0.9044328253350626
# step:23131,acc:0.9044356058968483
# step:23132,acc:0.9044370352758084
# step:23133,acc:0.9044371136471707
# step:23134,acc:0.9044385428373822
# step:23135,acc:0.9044413226712773
# step:23136,acc:0.9044427515560166
# step:23137,acc:0.9044428296667675
# step:23138,acc:0.9044442583628662
# step:23139,acc:0.9044456869354769
# step:23140,acc:0.9044471153846154
# step:23141,acc:0.9044485437102977
# step:23142,acc:0.9044526726298505
# step:23143,acc:0.9044541005919716
# step:23144,acc:0.9044528279467681
# step:23145,acc:0.9044569561460358
# step:23146,acc:0.9044570336127192
# step:23147,acc:0.9044557610057459
# step:23148,acc:0.9044585385346466
# step:23149,acc:0.9044613158235777
# step:23150,acc:0.9044627429805615
# step:23151,acc:0.9044641700142543
# step:23152,acc:0.9044669467000691
# step:23153,acc:0.9044697231460286
# step:23154,acc:0.9044698000345512
# step:23155,acc:0.9044739257179875
# step:23156,acc:0.9044740024183797
# step:23157,acc:0.9044754285961049
# step:23158,acc:0.9044768546506606
# step:23159,acc:0.9044728831123969
# step:23160,acc:0.9044743091537133
# step:23161,acc:0.904475735071888
# step:23162,acc:0.904474462481651
# step:23163,acc:0.9044731900012952
# step:23164,acc:0.9044746157831117
# step:23165,acc:0.9044760414418304
# step:23166,acc:0.9044747690581024
# step:23167,acc:0.9044788923900375
# step:23168,acc:0.90448166652279
# step:23169,acc:0.9044817428460443
# step:23170,acc:0.9044791217091066
# step:23171,acc:0.9044805468041949
# step:23172,acc:0.9044819717762818
# step:23173,acc:0.9044847451775774
# step:23174,acc:0.9044848213515146
# step:23175,acc:0.9044848975188781
# step:23176,acc:0.9044849736796686
# step:23177,acc:0.9044863981533416
# step:23178,acc:0.9044891707653809
# step:23179,acc:0.9044919431381854
# step:23180,acc:0.9044960634167386
# step:23181,acc:0.9044974871662137
# step:23182,acc:0.9045002588214994
# step:23183,acc:0.9045030302376742
# step:23184,acc:0.9045044535024155
# step:23185,acc:0.9045058766443821
# step:23186,acc:0.9045099952557578
# step:23187,acc:0.9045114180359685
# step:23188,acc:0.9045114930136278
# step:23189,acc:0.9045142632282548
# step:23190,acc:0.9045156856403622
# step:23191,acc:0.9045157604243025
# step:23192,acc:0.904518530096585
# step:23193,acc:0.9045212995300306
# step:23194,acc:0.9045240687246702
# step:23195,acc:0.9045214485880577
# step:23196,acc:0.9045228703224694
# step:23197,acc:0.9045229447773419
# step:23198,acc:0.9045270605224588
# step:23199,acc:0.904525787749472
# step:23200,acc:0.9045299030172413
# step:23201,acc:0.9045313240808586
# step:23202,acc:0.9045327450219809
# step:23203,acc:0.9045341658406241
# step:23204,acc:0.9045342397862437
# step:23205,acc:0.9045356604180134
# step:23206,acc:0.9045397741963286
# step:23207,acc:0.9045398478907226
# step:23208,acc:0.9045439611340917
# step:23209,acc:0.9045440346417338
# step:23210,acc:0.9045454545454545
# step:23211,acc:0.9045482206712334
# step:23212,acc:0.9045482939858693
# step:23213,acc:0.9045483672941886
# step:23214,acc:0.9045524791074352
# step:23215,acc:0.9045538983415895
# step:23216,acc:0.9045580095623708
# step:23217,acc:0.9045594284360597
# step:23218,acc:0.9045621931260229
# step:23219,acc:0.9045649575778457
# step:23220,acc:0.904567721791559
# step:23221,acc:0.9045704857671935
# step:23222,acc:0.9045719037981225
# step:23223,acc:0.9045760130043491
# step:23224,acc:0.9045747394936273
# step:23225,acc:0.9045734660925726
# step:23226,acc:0.9045748837509687
# step:23227,acc:0.9045749558703233
# step:23228,acc:0.9045763733425176
# step:23229,acc:0.9045791359938008
# step:23230,acc:0.9045805531640121
# step:23231,acc:0.9045819702122164
# step:23232,acc:0.9045847322658402
# step:23233,acc:0.9045848039426677
# step:23234,acc:0.9045875656365671
# step:23235,acc:0.9045916720464816
# step:23236,acc:0.9045944332070924
# step:23237,acc:0.9045918147781555
# step:23238,acc:0.9045918861347793
# step:23239,acc:0.904593302207496
# step:23240,acc:0.904593373493976
# step:23241,acc:0.90459613398735
# step:23242,acc:0.9045975496945186
# step:23243,acc:0.9046016542614981
# step:23244,acc:0.9046057584753054
# step:23245,acc:0.9046071735857174
# step:23246,acc:0.9046085885743784
# step:23247,acc:0.9046086591818299
# step:23248,acc:0.9046127623881625
# step:23249,acc:0.9046114886661792
# step:23250,acc:0.9046142473118279
# step:23251,acc:0.9046170057201841
# step:23252,acc:0.904618419920867
# step:23253,acc:0.9046171461746871
# step:23254,acc:0.9046185602476993
# step:23255,acc:0.9046172866050312
# step:23256,acc:0.9046200442896457
# step:23257,acc:0.9046228017371114
# step:23258,acc:0.9046242153237596
# step:23259,acc:0.9046269723547874
# step:23260,acc:0.9046297291487532
# step:23261,acc:0.9046324857056877
# step:23262,acc:0.9046338986329636
# step:23263,acc:0.9046379981085845
# step:23264,acc:0.904640753954608
# step:23265,acc:0.904642166344294
# step:23266,acc:0.904646264935958
# step:23267,acc:0.9046490200713457
# step:23268,acc:0.9046490888774282
# step:23269,acc:0.9046505006661223
# step:23270,acc:0.9046519123334765
# step:23271,acc:0.9046546667526105
# step:23272,acc:0.9046574209350292
# step:23273,acc:0.9046601748807631
# step:23274,acc:0.9046642712898514
# step:23275,acc:0.9046670247046187
# step:23276,acc:0.9046670927135246
# step:23277,acc:0.9046685032435451
# step:23278,acc:0.9046645437752384
# step:23279,acc:0.9046646118819537
# step:23280,acc:0.9046673646907216
# step:23281,acc:0.9046714595592973
# step:23282,acc:0.9046675006442746
# step:23283,acc:0.9046702529742731
# step:23284,acc:0.9046689786978183
# step:23285,acc:0.9046703886622289
# step:23286,acc:0.9046731405136134
# step:23287,acc:0.904674550178211
# step:23288,acc:0.9046746178289248
# step:23289,acc:0.9046720018034266
# step:23290,acc:0.9046760948905109
# step:23291,acc:0.904678845906144
# step:23292,acc:0.9046762300360639
# step:23293,acc:0.9046789808096853
# step:23294,acc:0.9046790482527689
# step:23295,acc:0.9046817986692424
# step:23296,acc:0.9046845488495879
# step:23297,acc:0.9046872987938361
# step:23298,acc:0.9046887071851661
# step:23299,acc:0.9046874329370359
# step:23300,acc:0.9046888412017168
# step:23301,acc:0.9046889082013647
# step:23302,acc:0.9046903162818642
# step:23303,acc:0.9046903832124619
# step:23304,acc:0.9046891091658085
# step:23305,acc:0.9046851534005578
# step:23306,acc:0.9046865614004977
# step:23307,acc:0.9046866284807139
# step:23308,acc:0.9046880362965506
# step:23309,acc:0.9046907846754473
# step:23310,acc:0.9046908515658516
# step:23311,acc:0.9046922590193471
# step:23312,acc:0.9046936663520934
# step:23313,acc:0.9046977544717539
# step:23314,acc:0.9046964806554002
# step:23315,acc:0.9046978876259919
# step:23316,acc:0.9047006347572483
# step:23317,acc:0.9047047218767423
# step:23318,acc:0.9047088086456815
# step:23319,acc:0.9047075346284146
# step:23320,acc:0.9047076007718696
# step:23321,acc:0.9047103468976458
# step:23322,acc:0.9047104129148443
# step:23323,acc:0.9047091390472923
# step:23324,acc:0.9047078652889727
# step:23325,acc:0.9047092711682744
# step:23326,acc:0.9047093372202692
# step:23327,acc:0.9047053843186008
# step:23328,acc:0.9047067901234568
# step:23329,acc:0.9047055167388229
# step:23330,acc:0.9047029039862837
# step:23331,acc:0.9047056491363422
# step:23332,acc:0.9047070546888394
# step:23333,acc:0.9047071208160117
# step:23334,acc:0.9047098654324163
# step:23335,acc:0.904709931433469
# step:23336,acc:0.9047113365615358
# step:23337,acc:0.9047140806444701
# step:23338,acc:0.9047168244922444
# step:23339,acc:0.9047195681048888
# step:23340,acc:0.9047223114824335
# step:23341,acc:0.9047250546249089
# step:23342,acc:0.9047264587438951
# step:23343,acc:0.9047278627425781
# step:23344,acc:0.9047292666209733
# step:23345,acc:0.9047320089955022
# step:23346,acc:0.9047320740169622
# step:23347,acc:0.9047348160363216
# step:23348,acc:0.9047308655987665
# step:23349,acc:0.904733607435008
# step:23350,acc:0.9047363490364025
# step:23351,acc:0.9047404286754315
# step:23352,acc:0.9047418315347722
# step:23353,acc:0.9047432342739691
# step:23354,acc:0.9047446368930376
# step:23355,acc:0.9047473774352387
# step:23356,acc:0.9047461037848947
# step:23357,acc:0.9047475061009548
# step:23358,acc:0.904746232554157
# step:23359,acc:0.9047489725587567
# step:23360,acc:0.9047517123287672
# step:23361,acc:0.9047544518642181
# step:23362,acc:0.9047558535228148
# step:23363,acc:0.9047585926464923
# step:23364,acc:0.9047599940078753
# step:23365,acc:0.9047640701904558
# step:23366,acc:0.9047654711974664
# step:23367,acc:0.9047655347284632
# step:23368,acc:0.9047682728517631
# step:23369,acc:0.904768336257435
# step:23370,acc:0.9047697368421053
# step:23371,acc:0.9047711373069188
# step:23372,acc:0.9047712005818929
# step:23373,acc:0.904772600864245
# step:23374,acc:0.9047726640711902
# step:23375,acc:0.9047713903743315
# step:23376,acc:0.9047701167864476
# step:23377,acc:0.904767506523506
# step:23378,acc:0.9047715801180597
# step:23379,acc:0.9047729800248085
# step:23380,acc:0.904774379811805
# step:23381,acc:0.9047757794790642
# step:23382,acc:0.9047758425284407
# step:23383,acc:0.9047799148954369
# step:23384,acc:0.9047813141464249
# step:23385,acc:0.9047853859311524
# step:23386,acc:0.9047881210980929
# step:23387,acc:0.9047908560311284
# step:23388,acc:0.9047935907302891
# step:23389,acc:0.9047949890974389
# step:23390,acc:0.9047963873450192
# step:23391,acc:0.9047964494891197
# step:23392,acc:0.904796511627907
# step:23393,acc:0.9048005813704955
# step:23394,acc:0.9048006433273489
# step:23395,acc:0.9048033767899124
# step:23396,acc:0.9048074457172166
# step:23397,acc:0.9048115142967047
# step:23398,acc:0.9048155825284212
# step:23399,acc:0.9048156438309329
# step:23400,acc:0.9048157051282051
# step:23401,acc:0.904817101833255
# step:23402,acc:0.9048198337748911
# step:23403,acc:0.9048225654830577
# step:23404,acc:0.904825296957785
# step:23405,acc:0.9048266930143132
# step:23406,acc:0.9048307592070409
# step:23407,acc:0.9048321549109241
# step:23408,acc:0.904833550495557
# step:23409,acc:0.9048349459609552
# step:23410,acc:0.9048363413071338
# step:23411,acc:0.9048404062192986
# step:23412,acc:0.9048418012130531
# step:23413,acc:0.9048445308162132
# step:23414,acc:0.9048459255146494
# step:23415,acc:0.9048486547085202
# step:23416,acc:0.9048500491117185
# step:23417,acc:0.9048514433958236
# step:23418,acc:0.9048528375608507
# step:23419,acc:0.904854231606815
# step:23420,acc:0.9048542912040991
# step:23421,acc:0.9048583536142778
# step:23422,acc:0.9048584130304842
# step:23423,acc:0.904861140759083
# step:23424,acc:0.9048638682547814
# step:23425,acc:0.9048652614727855
# step:23426,acc:0.9048693225475967
# step:23427,acc:0.9048707154138387
# step:23428,acc:0.9048747759091685
# step:23429,acc:0.9048735007896197
# step:23430,acc:0.904874893299189
# step:23431,acc:0.9048789530963254
# step:23432,acc:0.904880345254353
# step:23433,acc:0.9048817372935604
# step:23434,acc:0.9048844627464367
# step:23435,acc:0.9048871879667164
# step:23436,acc:0.9048872461170848
# step:23437,acc:0.904887304262491
# step:23438,acc:0.9048873624029354
# step:23439,acc:0.9048874205384189
# step:23440,acc:0.9048914782423209
# step:23441,acc:0.9048942024657651
# step:23442,acc:0.9048982595341695
# step:23443,acc:0.9048996502154161
# step:23444,acc:0.9049023737416823
# step:23445,acc:0.9049037641288121
# step:23446,acc:0.9049038215473855
# step:23447,acc:0.9049065445472768
# step:23448,acc:0.9049066018423746
# step:23449,acc:0.9049053264531537
# step:23450,acc:0.9049053837953092
# step:23451,acc:0.9049081062641252
# step:23452,acc:0.9049081634828586
# step:23453,acc:0.9049082206967126
# step:23454,acc:0.9049122750916688
# step:23455,acc:0.9049149968023875
# step:23456,acc:0.904915053717599
# step:23457,acc:0.9049177750778019
# step:23458,acc:0.904915167533464
# step:23459,acc:0.9049178886568054
# step:23460,acc:0.9049206095481671
# step:23461,acc:0.904921998209795
# step:23462,acc:0.9049220548120365
# step:23463,acc:0.904926107062183
# step:23464,acc:0.9049301589669281
# step:23465,acc:0.9049328787555935
# step:23466,acc:0.9049355983124521
# step:23467,acc:0.904935654323092
# step:23468,acc:0.904938373529913
# step:23469,acc:0.9049384294175296
# step:23470,acc:0.9049398167873881
# step:23471,acc:0.9049412040390269
# step:23472,acc:0.9049439225460123
# step:23473,acc:0.9049426468708729
# step:23474,acc:0.9049466963448922
# step:23475,acc:0.904945420660277
# step:23476,acc:0.9049481385244506
# step:23477,acc:0.9049481939770839
# step:23478,acc:0.9049469183916858
# step:23479,acc:0.9049496358447975
# step:23480,acc:0.9049483603066439
# step:23481,acc:0.9049510774668881
# step:23482,acc:0.9049524635891321
# step:23483,acc:0.9049565110931312
# step:23484,acc:0.9049592275591892
# step:23485,acc:0.9049579518841814
# step:23486,acc:0.9049593374776462
# step:23487,acc:0.904960722953123
# step:23488,acc:0.9049634387772479
# step:23489,acc:0.9049648239601515
# step:23490,acc:0.9049635483184334
# step:23491,acc:0.9049662636754502
# step:23492,acc:0.9049663183211306
# step:23493,acc:0.9049690333290767
# step:23494,acc:0.9049704179790585
# step:23495,acc:0.9049691423707171
# step:23496,acc:0.9049731869254342
# step:23497,acc:0.9049759011788739
# step:23498,acc:0.9049772853008766
# step:23499,acc:0.9049799991488999
# step:23500,acc:0.9049813829787234
# step:23501,acc:0.9049827666907792
# step:23502,acc:0.9049841502850822
# step:23503,acc:0.9049868633791431
# step:23504,acc:0.9049895762423418
# step:23505,acc:0.904989629865986
# step:23506,acc:0.9049910129328682
# step:23507,acc:0.9049937252733229
# step:23508,acc:0.904995108048324
# step:23509,acc:0.9049991492619848
# step:23510,acc:0.9050005316886431
# step:23511,acc:0.9050045723278466
# step:23512,acc:0.90500329618918
# step:23513,acc:0.9050046782630885
# step:23514,acc:0.9050087182104278
# step:23515,acc:0.9050089638005983

# %%
# 模型保存的名称
model_name = "ernie_for_news_classification"

paddle.save(model.state_dict(), "{}.pdparams".format(model_name))
paddle.save(optimizer.state_dict(), "{}.optparams".format(model_name))
tokenizer.save_pretrained('./tokenizer')
# Out:
# [2023-01-13 20:25:17,383] [    INFO] - tokenizer config file saved in ./tokenizer/tokenizer_config.json
# [2023-01-13 20:25:17,387] [    INFO] - Special tokens file saved in ./tokenizer/special_tokens_map.json
# ('./tokenizer/tokenizer_config.json',
#  './tokenizer/special_tokens_map.json',
#  './tokenizer/added_tokens.json')

# %%
valid_dataset = MyDataSet(Valid_path)

valid_set = MapDataset(valid_dataset)
# test_set = MapDataset(test_dataset)

valid_data_loader = create_dataloader(
    valid_set,
    batch_size=batch_size,
    batchify_fn=batchify_fn,
    trans_fn=trans_func
)

# %%
evaluate(model, metric,valid_data_loader)
# Out:
# eval loss:0.13060,acc:0.95774
# acc_list=[0.875, 0.921875, 0.9375, 0.9296875, 0.9375, 0.9427083333333334, 0.9419642857142857, 0.94140625, 0.9444444444444444, 0.946875, 0.9488636363636364, 0.9479166666666666, 0.9495192307692307, 0.9508928571428571, 0.9520833333333333, 0.951171875, 0.9503676470588235, 0.9513888888888888, 0.9506578947368421, 0.9515625, 0.9523809523809523, 0.953125, 0.9497282608695652, 0.9505208333333334, 0.9525, 0.953125, 0.9548611111111112, 0.953125, 0.9536637931034483, 0.9520833333333333, 0.9526209677419355, 0.9541015625, 0.9545454545454546, 0.9558823529411765, 0.9553571428571429, 0.9539930555555556, 0.9552364864864865, 0.9547697368421053, 0.9543269230769231, 0.95546875, 0.9557926829268293, 0.9553571428571429, 0.9556686046511628, 0.9566761363636364, 0.9576388888888889, 0.9578804347826086, 0.9574468085106383, 0.9576822916666666, 0.9559948979591837, 0.956875, 0.9577205882352942, 0.9585336538461539, 0.9587264150943396, 0.9589120370370371, 0.9590909090909091, 0.9598214285714286, 0.9599780701754386, 0.9595
# ave_acc=0.9576342451458822
# total_acc=2394.0856128647083,ave_acc=0.9576342451458834

# %%
# ------------------------------------   保存模型用于预测（推理）
from paddle.static import InputSpec
# 1.切换 eval()模式
model.eval()
# 2. 构造 InputSpec 信息
input_ids = InputSpec([32, 26],'int64')
segment_ids=InputSpec([32,26],'int64')
# 3.调用 paddle.jit.save 接口转为静态图模型
path = "model_for_predict/linear"
paddle.jit.save(
    layer=model,
    path=path,
    input_spec=[input_ids,segment_ids])

# %%
# ------------------------------------   加载模型用于预测
import paddle
path = "model_for_predict/linear"
loaded_model = paddle.jit.load(path)
# loaded_model.eval()
# Out:
# W0113 21:44:23.888254   178 gpu_resources.cc:61] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.2, Runtime API Version: 11.2
# W0113 21:44:23.894660   178 gpu_resources.cc:91] device: 0, cuDNN Version: 8.2.

# %%
batchify_fn02 = lambda samples, fn=Tuple(
    Pad(axis=0, pad_val=tokenizer.pad_token_id),
    Pad(axis=0, pad_val=tokenizer.pad_token_type_id),
    Stack(dtype='int64')
): [data for data in fn(samples)]

# %%
with open(Test_path,'r',encoding='utf-8') as f:
    data=f.readlines()
    data_dict_list=[]
    for line in data:
        message=line.strip('\n')
        text=message
        temp={'text':text}
        data_dict_list.append(temp)

# %%
data_dict_list[:2]
# Out:
# [{'text': '北京君太百货璀璨秋色 满100省353020元'}, {'text': '教育部：小学高年级将开始学习性知识'}]

# %%
class TestDataSet(paddle.io.Dataset):
    def __init__(self,path):
        self.data_dict_list=self.__load_data(path)


    def __load_data(self,path):
        with open(path,'r',encoding='utf-8') as f:
            data=f.readlines()
            data_dict_list=[]
            for line in data:
                message=line.strip('\n')
                text=message
                temp={'text':text}
                data_dict_list.append(temp)
        return data_dict_list

    def __getitem__(self, idx):
        return self.data_dict_list[idx]

    def __len__(self):
        return len(self.data_dict_list)

# %%
# tokenizer作用为将原始输入文本转化成模型model可以接受的输入数据形式。
import paddlenlp
from functools import partial
from paddlenlp.data import Stack,Tuple,Pad
N=0
max_seq_len=64


tokenizer = paddlenlp.transformers.ErnieTokenizer.from_pretrained('ernie-tiny')
# 该函数作用为将数据转换为ernie所需要的输入数据格式

def convert_example02(example, tokenizer, max_seq_length=128):
    global N
    N+=1
    encoded_inputs = tokenizer(text=example['text'], max_seq_len=max_seq_length)
    input_ids = encoded_inputs['input_ids']
    token_type_ids = encoded_inputs['token_type_ids']
    print('{},进入了test:'.format(N))
    return input_ids, token_type_ids


def create_dataloader02(dataset, batch_size=1,
                      batchify_fn=None, trans_fn=None):
    # trans_fn对应前边的covert_example函数，使用该函数处理每个样本为期望的格式
    if trans_fn:
        dataset = dataset.map(trans_fn)
    print('进入了create_dataloader02')

    # 定义并初始化数据读取器
    return paddle.io.DataLoader(dataset, batch_size=batch_size,
                                shuffle=False, collate_fn=batchify_fn,
                                num_workers=1, drop_last=False, return_list=True)


# trans_func = partial(
#     convert_example,
#     tokenizer=tokenizer,
#     max_seq_length=max_seq_len)

trans_func02 = partial(
    convert_example02,
    tokenizer=tokenizer,
    max_seq_length=max_seq_len)

batchify_fn = lambda samples, fn=Tuple(
    Pad(axis=0, pad_val=tokenizer.pad_token_id),
    Pad(axis=0, pad_val=tokenizer.pad_token_type_id),
    Stack(dtype='int64')
): [data for data in fn(samples)]
# Out:
# [2023-01-13 21:48:06,718] [    INFO] - Already cached /home/aistudio/.paddlenlp/models/ernie-tiny/vocab.txt
# [2023-01-13 21:48:06,754] [    INFO] - tokenizer config file saved in /home/aistudio/.paddlenlp/models/ernie-tiny/tokenizer_config.json
# [2023-01-13 21:48:06,757] [    INFO] - Special tokens file saved in /home/aistudio/.paddlenlp/models/ernie-tiny/special_tokens_map.json

# %%
with open(Test_path,'r',encoding='utf-8') as f:
            data=f.readlines()
            data_dict_list=[]
            for line in data:
                message=line.strip('\n')
                text=message
                temp={'text':text}
                data_dict_list.append(temp)

# %%
data_dict_list
# Out:
# [{'text': '北京君太百货璀璨秋色 满100省353020元'},
#  {'text': '教育部：小学高年级将开始学习性知识'},
#  {'text': '专业级单反相机 佳能7D单机售价9280元'},
#  {'text': '星展银行起诉内地客户 银行强硬客户无奈'},
#  {'text': '脱离中国的实际 强压人民币大幅升值只能是梦想'},
#  {'text': '内城土地稀缺 对开发商提出更高要求(组图)'},
#  {'text': '亚欧首脑会议举行第二次全体会议(组图)'},
#  {'text': '荷兰主帅球迷面前表决心耍酷 罗本不在范佩西成一哥'},
#  {'text': '搭配18-105VR镜头 尼康D90带票7109元'},
#  {'text': '百盛购物中心美罗城店 同一专柜花120得200'},
#  {'text': '陈水扁获释后首次出庭控告他人诽谤(图)'},
#  {'text': '为艺术喝彩 索尼推出限量珍藏NWD-W202'},
#  {'text': '新一轮价格战的开端？昂达VX530仅299元'},
#  {'text': '三星数码相框迎圣诞送好礼活动促销中'},
#  {'text': '魔兽33+11魔术克尼克斯 雷霆压爵士捍卫赛区榜首'},
#  {'text': '杭州经济适用房被曝质量问题'},
#  {'text': '欧元区在希腊援助条款上出现分歧'},
#  {'text': '入门级单反相机 尼康D3100促销价4060元'},
#  {'text': '盖特纳：解决希腊问题时间所剩无几'},
#  {'text': '骗子冒充北京干部骗财24万'},
#  {'text': '2010年韩国影展开幕 观众可体验“4D”效果(图)'},
#  {'text': '亨通光电：行业景气下滑 未来仍有看点'},
#  {'text': '美媒：内内下份合同值5000万 留在掘金能打大前锋'},
#  {'text': '刘明康：严格实施二套房政策 防范房产金融风险'},
#  {'text': '莎拉-杰西卡-帕克有意拍摄《欲望都市3》'},
#  {'text': '带伤大郅仍是江苏头号公敌 主帅：防住了他就能赢'},
#  {'text': '全国5.6万名军队转业干部安置完成'},
#  {'text': '法国总理菲永称希望修复对华关系'},
#  {'text': '欧洲三大股市下跌 英国股市跌0.18%'},
#  {'text': '2.8英寸液晶屏 iriver E200仅699'},
#  {'text': '美国3月ISM制造业指数为59.6 前值为56.5 '},
#  {'text': '台股全日跌2.4%'},
#  {'text': '纽约黄金期货收盘上涨1% 期铜大涨7%'},
#  {'text': '将浴缸里的水排尽(图)'},
#  {'text': '精钢打造，金属质感迈德克斯MS-830'},
#  {'text': '支持10倍光变 松下MD10000GK仅售6899'},
#  {'text': '前瞻-苏粤大战NBA外援成变数 郭艾伦对位马布里'},
#  {'text': '芝加哥影评人协会奖提名《社交网战》一家独大'},
#  {'text': '美国6月ISM制造业指数为56.2% 前值为59.7 '},
#  {'text': '美国上周初请失业金人数为55.4万 '},
#  {'text': '老师罚14岁女生做200个下蹲 称让其锻炼身体'},
#  {'text': '棕榈园林：积极稳健的踏上园林综合发展之路'},
#  {'text': '招商银行：贷款稳增 同业资产大幅增加'},
#  {'text': '门是以雕花作为造型(图)'},
#  {'text': '环球雅思张永琪：留学“增值服务”特色(组图)'},
#  {'text': '西班牙新宠克服离家恐惧症 25岁新星至今不敢考驾照'},
#  {'text': '揭密芙蓉姐姐的家(组图)'},
#  {'text': '华锐铸钢：风电竞争激烈 锻件刚刚开始'},
#  {'text': '澳际明日之星：有梦想你就是天才'},
#  {'text': '浙江阳光：业绩略低于预期 节能照明推广加速'},
#  {'text': '英媒评出：15位最具影响力的80后(组图)'},
#  {'text': '现场：魔术轻松破百只用三节 希尔也惹上犯规麻烦'},
#  {'text': '奇才vs热火首发：布莱切因伤缺席 白魔鬼担任替补'},
#  {'text': '时光漫步 三星WB2000镜头下的上海'},
#  {'text': '简洁大方的指导思想(图)'},
#  {'text': '热火防守彪悍双方盛赞 韦德：第一节我就知道要赢'},
#  {'text': '台媒体曝林志杰新季身价 野兽：我想要200万年薪'},
#  {'text': '合生创展涨3% 瑞信升目标价四成至7.43元'},
#  {'text': '高校简介：Middle Tennessee State University'},
#  {'text': '轻巧标头 佳能50mm f1.4USM售2550元'},
#  {'text': '发改委规定正部至科级官员办公室面积'},
#  {'text': '图文-火箭慈善活动 斯科拉和爱妻'},
#  {'text': '买单反不再是奢侈 六款套机周末推荐'},
#  {'text': '吉他英雄《World Tour》将登陆手机平台'},
#  {'text': 'APS-C画幅旗舰级单反 佳能7D单机9480元'},
#  {'text': '新基金销售依然冷飕飕'},
#  {'text': '西部倒数第2下课铃响 阿帅20年成也固执败也固执'},
#  {'text': '经典橱柜 优雅与精致并存(组图)'},
#  {'text': '卫生部要求各地防治手足口病消除恐慌'},
#  {'text': 'PC独占《猎杀潜航5》公布 预告片放出'},
#  {'text': '英国科学家计划打通地壳直接获取地幔物质(图)'},
#  {'text': '品鉴前门最后一片居住区 前门前8月推出百万私产'},
#  {'text': '具备5倍光学变焦 三星PL70仅售1180元'},
#  {'text': '5倍光学变焦镜头 宾得W80仅售1580元'},
#  {'text': '英国渔民展示3米长巨无霸海鳗 '},
#  {'text': '警员在警署内强奸19岁报案女子'},
#  {'text': '高清相机出西施 富士Z71捕捉瞬间之美'},
#  {'text': '希腊气若游丝 财长称不施救将崩盘'},
#  {'text': '《单身男女》古天乐再战情场 大展浪漫攻势(图)'},
#  {'text': '当家花旦实惠多 COWON J3购机还有好礼赠'},
#  {'text': '美元跌破低点 加剧新兴市场货币升值压力'},
#  {'text': '名校展现场报道：德意志学术交流中心(图)'},
#  {'text': '全线Full HD 索尼四款全新单反谍报曝光'},
#  {'text': '最被低估强队并非无解 江苏低调战东莞先得抗感冒'},
#  {'text': '《波斯王子5：遗忘沙漠》砂雕欣赏'},
#  {'text': '《2011：城市漫游》――从城市看刘伟强电影'},
#  {'text': '世界杯巴萨球员最多共13名 切尔西饱受伤病影响只12人'},
#  {'text': '欧洲著名十大牛校：巴黎高师等(组图)'},
#  {'text': '宁波银行：息差继续大幅反弹 增持'},
#  {'text': '瑞芯微将支持Android2.1 图片视频曝光'},
#  {'text': '詹俊足彩火线：巴萨曼联势稳 国米利物浦皇马防平'},
#  {'text': '皇帝现在投篮有绝望感觉 韦德夺冠我们还有6年'},
#  {'text': '图文-[总决赛IV]热火83-86小牛 诺维茨基突破上篮'},
#  {'text': '香川照之为拉贝婉拒南京？ 陆川称毫不知情(图)'},
#  {'text': '一个最值得信赖的避风港(图)'},
#  {'text': '美版犀利哥蹿红网络 NBA和媒体争相聘用(组图)'},
#  {'text': '5名空姐超重被禁飞状告航空公司'},
#  {'text': '花大虫用早期乔丹激励罗斯：没有队友你不会成功'},
#  {'text': '债基唱主角 新基金发行再现高潮'},
#  {'text': '《欧洲空战英雄》体验二战空战史诗感'},
#  {'text': '快讯：印度央行上调回购利率25个基点至8.25%'},
#  {'text': '立讯精密：三季报符合预期'},
#  {'text': '全手动定焦 卡尔蔡司501.4 ZF2爆4649'},
#  {'text': '两市总市值升上22万亿'},
#  {'text': '香江控股：关注大股东注资和再融资进程'},
#  {'text': '坚固大方 奥林巴斯μTOUGH-8000欲破2K'},
#  {'text': '彩虹精化：成熟品牌收购 竞争力强劲'},
#  {'text': '80GB硬盘高清DV机 索尼XR100E送备用电池'},
#  {'text': '《皇家刺青》海报曝光 9月30日全国公映(附图)'},
#  {'text': '驻美领馆参赞：首批留学生的窘迫生活'},
#  {'text': '瑞旗家园200余业主收房'},
#  {'text': '皖维高新：突破围城实现跨越发展'},
#  {'text': '另辟蹊径掘金重组：大股东减持暗藏升机'},
#  {'text': '杨洁篪会见联合国秘书长潘基文'},
#  {'text': '最年轻MVP面临最尴尬数据 罗斯：我必须拿出侵略性'},
#  {'text': '张纪中要拍3D《美猴王》 中国编剧写不好孙悟空'},
#  {'text': '跨界合作 破解房地产品质与效益博弈困局'},
#  {'text': '英国女子打算在珠穆朗玛峰上空跳伞'},
#  {'text': '《贫民》小童星回国 被高高举起似英雄凯旋(图)'},
#  {'text': '政策模糊 二套房贷利率或现竞争性下浮'},
#  {'text': '8G仅299 驰为1080P新品P7nano即将上市'},
#  {'text': '一场失利为热火敲响警钟 真的季后赛这才刚开始！'},
#  {'text': '模拟真实驾驶!《无限试驾2》初步细节'},
#  {'text': '恋人因感情遭家长反对欲跳楼殉情(图)'},
#  {'text': '6款圣诞狠降数码相机盘点：理光GX200'},
#  {'text': '嫦娥二号飞离月球奔向150万公里深空'},
#  {'text': '热火客场取关键胜利 特制红色战靴助詹韦升空(图)'},
#  {'text': '开元控股：产品结构调整 业绩略超预期'},
#  {'text': '华商在工行开通基智定投业务 '},
#  {'text': '纽约黄金期货价格周四收盘小幅下跌'},
#  {'text': '现场：10比2高潮马丁一人制造 基德妙手演空接好戏'},
#  {'text': '28mm广角镜头 佳能IXUS110仅售1899元'},
#  {'text': '美CPI数据为QE2奠基铺路 美元涨势暂歇 '},
#  {'text': '张学友拍戏吃苦头 与汤唯茶餐厅坐足10小时(图)'},
#  {'text': '男子半夜遭劫身中9刀后被好心人搭救(图)'},
#  {'text': '马丁：球队输球自己得高分无意义 没想特意造犯规'},
#  {'text': '2010年澳洲技术移民政策重大调整'},
#  {'text': '选手gych7300换仓苏州固锝 挽回损失'},
#  {'text': '联储降息预期推动油价大涨6.5%'},
#  {'text': '招商银行(600036)：行业龙头二次拉升'},
#  {'text': '中牧股份：狂犬疫苗获批 参股企业上市'},
#  {'text': '研究称古埃及美女王后长鹰钩鼻不美艳(图)'},
#  {'text': '微距镜头新宠 腾龙602仅售3490还送UV镜'},
#  {'text': '中国将同阿拉伯国家加强能源合作机制建设'},
#  {'text': '彩色橱柜 帮你大展厨艺(组图)'},
#  {'text': '三五互联：内延和外延两手抓'},
#  {'text': '人民币对美元汇率升破6.53 再创汇改以来新高'},
#  {'text': '创业板指涨0.10% 个股涨跌互现'},
#  {'text': '超长焦距加高清摄像 尼康P100套装2980元'},
#  {'text': '易建联：今天打马刺全力以赴 黑人范范来看我比赛'},
#  {'text': '金属质感超值售价 三星PL50节前特价'},
#  {'text': '真情菜百 “�福结婚金饰”演绎婚庆新思维'},
#  {'text': '孙红雷回应争议：给自己打20分 是还有进步空间'},
#  {'text': '最悲催卫冕冠军湖人仅第5 07热火亦难敌后乔丹沦陷'},
#  {'text': '美国货车行程逾百万里程表上重归零'},
#  {'text': '证券通盈利和评级综合调整一览表'},
#  {'text': '印度计划再从俄罗斯采购42架苏-30MKI战机(图)'},
#  {'text': '亚鹏和王菲的是别墅区最大A1户型(图)'},
#  {'text': '中信证券：金种子酒业绩符合预期 维持增持评级'},
#  {'text': '日股全日升6点或0.07%'},
#  {'text': '时髦外套：香奈儿演绎中性美'},
#  {'text': '东莞主场轻取吉林保持不败 后场核心爆发砍下27分'},
#  {'text': 'HDMI输出全格式高清 昂达VX575HD曝光'},
#  {'text': '奥斯卡头号种子《贫民富翁》在印度遭抗议(图)'},
#  {'text': '两万元装修的时尚两居室(组图)'},
#  {'text': '传闻中国可能马上加息'},
#  {'text': '佳能IXUS105沈阳热销 多彩不容错过'},
#  {'text': '澳移民政策收紧恐引发“多米诺”效应'},
#  {'text': '格里芬这个夏天很充实 苦练投篮强化防守变全能战士'},
#  {'text': '《阿凡达》全球大卖 续集或探阿尔法星系'},
#  {'text': '教育部透露文理是否分科有望八月敲定'},
#  {'text': '《爱情左灯右行》将上映 林嘉欣与12位男星搭档'},
#  {'text': '时尚家用卡片相机 索尼WX1售价1739元'},
#  {'text': '3D全景扫描小资生活 索尼TX9为您添情趣'},
#  {'text': '湖人指挥15+11+7想夸但不得不骂 硬一回咋那么难'},
#  {'text': '青年刺死女友后自杀未遂被判死缓'},
#  {'text': '美国7月商业库存月率为-1.0% 前值为-1.1% '},
#  {'text': '银监会将与央行联手严查无贸易背景票据贴现'},
#  {'text': '货币战争：人民币亚洲发力'},
#  {'text': '民政部成立社会福利和慈善事业促进司'},
#  {'text': '瑞士央行16日料按兵不动 且不会恢复干预'},
#  {'text': '蔡英文首次提出希望21日与马英九对话'},
#  {'text': '3月05日十六机构荐黑马股'},
#  {'text': '比利时妖星：我们比荷兰更强 奥运会有信心战胜中国'},
#  {'text': '公交车门夹伤老汉引发群殴'},
#  {'text': '体育总局局长因赛艇夺金兴奋险落水'},
#  {'text': '好友称吴淑珍在龙潭购地案中收取2亿新台币'},
#  {'text': '周迅诠释争议人物南子 时间有限考验演技'},
#  {'text': '女售票员拼死抵住车门拦下小偷'},
#  {'text': '欧佩克原油周一跌1.35美元报每桶70.37美元'},
#  {'text': '节日推荐 时尚索尼TX1南宁仅2180元'},
#  {'text': '泸州老窖000568：持续增长任重而道远'},
#  {'text': '老鹰锁定东部季后赛席位 约翰逊伤退至少休战一场'},
#  {'text': '水瓶都是孤寂的天使(图)'},
#  {'text': '42倍光学变焦镜头 松下H48GK仅售2500元'},
#  {'text': '欧洲央行3月利率会议几大猜想'},
#  {'text': '黄奕：我也想有一个肩膀依靠 没考虑过生子问题'},
#  {'text': '辽宁主帅揭秘为何双裁外援 1个能力太差1个没纪律'},
#  {'text': '一电影竟有十几监制 三地导演呼吁重视电影监制'},
#  {'text': '开来资讯每日板块热点透析'},
#  {'text': '29+6小霸王无愧东部首发 堪与勒布朗比肩舍他其谁'},
#  {'text': '高鸿股份：铁公鸡定增反蹊跷涨停 '},
#  {'text': '欧锦赛-科斯蒂奇23分特奥9助攻 塞尔维亚轻取2连胜'},
#  {'text': '火箭40+俱乐部又添新人 马丁更强数据填补休城空白'},
#  {'text': '英国首相布朗预计英央行将进一步降息  '},
#  {'text': '全时音乐陪伴！COWON X7音界新领主'},
#  {'text': '彩民周刊双色球09006期专家组：重号可能再度热出'},
#  {'text': '蓝军铁主力三朝功与过 里皮卡佩罗是否都高估了他？'},
#  {'text': '调查：你关注本届青龙奖什么以及最大冷门是？'},
#  {'text': '银行理财产品火爆态势能否持续'},
#  {'text': '纽曼XD60时尚录音笔 断电犹存“耳”留余音'},
#  {'text': '篮协禁令令DJ仍有漏洞可钻 客队进攻时他放大悲咒'},
#  {'text': '明日最具爆发力六大牛股'},
#  {'text': '公司员工携起爆器登机被截获 办理托运后放行'},
#  {'text': '欧洲市场黄金周四走低'},
#  {'text': 'HD7打压安卓价格 DesireHD惊爆3799元'},
#  {'text': '10月足彩日历周末胜负彩双猜 英德组合周3晚开售'},
#  {'text': '银轮股份002126：汽车散热器行业的龙头'},
#  {'text': '豹子头林冲打头阵《水浒》好汉竞相上银幕(图)'},
#  {'text': '世界十大最古老树木：4800岁地狐尾松问鼎(图)'},
#  {'text': '值班室烧炭取暖引发一氧化碳中毒致1死1伤'},
#  {'text': '山东连胜背后隐患正扩大 本土头号得分手休战一周'},
#  {'text': '华鲁恒升：一体化程度提高稳定业绩'},
#  {'text': '初中生遭同学围殴后开始报复他人(图)'},
#  {'text': '25X光变高清闪存 索尼CX150E降至3960'},
#  {'text': '范德法特射门扭伤脖子 荷兰绞肉机训练赛踢伤两大将'},
#  {'text': '金价半年内可上1300美元'},
#  {'text': '4款尼康相机再降价 降幅最多达400元'},
#  {'text': '15倍光变长焦！高清富士S2000仅1880'},
#  {'text': '曾文鼎已与上海队签订四年合同 本季出场希望渺茫'},
#  {'text': '希尔刺眼数据把火箭扎得好疼 难道他真扶不起来？'},
#  {'text': '梅开二度射失点球逃过法眼 比利亚包揽所有故事'},
#  {'text': '《袁崇焕》看片会 于魁智不避谈欠缺(组图)'},
#  {'text': '刘嘉玲北京验收五千万豪宅(组图)'},
#  {'text': '刘建宏：不在现场也光荣 张斌一直是节目负责人'},
#  {'text': '罗斯驳斥与韦德不和传闻：我连他电话号码都没有!'},
#  {'text': '实惠送到家 佳能500D小套特价4688元'},
#  {'text': '防总针对北方旱情启动抗旱Ⅳ级应急响应'},
#  {'text': '欧锦赛-大加两双纳瓦罗26分 西班牙灭斯队进四强'},
#  {'text': '最适合中国学生申请的十所国外名校'},
#  {'text': '冯小刚感慨《温故》遇贵人 曝与李雪健十年之约'},
#  {'text': '王胜俊：法院须把实现人民新要求作为工作标准'},
#  {'text': '预告：25日视频直播电影《将爱》发布会'},
#  {'text': '3D拍摄小DC性能王 索尼WX5C仅售2280元'},
#  {'text': '香港零售商店七月七日起对塑胶购物袋收费'},
#  {'text': '英国人争端公务员“铁饭碗”(组图)'},
#  {'text': '宫崎骏工作室年底推出新动画《动物农场》(图)'},
#  {'text': '德拉吉获欧洲央行行长正式提名 鹰派立场利好欧元'},
#  {'text': '对话《战国》作曲神思者：创作中我非常脆弱'},
#  {'text': '巴西政府出台进一步措施遏制雷亚尔升值 '},
#  {'text': '上海机场：未来国际航线高增长的最大受益者'},
#  {'text': '第13届釜山电影节开幕 参展影片创历史新高(图)'},
#  {'text': '热销实用“色”无穷 尼康S3000现售1300'},
#  {'text': '荣信股份：关注电网市场开拓进程'},
#  {'text': '广发证券：中期业绩符合预期'},
#  {'text': '冰岛真相报告 曝光经济崩溃元凶'},
#  {'text': '美债头上利剑高悬 投行热议违约后果'},
#  {'text': '欧美经济患上慢性病 意大利接棒希腊成吊尾车'},
#  {'text': '詹姆斯：波什受伤所幸赛程松 祝中国球迷新年快乐'},
#  {'text': '《十月围城》深圳看片会 王学圻甄子丹受好评'},
#  {'text': '教师救溺水少年未成功 死者家属指责其为杀人犯'},
#  {'text': '实力机构周末荐股精选'},
#  {'text': '“会讲故事的童装” DADIDA打造童装第一品牌'},
#  {'text': '数据谈：皮尔斯一战创52年历史 热火难称精英球队'},
#  {'text': '早产女婴患18种疾病被救活'},
#  {'text': '隆多亲口确认戴护具出战第四场：那东西会很难看！'},
#  {'text': '澳洲联储对经济较乐观 澳元反弹触及1.0240'},
#  {'text': '丰田子公司大发汽车将在日本召回逾27万辆汽车'},
#  {'text': '历届获奖者将会师金鸡颁奖礼 夏雨袁泉夫妻同行'},
#  {'text': '《变形金刚塞伯坦之战》增加女机器人'},
#  {'text': '世界杯T台上演制服诱惑 德国教头创立男人着装范本'},
#  {'text': '马英九向救灾殉职飞行员颁褒扬令(图)'},
#  {'text': '陈水扁夫妇新旧情书细节曝光 回忆私奔称不爱钱'},
#  {'text': '货币四角将横盘震荡 人民币升值压力仍在'},
#  {'text': '送原装电池带包 索尼XR150E套装售价4950元'},
#  {'text': '美眉说藏：小本票独树一帜'},
#  {'text': '孟广美无悔爱错郎 自曝前男友仍天天示爱(图)'},
#  {'text': '依然是那么时尚创新(图)'},
#  {'text': '超薄家用卡片相机 尼康S620仅售1870元'},
#  {'text': '四只基金接近清盘线'},
#  {'text': '全明星微博征文明日启动 更多奖品等你来拿！'},
#  {'text': '海鸥卫浴：低谷爬起 奋起直追'},
#  {'text': '美多颗卫星太空密切监视飓风艾琳动向(图)'},
#  {'text': '欧元区1月工业产出环比增1.7% 创20年最高增幅'},
#  {'text': '四劲旅盯上掘金1300万核心 经理他比安东尼先离队 '},
#  {'text': '08销量已超去年：体福彩差距缩小 即开票为增长点'},
#  {'text': '一批券商个股最新评级及推金股'},
#  {'text': '亚太地区主要股市多数上涨'},
#  {'text': '中学生游泳溺水身亡 同伴相约隐瞒实情'},
#  {'text': '孙菲菲再战银幕 《人皇伏羲》演女娲传递爱(图)'},
#  {'text': '申华控股：创投风能汽车三概念'},
#  {'text': '16G闪存高清DV 松下TM200促销6499元'},
#  {'text': '格力电器：内销保持10%左右的增长速度'},
#  {'text': '老鹰一招打中热火七寸 现在知道他有多珍贵了吧！'},
#  {'text': '埃利斯24分勇士轻取骑士 6人上双76人阻止步行者'},
#  {'text': '从精英到草根：成功留学“两步走”'},
#  {'text': '太阳篮板不利欲补强力中锋 凤凰城盯上火箭弃签之人'},
#  {'text': '赵建民接任台当局“陆委会副主委”职务'},
#  {'text': '《麻辣空姐》开机 解密空姐空少浪漫爱情(组图)'},
#  {'text': '《星际2》港版可能采用月卡收费模式'},
#  {'text': '舒斯特尔：德国球风已翻天覆地 巴拉克受伤仍难弥补 '},
#  {'text': '专访《生死朗读》导演：温斯莱特实在很出色'},
#  {'text': '《画壁》新浪官网启动 闫妮掌控情欲法则(组图)'},
#  {'text': '快讯：日本股市午盘上涨1.53%'},
#  {'text': '佳能兔年新岁 60D套机降价促销迎新春!'},
#  {'text': '6月16日美股专家坐堂实录'},
#  {'text': '佛罗里达上演蟒蛇吞食鳄鱼大战(组图)'},
#  {'text': '渣打银行个贷宣传轰炸 月薪3000元可贷20万'},
#  {'text': '《幻想三国志4》预计1月16日上市(图)'},
#  {'text': '480光年外疑发现火山行星：温度达2200度(图)'},
#  {'text': '巴黎CAC40股指28日报收于3693.14点'},
#  {'text': '实录：冯小刚刘震云王中磊做客聊《温故1942》'},
#  {'text': '外国央行增持美国公债'},
#  {'text': '图文-海耶斯中国行访男篮 面露笑容轻松应付投篮'},
#  {'text': '香港女子被卷入车底致盆骨和右大腿被辗裂'},
#  {'text': '阿根廷队长详解失球：是“呜呜祖拉”给韩国人的助攻'},
#  {'text': '奥运焰火脚印设计者自曝曾想出家(图)'},
#  {'text': '蜘蛛人坠下12楼全身骨折奇迹生还'},
#  {'text': '小语种国：中国留意大利学生近四千'},
#  {'text': '《夺魂索》男星法利-格兰杰纽约逝世 享年85岁'},
#  {'text': 'ICOO 4.7英寸屏高清新品M100HD曝光'},
#  {'text': '科学家揭开埃及挣扎尖叫状木乃伊之谜(组图)'},
#  {'text': '苏有朋无缘开幕式 坦言做好工作就是支持奥运'},
#  {'text': '孤狼现身北京八达岭被麻醉捕获'},
#  {'text': '《让子弹飞》主题曲酿全家福 葛优嘉玲确认开嗓'},
#  {'text': '穆迪：地震或令日本面临二次衰退'},
#  {'text': '净赎回连续两季居高 易方达三基金失意投资人'},
#  {'text': '裘德-洛男扮女装反串名模 被指酷似其前妻(图)'},
#  {'text': '商家悄然隐瞒 揪出不靠谱的MP3参数'},
#  {'text': '益佰制药战略清晰 步入快速发展期'},
#  {'text': '奥运男足观战指南：看超男如何带领国奥突出重围'},
#  {'text': '美国11月成屋销售月率为7.4% 前值为10.1%  '},
#  {'text': '美菱电器：业绩增长态势良好 '},
#  {'text': '皇帝满分领衔最佳阵容1队 科比9度入选平现役纪录'},
#  {'text': '俄央行六周内第三次降息以刺激经济增长'},
#  {'text': '我国已成为世界恐龙研究重要一极'},
#  {'text': '司机开车时未照明将睡觉工人碾死'},
#  {'text': '备受消费者青睐 佳能550D带票5283元'},
#  {'text': '9+10+6!达拉斯之魂已到极限 38岁真神拿灵魂拼冠军'},
#  {'text': 'IMF前总裁卡恩重获自由 或参选总统大选'},
#  {'text': '3D希腊神话新作《惊天战神》11月登陆内地(图)'},
#  {'text': 'IEF09电子竞技大赛郑州赛区完美落幕'},
#  {'text': '阿帅：交易后人人挺身而出 全新轮转已经趋于稳定'},
#  {'text': '欧洲三大股市上升 英国股市升1.07% '},
#  {'text': '经典老画在国外也热起来了'},
#  {'text': '重卡销售进入景气上行区域'},
#  {'text': '最后一款复杂结构产品离场 银行理财走低风险路'},
#  {'text': '热火裁掉阿罗约就为签毕比 LBJ早就渴望与他合作'},
#  {'text': '巴西试图利用主权基金遏止雷亚尔涨势'},
#  {'text': '股市井喷 基金排名未见大变'},
#  {'text': '贵族奢侈再次袭来 徕卡S2套机最新疯狂价'},
#  {'text': 'iPhone4骤降 全新美版机狂跌近2000元'},
#  {'text': '刷新纪录：09年留英学生签证再创新高'},
#  {'text': '皇帝阿杜赛后用伟大互赞 KD：这次我尝试了新动作'},
#  {'text': '历史冰点价 手动旗舰佳能G12震撼价3630'},
#  {'text': '水瓶男爱上你的表现揭秘(图)'},
#  {'text': '央行连续三周净投放 7天回购利率创2年多新高 '},
#  {'text': '蔡英文称5月19日决定是否发动罢免马英九'},
#  {'text': '隆多缺阵绿衫军狂胜篮网 小霸王31分16板镇压猛龙'},
#  {'text': '台当局称两岸即将合拍电视剧'},
#  {'text': '女子拒绝让座遭指责 邀情夫将无辜乘客打死'},
#  {'text': '首相萨帕特罗：西班牙也将需要援助'},
#  {'text': '美国8月核心消费者物价指数年率为1.4% '},
#  {'text': '美元再涨 纽约金价跌破1040美元'},
#  {'text': '中国将在2016年前发射空间实验室'},
#  {'text': '强心针仍难激活欧美需求'},
#  {'text': '液态奶第八次抽样检测未检出三聚氰胺'},
#  {'text': 'DC也可“美急？且看富士F85的变身术'},
#  {'text': '中端专业好选择 佳能60D单反套机售9800'},
#  {'text': '专家：海外投资移民巨变下六大新机遇'},
#  {'text': '雷霆vs掘金前瞻V威少需减少得分 掘金罚球太逆天'},
#  {'text': '盘点世界高空观景台：上海世博和谐塔上榜(图)'},
#  {'text': '恩师称皇帝是乔丹魔术师合体他一辈子都是胜利者'},
#  {'text': '美国首次使用激光击落运动中飞机(图)'},
#  {'text': '10月7日国际财经焦点提示'},
#  {'text': '新生珍稀小狐猴将泰迪熊当妈妈(组图)'},
#  {'text': '“yzr100127310”投资组合获利了结两股'},
#  {'text': '今年上半年对冲基金资产创6年最小增幅  '},
#  {'text': '台股全日升114点或1.62%'},
#  {'text': '兼具时下热门功能 英利普YDP612热卖'},
#  {'text': '要低价不要山寨！MP3播放器网购指南'},
#  {'text': '透视国际油价变局 油价飙升背离正常供需'},
#  {'text': '康美药业：四头并进确保较快增长'},
#  {'text': '中国电影爱上日本配乐 国内电影配乐人才稀缺 '},
#  {'text': 'DOTA2表演赛英雄出场及胜率统计'},
#  {'text': '一种揉和了蓝色绿色的奇妙组合(图)'},
#  {'text': '纽约金价高收1.2% 盘中突破940美元'},
#  {'text': '麦蒂5大火箭时刻：羞辱多少巨星 只留22胜在人间'},
#  {'text': '女子患肌肉骨化症身体僵直如棍子(图)'},
#  {'text': '梅根-盖尔要演神奇女侠 碧昂斯欲抢角色(图)'},
#  {'text': '女子衣着太暴露遭丈夫暴打'},
#  {'text': '中国五地首发中医药堂邮票 '},
#  {'text': 'CPL赛事总监sky三年后涅�重生 '},
#  {'text': '赵一苇：哈佛录取生的“传奇经历”(图)'},
#  {'text': '张曼玉秀男友又抱又牵 不敌李宇春场面火爆(图)'},
#  {'text': '汇川技术：强烈推荐 目标价115.85元'},
#  {'text': '法国希望在G20框架内推动征收金融交易税方案 '},
#  {'text': '东北证券：业绩符合预期 份额持续攀升'},
#  {'text': '图文-火箭常规训练 阿帅不忘关心下姚明'},
#  {'text': '美国4月ISM非制造业指数为55.4 前值为55.4 '},
#  {'text': '创新推播放器新品ZEN Style系列'},
#  {'text': '留学莫斯科：一年只需4万元人民币'},
#  {'text': '放贷人条例加快制定 个人可望成为放贷人'},
#  {'text': '图文-火箭常规训练 小布目视何处？'},
#  {'text': '标普下调爱尔兰主权信用评级 '},
#  {'text': '双屏自拍仅2台 三星PL100曝999+送礼'},
#  {'text': '欧元创两周最大涨幅 后市走势依然偏空'},
#  {'text': '格里芬队友考虑来中国打球：我喜欢那的球迷气氛'},
#  {'text': '全国检察机关举报网络和电话统一化'},
#  {'text': '平煤股份：未来受益于高弹性和资源整合'},
#  {'text': '证券通强势个股最新估值'},
#  {'text': '全球竞争力下滑 奥巴马就业市场开刀'},
#  {'text': '热火当家控卫3分命中率联盟第3 三巨头让他放轻松'},
#  {'text': '《风声》票房达1.5亿 口碑支持长线上映(图)'},
#  {'text': '魔鬼训练上海队长腿跑断 刘炜：客场很难打你懂的'},
#  {'text': 'NASA开始准备最后一次哈勃太空维修(图)'},
#  {'text': '台特侦组下周将连续两天传唤吴淑珍'},
#  {'text': '支持4倍光学变焦 奥林巴斯FE4020仅售999元'},
#  {'text': '正在视频直播太阳vs火箭 小布洛瑞谁是休城第一控'},
#  {'text': '儿子无钱葬母含泪将遗体装袋沉河'},
#  {'text': '配24-85mm镜头 尼康新品D7000套机降'},
#  {'text': '新黄浦：期货业务处于高增长期'},
#  {'text': '15X光变高清摄像 富士S2000送卡1699元'},
#  {'text': '篮网盯上骑士第四签位 萨沙看到希望急抱老板大腿'},
#  {'text': '华宇时尚购物中心 时尚零距离百余品牌齐亮相'},
#  {'text': '分析师：美元反弹难以变成趋势性反转行情 '},
#  {'text': '每日晚间实力机构点评热门个股精选'},
#  {'text': '便携的1080P 爱国者AHD-S1闪存DV售1890'},
#  {'text': '热火内线支柱两战判若两人 他若昏头詹韦还能依靠谁'},
#  {'text': 'Pimco：全球金融市场为何血流成河'},
#  {'text': '配18-105mm镜头 尼康D90套机售价7100'},
#  {'text': '天宫一号可能推迟至本月下旬发射'},
#  {'text': '21岁女子嫁给6旬富翁获赠豪宅轿车'},
#  {'text': '男子为逃过路费冒充记者(图)'},
#  {'text': '纽约黄金期货收盘上涨0.3% 报1622.30美元'},
#  {'text': '凯迪电力：业绩增长超预期 转型生物质发电'},
#  {'text': '胜负彩08100期彩果：拉齐奥主场取胜 销量2000万'},
#  {'text': '油价受美元走低推动突破72美元'},
#  {'text': '刘韬：吴泓先生安息 一路走好'},
#  {'text': '图文-[常规赛]凯尔特人104-102奇才 篮下死磕'},
#  {'text': '实用旋转屏 搭18-200mm镜佳能60D仅9799'},
#  {'text': '股市暴跌催热金市 银行争推保证金炒金业务'},
#  {'text': '山猫狂人七号秀登陆再受阻 旧合同在身FIBA拒放人'},
#  {'text': '图文-奇才举行媒体见面会 改头换面的大将军'},
#  {'text': '日本财相将于G20峰会敦促欧洲大规模支持银行业'},
#  {'text': '《子弹》首映笑声掌声全收 周润发答谢姜文(图)'},
#  {'text': '今日数据趣谈：勒夫赢数据输比赛 篮网成加时专家'},
#  {'text': '热火vs火箭首发：三巨头来势汹汹 蝙蝠侠对位皇帝'},
#  {'text': '华光股份：业务结构不如预期 但订单欣欣向荣'},
#  {'text': '是电话还是电子书毕升500T活动热销中'},
#  {'text': '国际投行坐庄零和游戏 银行对赌通吃投资者'},
#  {'text': '日经指数低开重挫逼近8000点'},
#  {'text': '汤姆-汉克斯暗示《玩具总动员》将拍摄第四部 '},
#  {'text': '中端入门级相机 宾得K7单机现价6199元'},
#  {'text': '揭秘电影版《武林外传》 佟掌柜成钉子户'},
#  {'text': '熊市基金经理怕见持有人'},
#  {'text': '车祸受害人赔偿执行难 法官资助事主七年'},
#  {'text': '警惕网银五大陷阱 冒名网站往往一字之差'},
#  {'text': '《生化危机4》热拍 米拉-乔沃维奇网上曝剧情'},
#  {'text': '兴业叫板浦发信用卡 贷款市场暗战'},
#  {'text': '胜利股份：明年还看生物产业发展'},
#  {'text': '科学家捕捉到两颗恒星合二为一精彩瞬间(图)'},
#  {'text': '5倍光学变焦镜头 松下FX580最新价1980元'},
#  {'text': '陈水扁用法国大革命的巴士底监狱譬喻自己入狱'},
#  {'text': '湖人将帅不在意登顶西部榜首 全能王：只要总冠军'},
#  {'text': '牛津剑桥模拟面试题雷倒山东考生'},
#  {'text': '亨利进谏要求与萨科奇面谈 足协：要揪出元凶制裁'},
#  {'text': '温家宝：任何国家不能对人民币升值或贬值施压'},
#  {'text': '受澳校倒闭影响中国留学生安置获新进展'},
#  {'text': '中国和哥斯达黎加启动自由贸易区谈判'},
#  {'text': '总决赛那些事(5)：詹韦卧膝长谈 牛仔永不言败'},
#  {'text': '投不进球防守被詹韦爆 公牛玉面射手坦言很受打击'},
#  {'text': '超酷的变形金刚沙发(组图)'},
#  {'text': '研究显示大规模岩浆喷发或导致生命大灭绝'},
#  {'text': '火箭选秀夜修修补补只为一个空缺 真正交易远未结束'},
#  {'text': '超龄也门助阿联酋入世少赛 国少冤案揭示双重标准'},
#  {'text': '湖人首战竟死于洛城人之手 诺天王：我最爱就是他'},
#  {'text': '长安福特举行“2008城市英雄时尚盛典”(图)'},
#  {'text': '月最佳教练马刺老帅夺最佳战绩 绿军教头称霸东部'},
#  {'text': '10X光变长焦 富士F85特价促销仅1580元'},
#  {'text': '[彩民周刊]何明09002期双色球：谨防一区开出连号'},
#  {'text': '英国12月CPI同比上升2.9% 高于预期'},
#  {'text': '一批券商个股最新评级及推荐金股'},
#  {'text': '经济前景不明 澳央行维持利率不变'},
#  {'text': '公务员拖欠前妻9万元拒绝还款被拘'},
#  {'text': '3背光学变焦镜头 佳能IXUS100仅售1698元'},
#  {'text': '《肩上蝶》7月8日公映 魔幻爱情进军暑期档'},
#  {'text': '图文：ELS美国教育中心中国区总裁观看比赛'},
#  {'text': '长阳半岛贯彻标准化设计'},
#  {'text': '夫妻婚床布满水银 一家三口汞中毒(图)'},
#  {'text': '趣味数据：波什尴尬19年未有 杰弗森神勇堪比马龙'},
#  {'text': '新品鉴：给你的鞋子戴套 一双变十双'},
#  {'text': '日剧《暗金丑岛君》拍电影版 山田孝之继续主演'},
#  {'text': '杨洁篪与欧盟轮值主席国捷克外长通电话'},
#  {'text': '啊哈！小霸王其乐无穷啊 MVP表现他已早忘记纳什'},
#  {'text': '辽宁彩民大复式擒获965万 双色球亿元加奖仅余9期'},
#  {'text': '环球科学：聪明药惹质疑(组图)'},
#  {'text': '哥白尼遗骨500年后在波兰重新下葬(图)'},
#  {'text': '西川和久佳能7D人像样张合集'},
#  {'text': '美国4月PCE物价指数月率为0.1% 前值为0.0%'},
#  {'text': '3届MVP遭主场球迷嘘声 效力十年到底谁伤了谁的心'},
#  {'text': '新疆众和：09年年报点评'},
#  {'text': '出示爱国者相机,观看公益摄影展'},
#  {'text': '广角卡片机 索尼T99C售1570还送4G卡'},
#  {'text': '具备1200万像素 松下FX580仅售2100元'},
#  {'text': '11月5日晚间实力机构荐股精选'},
#  {'text': '周穗安：瑞士是西班牙的试金石 更看好南非胜乌拉圭'},
#  {'text': '隔断处的花艺屏风(图)'},
#  {'text': '海富通稳健添利下周一起发行'},
#  {'text': '英国富翁涉嫌枪杀妻女潜逃欧洲'},
#  {'text': '美国4月房屋价格指数月率为0.8% 前值为0.3%  '},
#  {'text': '量子高科：十年磨一剑 专注健康事业'},
#  {'text': '中文系大二学生花40余万元拍电影'},
#  {'text': '证券通盈利和评级综合调整一览表'},
#  {'text': '科比半场23+8+2闪耀麦迪逊 布朗两次扣篮全场惊呼'},
#  {'text': '房子有了让人眷恋的风景(图)'},
#  {'text': '2011搞笑诺贝尔奖公布：甲虫会和酒瓶交配'},
#  {'text': '身价的含量 威宝移动硬盘PK黄金组装盘'},
#  {'text': '中国大型油气田及煤层气开发重大专项启动'},
#  {'text': '温网第1金童玉女秀恩爱 莎娃为萨沙擦额头汗水(图)'},
#  {'text': '私人开发无人岛调查：没有一亿不用做岛主梦'},
#  {'text': '在港澳工作大陆人士可赴台自由行'},
#  {'text': '憋了两场的郁闷今天发泄 这一战中国KG终赢回最严'},
#  {'text': '花鸟图案的壁纸搭配格纹桌布(图)'},
#  {'text': '马钢股份：等待动车轮加速'},
#  {'text': '组图：第47届百想大赏 汤唯亮相红毯彩裙飘逸'},
#  {'text': '远洋天著解密 距CBD最近的东五环别墅价值几何'},
#  {'text': '勿忘老用户 汉王电纸书N518功能大升级'},
#  {'text': '诈骗分子通过电话骗走市民220万元'},
#  {'text': '澳驻华使馆：政府公布多项国际教育新规'},
#  {'text': '潘震宇做客乐居揭秘东方太阳城热销原因(组图)'},
#  {'text': '《谍影重重》有望拍摄前传 马特-达蒙不再主演'},
#  {'text': '《建党伟业》在京试映 毛泽东感情戏受认可(图)'},
#  {'text': '奥巴马访华：美国留学将出现爆发式增长'},
#  {'text': '英国开发读心软件解读人类思维 成功率近五成'},
#  {'text': '孩子姓氏归属权拆散恩爱小夫妻'},
#  {'text': '五部委：全程监督检查新增千亿投资落实情况'},
#  {'text': '联盟杯积分榜：米兰胜仍未登顶 死亡之组谁可逃生'},
#  {'text': '人怕出名猪怕壮 盘点遭敲诈的好莱坞明星(组图)'},
#  {'text': '周杰伦筹拍《秘密2》 女主角“换血”(图)'},
#  {'text': '摄影师抓拍到松鼠手举椰子壳吃椰肉照片(图)'},
#  {'text': '卫生部调查天津蓟县5名婴儿感染致死事件(图)'},
#  {'text': '大叔巫刚恋上小萝莉 《绑架》导演延续同性元素'},
#  {'text': '神火股份：煤炭产量翻番 电解铝走向盈利'},
#  {'text': '文隽：香港电影90%的影响都来自李小龙'},
#  {'text': '谢霆锋和容祖儿去首都体育馆观看中国女排比赛'},
#  {'text': '《追影》横店热拍 吴镇宇钦点谢娜演“镇花”'},
#  {'text': '1200万像素家用！索尼W210标配1350'},
#  {'text': '中年夫妻相互指责对方不忠当街打成一团'},
#  {'text': '南方基金：降息意味着从紧货币政策结束'},
#  {'text': '组图：大会评委雨中红毯亮相 张静初恬静秀美背'},
#  {'text': '大学生情侣租房内煤气中毒身亡 房东为避责焚尸'},
#  {'text': '让你在快乐和安静的世界里遨游(图)'},
#  {'text': '专业级广角相机 佳能S90带票套装仅售3500'},
#  {'text': 'IMF：欧盟需对巴塞尔协议执行法案作修订'},
#  {'text': 'ESPN：火箭不卖钻石就要亏本 阿根廷人成清洗对象'},
#  {'text': '纽约油价周一涨至每桶40美元以上'},
#  {'text': '4G容量MP3仅售199元 昂达VX363到货广州'},
#  {'text': '欧美经济前景迷离 美元趋弱非美短暂反弹'},
#  {'text': '《画壁》广州首映 邓超被女学生问第三者问题'},
#  {'text': '拼死拼活就是不降 细数七款价格坚挺相机'},
#  {'text': '组图：杨紫琼亮相《昂山素季》釜山发布会'},
#  {'text': '“风中的承诺”持股维科精华 浮盈超30%'},
#  {'text': '青岛啤酒：市场份额指标将提上考核议程'},
#  {'text': '武圣携好友被捕 两人联手殴打男子或惹牢狱之灾？'},
#  {'text': '名师教你塑造个性家居风格(组图)'},
#  {'text': '10岁女孩不满父母减少零花钱离家出走卖花'},
#  {'text': '陈水扁再次申请停止羁押遭法院驳回'},
#  {'text': '抢个篮板差点膝盖报销 以为要退役麦蒂当场泪纵横'},
#  {'text': '吴伯雄7月将出席两岸经贸文化论坛'},
#  {'text': '证券通每日板块热点透析'},
#  {'text': '高考生持刀抢劫因抗震有功被免诉'},
#  {'text': '可怕惯性压垮钢制战车 胜负怎能让他末节一人担？'},
#  {'text': '“谋女儿”大揭秘 借光张艺谋曾得李安推荐(图)'},
#  {'text': '英国森林深处惊现巨头雕塑(图)'},
#  {'text': '最高法要求为经济平稳较快发展提供司法保障'},
#  {'text': '让音乐来说话 ipod shuffle3仅售558'},
#  {'text': '30G带光学防抖 松下H288套装仅3450元'},
#  {'text': '红圈经典头 佳能24-105mmF4促销6800元'},
#  {'text': '5.0英寸高清显示屏 酷比魔方H600HD仅499元'},
#  {'text': '图文-火箭队常规训练 巴丁格向小布取经'},
#  {'text': '全国已有11.3亿人参加基本医保'},
#  {'text': '超强六防设计 奥林巴斯μTough6010到'},
#  {'text': '南极巨型冰架崩塌 面积与纽约相当(组图)'},
#  {'text': '图文-[总决赛IV]热火vs小牛 詹姆斯运球强突'},
#  {'text': '埃夫隆与史泰龙争烂片影帝 Rain新片获四项提名'},
#  {'text': '客车自燃烧成空架子 20余名乘客逃生(图)'},
#  {'text': '阿联一扣二后还有快攻怒扣 三大步启动他飞了好久'},
#  {'text': '赴美留学签证申请3月1日起改网上递交'},
#  {'text': '地下非法彩票刊物案件告破 印发六合彩码报达两年'},
#  {'text': '观察：新富海外移民显示出的“忧患”'},
#  {'text': '全智贤因拍戏爱上运动 称拍打戏苦不堪言(图)'},
#  {'text': '男子刺死女学生后送医院谎称见义勇为'},
#  {'text': '南方队也有新星正在升起 何忠勉道出东莞提升原因'},
#  {'text': '暑期火爆热销中 佳能A490您最佳的选择'},
#  {'text': '英格兰队面临背水一战 卡佩罗先紧急整风再变阵'},
#  {'text': '天生无四肢青年已在12国演讲1600场'},
#  {'text': '西方国家让人匪夷所思的四大禁忌(组图)'},
#  {'text': '男子为求暗恋女生欢心重伤舍友被判14年'},
#  {'text': '填写官方申请表格 有机会获得DOTA2测试邀请'},
#  {'text': '口述：大龄剩女的穿着苦恼'},
#  {'text': '中国支付清算协会成立 第三方支付牌照发放爽约'},
#  {'text': '外交部发言人就印尼酒店爆炸案答问'},
#  {'text': '相机摇身变投影 尼康S1000pj特价售1800'},
#  {'text': '下周重要经济事件提示(11月9日-11月15日)'},
#  {'text': '小伙因经济拮据发帖转让女友'},
#  {'text': '高清MP4送乐扣水杯 爱国者PM5966仅619'},
#  {'text': '开来资讯天天涨幅榜背景大揭秘 '},
#  {'text': '搭配QA：破洞牛仔裤咋搭最时髦'},
#  {'text': '商务部：支持流通企业做大降低成本扩大消费'},
#  {'text': '专访《第四号》男主角亚历克斯：我不追名逐利'},
#  {'text': '新浪正在视频直播热火vs老鹰 鹰王放水闪电侠？'},
#  {'text': '辨别真伪：学校越“野鸡”名头越吓人'},
#  {'text': '舒淇演技遭质疑当场曝粗口 自觉表演很内在(图)'},
#  {'text': '4X光变广角机 索尼W310破千还送2G卡'},
#  {'text': '长焦DC巅峰之作 富士HS11报价3380元'},
#  {'text': '陈水扁律师公布侦讯录影带指控检方教唆伪证'},
#  {'text': '林青霞复出王家卫随时量身打造角色(图)'},
#  {'text': '中国最强神虫聚首 F91登顶冠军宝座'},
#  {'text': '江苏周日主场搬往奥体 高层解释突然“试水”原因'},
#  {'text': '欧洲进入冰川时代仅用6个月速度为预计20倍'},
#  {'text': '美科学家坚信发现外星生命只是时间问题'},
#  {'text': '易宪容：银行反价纠纷不可避免'},
#  {'text': '格林讽刺火箭防守 巴蒂尔：我们的表现已经是进步'},
#  {'text': '美元能否厚积薄发 焦点转向本周关键数据'},
#  {'text': '捷波朗亚太区发布降噪蓝牙耳麦Jabra GO660'},
#  {'text': '时尚超薄卡片相机 佳能IXUS300仅售2200元'},
#  {'text': '男子当街连砸20多辆汽车车窗玻璃'},
#  {'text': '阿帅：赛程让训练得不到保证 防守端我们没尽全力'},
#  {'text': '《假戏真作》影射名导 彭浩翔30分钟搞定黄立行'},
#  {'text': '澳洋顺昌：产能扩张 多元化经营引领增长'},
#  {'text': '《连线》杂志：人类百米跑速度远未接近极限'},
#  {'text': 'NBA编年史之1986-87红衣主教失策 绿军入黑暗期'},
#  {'text': '康强电子：封装材料龙头 蓄势待发'},
#  {'text': '多重大礼相送 4GB三星YP-R0现售659元'},
#  {'text': '2008-2024：冥王星魔羯座的大时代(图)'},
#  {'text': '英国对语言学校“网开一面” 签证时间放宽'},
#  {'text': '《非诚勿扰》北京庆功 冯小刚进3亿俱乐部(图)'},
#  {'text': '成飞集成：航空数控加工 汽车模具业务增长明确'},
#  {'text': '人均债务721万日元 日本面临债务危机总爆发'},
#  {'text': '调查：美国5月个人消费支出或微幅上升'},
#  {'text': '澳洋顺昌：下游行业景气恢复 小额贷款收益增加'},
#  {'text': '严宽视大学生为偶像 与刘烨同台拼人气(组图)'},
#  {'text': '三部委要求中小学严格控制暑期作业量'},
#  {'text': '媒体指楼市存三团迷雾 成房价上涨隐形翅膀'},
#  {'text': 'ECL战火点燃七月 S2总决赛决战郑州'},
#  {'text': '谁与争锋 8G苹果iPod touch4大泻报1800'},
#  {'text': '新债基全是红苗 弱市中优势明显'},
#  {'text': '日股全日升51点或0.57%'},
#  {'text': '日股全日下跌93.4点或1.07%'},
#  {'text': '10大最受喜爱球员：坏小子变慈世平 魔兽乃沙克2.0'},
#  {'text': '全触摸控制 苹果iPod nano 6报价1200元'},
#  {'text': '新研究发现恐龙暴脾气或与虱子骚扰有关'},
#  {'text': '传递摄影的乐趣 圆角佳能IXUS110IS热售'},
#  {'text': '“白领地摊族”的新乐活方式(图)'},
#  {'text': '火卫一数百万年后可能撞上火星(图)'},
#  {'text': '1210W像智能对焦 索尼W310促销价1089元'},
#  {'text': '简单生活特别企划：瓶里盛满大海一样的简单爱'},
#  {'text': 'QE2的终结对美元意味着什么'},
#  {'text': '东华能源：再生资源第一股 新能源概念突出'},
#  {'text': '美国6月里奇蒙德联储制造业指数为23 '},
#  {'text': '两院院士评出2009国内外十大科技进展'},
#  {'text': '天源迪科：BSS系统是业务突破口'},
#  {'text': '中方在苏丹被绑架人员仍有2人失踪'},
#  {'text': '纽约油价跌收2.8% 报51.05美元'},
#  {'text': '时代周刊2008十大医学突破揭晓(组图)'},
#  {'text': '虎年你最红! 喜庆红色系IT产品推荐-相机篇'},
#  {'text': '谢霆锋哭戏酝酿20天 当了爸爸更懂照顾小孩(图)'},
#  {'text': '1220万像时尚卡片 三星st45仅千元出头'},
#  {'text': '英国研发出有助治疗腭裂新材料'},
#  {'text': '全画幅重量级单反！尼康D700售14500元'},
#  {'text': '渣打银行调查显示四成小企业靠民间借贷度日'},
#  {'text': '房地产泡沫 有还是没有'},
#  {'text': '2010年四季度机构龙虎榜全景'},
#  {'text': '《秋瑾》片花黄奕挥鞭抗敌 郑嘉颖全靠妻子保护'},
#  {'text': '詹俊足彩推荐：英超又见“和风”吹 博胆首选曼联'},
#  {'text': '银行疯狂收费让人吓一跳：打印一张纸需要40元'},
#  {'text': '鳄鱼邓迪保罗-霍根涉嫌逃税禁止离澳(图)'},
#  {'text': '送原装备用电池 索尼XR550套装10480元'},
#  {'text': '《额吉》母亲节公映 民族史诗抒写深情传奇'},
#  {'text': '4款造型花洒 沐浴多功能体验(组图)'},
#  {'text': '《变3》记者会梅根“抢戏” 赤裸植入广告被批'},
#  {'text': '美国上周EIA蒸馏油库存变化为+120万桶'},
#  {'text': '美联储暗示经济复苏 日元兑欧元创三周最高跌幅'},
#  {'text': '图文-热火小牛备战总决赛 老基德踏入训练馆'},
#  {'text': '爱尔兰借贷成本飙升 欧盟做好援救准备'},
#  {'text': '小法：能为西班牙踢球甘当替补 梅西已是阿根廷一哥'},
#  {'text': '每日之星：勒布朗科比何不同 皇帝两月命中率近六成'},
#  {'text': '陕国投A：未来提升空间大 逢低关注'},
#  {'text': '《失恋33天》做客快乐大本营 文章被赞绝种好男'},
#  {'text': '金发碧眼看中国：雄伟壮丽的长城(组图)'},
#  {'text': '解读留学各国艺术类院校的招生规则'},
#  {'text': '图文-火箭常规训练 伤不好，洛瑞很苦恼'},
#  {'text': '专家：加索尔做到5点可重生 找科比沟通帮安猪防守'},
#  {'text': '日本核泄漏危机 金融市场大动荡'},
#  {'text': '陈水扁妻子吴淑珍坦承教唆子女作伪证'},
#  {'text': '男工帮女同事换光管被误为情敌遭砍手'},
#  {'text': '大提琴女孩与《甜蜜乐章》约定曲试听'},
#  {'text': '男子强奸幼女后潜逃 贩毒时被抓'},
#  {'text': '中方教练抛弃杜伊嫡系球员 日本专家：中国足球完了'},
#  {'text': '十款最具发展前景机器人智能社交机器人会互动'},
#  {'text': '奇才vs开拓者首发：阿联继续先发 沃尔挑战老米勒'},
#  {'text': '生活中的趣味数学：同一天生日概率有多大'},
#  {'text': '每月跌400元 猴票领跌邮市呼唤交易新机制'},
#  {'text': '55分之夜马布里为何会疯狂 最爱之人正在天上看他'},
#  {'text': '职工向女同事发黄色图片引发75万经济损失案'},
#  {'text': '国资委：央企须建安全生产组织机构'},
#  {'text': '亨通光电：全年业绩将低于预期 关注明后年增长'},
#  {'text': '《国家代表》连续4周蝉联韩国票房冠军(图)'},
#  {'text': '独特的装饰方式(图)'},
#  {'text': '哈利-波特要玩速老术 收官片出动四百群众演员'},
#  {'text': '证券通盈利和评级综合调整一览表'},
#  {'text': '宫本制作所将发售徕卡多款NEX用转接环'},
#  {'text': 'MO&Co. De Paris 冬季装备 强势姿态'},
#  {'text': '米卢VS奎罗斯：世界杯是梦想成真 C罗能改变胜负'},
#  {'text': '罗本抵达约堡与荷兰队汇合 主帅坚持首战雪藏爱将'},
#  {'text': '商业地产1号基金：工商联中信证券锁定温州资本'},
#  {'text': '布拉德-皮特密会安妮斯顿 重戴前妻定情项链'},
#  {'text': '圣农发展：鸡肉量价齐升 全年业绩翻番'},
#  {'text': '拥有1211万有效像素 松下GF1带票仅售4850元'},
#  {'text': '工行状告三名信用卡负翁 信用记录列为禁入'},
#  {'text': '超热入门新单反 尼康D3000套机促销中'},
#  {'text': '时尚高性价比卡片DC 佳能IXUS105仅售1450元'},
#  {'text': '《狄仁杰》观影调查揭晓 九成观众对电影满意'},
#  {'text': '老汉在地下室私藏树脂被炸飞(图)'},
#  {'text': '揭黑记者被控三周内犯三项罪 疑遭打击报复'},
#  {'text': '一定要给床上增添几种布艺床品(图)'},
#  {'text': '开启数码影像次时代 理光岁末发布GXR'},
#  {'text': '“岁月流沙，变幻与永恒”的经典概念'},
#  {'text': '以蓝色为中心 让人感觉舒畅(图)'},
#  {'text': '5�1280P蓝光ICOO E900P 8GB 499元'},
#  {'text': '东西之间：给老外送礼的“潜规则”(图)'},
#  {'text': '欧洲银行压力测试有点儿不靠谱'},
#  {'text': '意大利戴黑纱悼念传奇英雄 如此表现怎能告慰英灵？'},
#  {'text': '全球评级市场几乎被完全垄断 谁来给穆迪评级'},
#  {'text': '双头套机最新低价 松下GF1送包7500元'},
#  {'text': '兰多夫挺工会宁可赛季取消 自称要追随小加赴海外'},
#  {'text': '瑞典将向非欧盟国家留学生提高奖学金额'},
#  {'text': '辰州矿业：金锑钨三大产品价格均大幅上涨'},
#  {'text': '关小刀火线解盘：霍芬海姆取连胜 维拉主场奏凯歌'},
#  {'text': '火箭客场失利命悬一线 黄蜂苦战过关锁定季后门票'},
#  {'text': '伤病编年史：8年两度骨折5次手术 左脚是姚明噩梦'},
#  {'text': '广东野兽还没达到期望值 他不缺天赋只是缺少血性'},
#  {'text': '北京回迁户选号逾千人排队 现场开门时挤倒数人'},
#  {'text': '在美华人摆脱单身秘诀：约会要直截了当'},
#  {'text': '12星座之住宅风水 解密星座与住宅(组图)'},
#  {'text': '女大学生埋怨男友不给暖脚拨110报警'},
#  {'text': '太极股份002368：三热点给力公司转型'},
#  {'text': '丰原生化：燃料乙醇价大涨 产业整合犹存'},
#  {'text': '福耀玻璃：连续7日上涨 股价创今年反弹新高'},
#  {'text': '科学家首次目睹超大质量黑洞吞噬高温气体(图)'},
#  {'text': '太委屈 四大行逆势招聘惹争议'},
#  {'text': '知情人士称银行税不会纳入第二轮希腊援助计划'},
#  {'text': '太空之眼：八具最伟大空间望远镜(组图)'},
#  {'text': '人大常委会第9次会议首次审议海岛保护法等'},
#  {'text': '现场-德罗西后场传球被断 斯洛伐克死角破门1-0领先'},
#  {'text': '广发证券：各业务竞争力强 融资推动增长'},
#  {'text': '卫生部：今年将推广免费婚检和婚育健康咨询'},
#  {'text': '新西兰央行27日预计按兵不动'},
#  {'text': '成龙：卡梅隆牛，可他是我的影迷(图)'},
#  {'text': '纽约油价跌破80美元关 三连阴重挫10.5%'},
#  {'text': '死扛2245点等待明确信号 基金仍不愿意做多'},
#  {'text': '爱尔眼科：全国布局的协同效应将显现'},
#  {'text': '设计师很费了一番气力(图)'},
#  {'text': 'ICOO高清Widget触摸黑色版E500P上市热卖'},
#  {'text': '海协会副会长访台被绿营支持者推倒在地(组图)'},
#  {'text': '西川和久宾得K7人像样张合集'},
#  {'text': '欧洲央行重新考虑货币退出政策时间表'},
#  {'text': '古井贡酒：再造一个古井指日可待'},
#  {'text': '咨询站：GRE成绩不够申请名校机会渺茫'},
#  {'text': '8%新生儿父母为非法移民 美落地国籍或废除'},
#  {'text': '抢匪受伤后报警谎称被打劫'},
#  {'text': '发布会“明谢”创意来自姚明 发言稿经四次修改成型'},
#  {'text': '盘点美华人家暴：谁说男人不是受害者(图)'},
#  {'text': '业主拖欠237万管理费与物业公司打官司7年'},
#  {'text': '林志玲《决战刹马镇》饰演老板娘拒说娃娃音'},
#  {'text': '厨房位于西方 能带来财运(图)'},
#  {'text': '吸血鬼征服银幕 《嗜血破晓》公布新款海报(图)'},
#  {'text': '震撼：考上美国名校一年竟花了60万(图)'},
#  {'text': '犹如顺水而下的金砂 就买错杀股'},
#  {'text': '胜负彩08072期差异指数火线：临场升半球勒沃完胜'},
#  {'text': '组图：李孝利华丽街头风 加点运动更性感'},
#  {'text': '味觉诱惑：不可错过的阿根廷美食(组图) '},
#  {'text': '调查-您如何看待火箭新帅 大姚是否会受到他影响'},
#  {'text': '原道G85 TOUCH VIVA半价试用招募中'},
#  {'text': '完美蜕变的开始？佳能60D套机火热促销'},
#  {'text': '周口店遗址新馆10月开建预计明年完工'},
#  {'text': '曾志伟深圳筹款建校 证实尹志强流鼻血入院'},
#  {'text': '新品鉴：2010冬季最犀利单品 逗趣保暖胡须帽'},
#  {'text': '《欧洲空战英雄》预览视频'},
#  {'text': '猕猴遭雷劈截肢两次 获名猴巨强(图)'},
#  {'text': '延续D90辉煌 中端单反尼康D7000首发评测'},
#  {'text': '一种浪漫而精致的气质(图)'},
#  {'text': '宁静自曝曾放弃绿卡：我很顽固！'},
#  {'text': '欧洲留学大探营：法德荷强势专业推荐'},
#  {'text': '宝哥五要素：过往交锋沙尔克全胜 阿森纳遭遇克星'},
#  {'text': '住建部今年严查保障房质量 开展监督执法检查'},
#  {'text': '日本央行再度注资3万亿日元 总额达18万亿'},
#  {'text': '欧洲三大股市上升 英国股市升0.69%'},
#  {'text': '《阿里郎》一种关注单获元奖 金基德现场高歌'},
#  {'text': '中国医药：受益于达菲收储及经销'},
#  {'text': '开发商跟物业公司究竟有没有关系'},
#  {'text': '士兰微：筹备多芯片高压功率模块 买入'},
#  {'text': '专业级手动广角相机 佳能S90仅售2980元'},
#  {'text': '日媒金狼24岁第一射真爽 德新社这是开赛来最大冷门'},
#  {'text': '疱丁解牛：山东黄金 金价上涨诱发反弹'},
#  {'text': '六色炫彩美颜机 轻薄卡西欧Z90送好礼'},
#  {'text': '澳大利亚将对迷途幼鲸实施安乐死(图)'},
#  {'text': '潘石屹无缘前门改造项目 17.7亿收购商业物业'},
#  {'text': '搞怪手绘 营造幽默家居气氛(组图)'},
#  {'text': '国青球员中超生存报告 再揭足坛内部不团结之本质'},
#  {'text': '峨眉山A：有待进内外因驱动下成长提速期'},
#  {'text': '720P平民超值相机！富士jv155仅999元'},
#  {'text': '《家有喜事》爆笑剧照：黄飞鸿大战李铁梅(图)'},
#  {'text': '美研制僵尸昆虫飞行器电极植入大脑操控(图)'},
#  {'text': '将一整块窗帘布裁剪成两半(图)'},
#  {'text': '400余人齐聚公司讨工资和材料费'},
#  {'text': '小店店主闯入市容大队暴打城管队员及警察'},
#  {'text': '阿帅对手仨大个子真要命 巴丁格我们尽力战斗了'},
#  {'text': '纽约原油期货周五收盘下跌0.9%'},
#  {'text': '雅居乐地产全年业绩增160%'},
#  {'text': '高品质诱惑机型 松下GF1套机仅售3K8'},
#  {'text': '海外视角：美国饭桌上培养独立能力'},
#  {'text': '好莱坞影片垄断暑期档 5.43亿人次14年观众最少'},
#  {'text': '新研究称埃及狮身人面像最初有狮头(组图)'},
#  {'text': '冯小刚首次透露：新片无法回避汶川大地震(图)'},
#  {'text': '卫星图片显示北半球冬季地表温度异常(组图)'},
#  {'text': '美国新书展示海洋鱼类：皇带鱼长达6米(图)'},
#  {'text': '热火悲剧天不助or人作孽 为什么为什么不传韦德'},
#  {'text': '全触屏卡片机 佳能IXUS 210跌百杀低价'},
#  {'text': '这个夏季注定是美元与欧元的较量'},
#  {'text': '澳洋顺昌：短期强劲 长期稳健'},
#  {'text': '格力地产最后一搏'},
#  {'text': '《变形金刚2》PC版今夏也可能推出DLC'},
#  {'text': '组图：宋慧乔刘亦菲谁是迷你女王'},
#  {'text': '电视台女主播车内遭劫 歹徒被包围后开枪自杀'},
#  {'text': '中国在英近10万学生买假文凭 中介造假一条龙'},
#  {'text': '亚姐“赛”身材 浩沙“展”实力'},
#  {'text': '上海银行备战IPO 员工持股问题待解'},
#  {'text': '杜兰特66分征服洛克公园 神奇表演中断比赛(视频)'},
#  {'text': '《加勒比海盗4》减预算 杰克船长少下海多上陆'},
#  {'text': '水井坊：精细化营销新气象'},
#  {'text': '揭秘子宫里的动物：小袋鼠仅软糖大小(组图)'},
#  {'text': '随意DIY 首款可换壳DC宾得RS1000上市'},
#  {'text': '《龙腾世纪：起源》浏览器版游戏上线'},
#  {'text': '留学途径：哪条大路能到“罗马”？'},
#  {'text': '1420W像素5倍光变 三星ES75仅售899'},
#  {'text': '澳移民削减计划瞄准留学生遭业界反对'},
#  {'text': '火箭夏季首笔出价目标曝光 反对派笑他似斯威夫特'},
#  {'text': '中国精英移民潮：北京买房不如移民'},
#  {'text': '时尚同样强大 卡西欧EX-H15售1790元'},
#  {'text': '社保基金新进44股 青睐五行业'},
#  {'text': '现场：热火狂攻力争结束连败 主帅不满判罚吃技犯'},
#  {'text': '特锐德：受益高铁快速增长'},
#  {'text': '澳门将拨款逾30亿澳门元发放现金'},
#  {'text': '药监局将增加食品卫生安全监管职责'},
#  {'text': '现场：阿联策动3点1线进攻 奇才铁血防守成功反超'},
#  {'text': '欧元愁云惨淡万里凝 花旗看空至1.40下方'},
#  {'text': '北美票房综述：《超级反派》力压唐尼夺冠(图)'},
#  {'text': '褶皱灯设计 饰家小生灵(组图)'},
#  {'text': '超大光圈轻薄机身 佳能S95特价2830元'},
#  {'text': '账户资料人证物证指向吴淑珍 检方再传2人应讯'},
#  {'text': '极端天气今年为何频发：高空喷射气流是祸首'},
#  {'text': '物虽稀但真贵 徕卡D-LUX4限量版12300元'},
#  {'text': '加拿大媒体评出2010年度佳片 《海上传奇》上榜'},
#  {'text': '国奥开房门再起波澜 知情人透露主角韩鹏周海滨'},
#  {'text': '曝奥尼尔恐已无缘常规赛 大鲨鱼当务之急是季后赛'},
#  {'text': '技嘉TopGamer联赛总决赛时间变更'},
#  {'text': '圣诞礼物数码化 绿屋推出可爱雪人U盘'},
#  {'text': '中煤能源：3月份产量增长减速'},
#  {'text': '《观音山》走进北大 陈柏霖愿与房祖名演情人'},
#  {'text': '专家详析火箭潜力新秀：莫里斯难比甜瓜难成巨星'},
#  {'text': '中国大片七年鉴：忽悠到靠谱 空壳到实质(图)'},
#  {'text': '音质纯正自然MP3 艾利和E30仅349'},
#  {'text': '续约小巨人or签自由球员？ 姚明五大替身浮出水面'},
#  {'text': '勒夫生死战仍镇定自若 克林斯曼：德国队胜在稳定'},
#  {'text': '两男子街头持刀挟持人质 的哥将其困在后车厢内'},
#  {'text': '澳门有意引入换地权证制度'},
#  {'text': '湖人出售奥多姆换2号签遭拒 舍全能王只为得1菜鸟'},
#  {'text': '英央行行长面临最严峻危机 有必要重启量化宽松'},
#  {'text': '北京4家房企销售违规遭处罚'},
#  {'text': '下一部《刺客信条》Ezio将重返罗马'},
#  {'text': '网友发帖曝民工夫妇养家还债照片获关注'},
#  {'text': '本周分析师最看好的股票'},
#  {'text': '《南京南京》长春赶拍逢瑞雪 导演陆川抢拍雪景'},
#  {'text': '一周重要经济事件提示(10月11日-10月17日)'},
#  {'text': '泰豪科技：未来两年增长有保障'},
#  {'text': 'NBA编年史之1958-59：贝勒入主洛城 绿军王朝揭幕'},
#  {'text': '购房员工未签合同 中石油支付团购预付款'},
#  {'text': '台电性感MM升级 支持HiFi新品T51图赏'},
#  {'text': '英格兰出局经济损失至少10亿镑 进决赛可收入20亿'},
#  {'text': 'IPO因素继续影响债市 国债认购倍数创年内新低 '},
#  {'text': '台湾性工作者团体赴内政部门要求不罚娼'},
#  {'text': '杰克逊谩骂裁判被罚5万 苛刻判罚或是船长暴怒原因'},
#  {'text': '横跨卡片单反 五款性能诱人新机强力推荐'},
#  {'text': '基大叔VS赵大叔：本山幽默大胜 基德球技扳回一城'},
#  {'text': '真彩触控屏设计 OPPO S33现售550元'},
#  {'text': '24mm广角双重防抖 三星WB1000旗舰DC'},
#  {'text': '尽展清晰画质 佳能S95数码相机沈阳热卖'},
#  {'text': '蔡淑臻晒出丁字线耍性感 爱大自然也爱健康(图)'},
#  {'text': '毕淑敏作品被刊载状告淮北实验高中一审败诉'},
#  {'text': '大卫-芬奇解构《返老还童》 称绝不拍《8宗罪》'},
#  {'text': '26岁女画家用新浪微博拍卖画作救助白血病患者'},
#  {'text': '雷霆被裁判送进第二轮! 15.4秒这生死改判对or错'},
#  {'text': '最便宜广角高清 三星ST60卖价不足900'},
#  {'text': '韦德缺席令詹皇发挥更舒服 波什一战重拾龙王自信'},
#  {'text': '折射的是异域风格的金色灯罩(图)'},
#  {'text': '《全城热恋》前导海报曝光 大牌演员均不见(图)'},
#  {'text': '李宇春登英国杂志封面 成娱乐圈标志性人物'},
#  {'text': '部分城市楼价暴涨引高层关注 中央部署调研'},
#  {'text': '解读2011春夏男装时髦词汇'},
#  {'text': '[北京]大降数百元 佳能大马三特价开卖'},
#  {'text': '战略模拟《前线任务》新作将有PC版本'},
#  {'text': '清新纯色系 理想家居装修之欧美风(组图)'},
#  {'text': '飞声音效高频通透 飞利浦MIXⅡ现225元'},
#  {'text': 'Grubby Tod星际争霸2比赛再相逢 '},
#  {'text': '发达国家二次衰退风险加大'},
#  {'text': '专业级单反相机 佳能500D双头套机售5999'},
#  {'text': '价格无限诱惑 尼康D3000套机仅3380元'},
#  {'text': '极具性价比 2GB忆捷R30录音笔仅售299元'},
#  {'text': '粤水电：风电及拟增发项目将成为未来看点'},
#  {'text': '中建前8月房地产销售达328亿'},
#  {'text': '10倍光变时尚长焦 索尼H20售价降至2099'},
#  {'text': '高盛：美国经济二次衰退几率25%至30%'},
#  {'text': '雨天尽享音乐时光 索尼NWZ-W252现539元'},
#  {'text': '欧盟或采取激进措施防止新的泛欧信贷紧缩'},
#  {'text': '传奥林巴斯于今年推出4支M43镜头'},
#  {'text': '原道G82HD升级版到货 8GB容量报价399元'},
#  {'text': '季后赛首战险创生涯一新低 皇帝：我从不是得分手'},
#  {'text': '联盟数据统计出现严重疏漏？ 扣篮王追回3次封盖'},
#  {'text': '患重病女子偷病友13600元 6天后自首'},
#  {'text': '[上海]简约而紧凑 索尼W320现售1350元'},
#  {'text': '纽约油价高收1.6% 本月上涨0.4%'},
#  {'text': '今晚“金马”最八卦 蔡康永要给大S“闪婚卡”'},
#  {'text': '8月21日十六机构荐黑马股'},
#  {'text': '《就是这样》北美首映日入账220万美元(图)'},
#  {'text': '国家防总冬麦旱区旱情得到缓和'},
#  {'text': '专家称购买意债符合中国长远利益'},
#  {'text': '送摄像头！东芝320G移动硬盘仅299元'},
#  {'text': '图文-热火举行新赛季媒体日 三巨头低调上路'},
#  {'text': '热门入门单反！佳能500D套机售4700'},
#  {'text': '多位经济学家认为美联储年内不会加息'},
#  {'text': '量子物理学引发奇谈怪论：薛定谔的猫(组图)'},
#  {'text': '绿城已实现销售破百亿 御园将成华北战略重点'},
#  {'text': '六大特色南极科考站：英国科考站似巨型野营车'},
#  {'text': '《秋瑾》曝群星谱 黄奕演绎传奇女人史诗(图)'},
#  {'text': '《刀见笑》未映先热 乌尔善将导《画皮2》(图)'},
#  {'text': '4倍光学变焦镜头 索尼W350售价1500元'},
#  {'text': '《肩上蝶》亮相美国电影市场展 陈坤赞导演浪漫'},
#  {'text': '马苏亮相金鸡百花电影节 红毯大秀好身材(图)'},
#  {'text': '台北股市5年来收盘首破5000点'},
#  {'text': '禅师呼吁良性竞争莫谈仇恨 硝烟未起暴力T恤先大卖'},
#  {'text': '章鱼帝传奇：无法识别颜色的色盲(图)'},
#  {'text': '鲁比尼：美元一旦走强将致使资产泡沫破裂'},
#  {'text': '世界杯-韩国2-2险平尼日利亚 晋级16强将战乌拉圭'},
#  {'text': '电竞比赛遭禁 德国玩家街头游行抗议'},
#  {'text': '胡锦涛称希望中韩经济界全面深化互利合作'},
#  {'text': 'Laurendia land首家旗舰店进驻三里屯SOHO(图)'},
#  {'text': '揭秘美国沙漠火星基地：一切遵循太空规则'},
#  {'text': 'NBA官网：奇才可选臂展7尺7神人 他现在是一个谜'},
#  {'text': '采用5倍光学变焦 佳能G12带票仅售3879元'},
#  {'text': '日本干预犯下致命错误 日高官称其愚蠢至极'},
#  {'text': '贾庆林主持全国政协第十一次主席会议'},
#  {'text': '两岸航运组织正积极磋商海运直航'},
#  {'text': '公安部已向19个国家派驻30名警务联络官'},
#  {'text': '西安民生：持续发展来自股本进步做大做强'},
#  {'text': '组图：《母亲》三项大奖称霸韩国电影青龙奖'},
#  {'text': '主人气质和大厅气派的家居沙发(图)'},
#  {'text': '广角防抖G镜头 索尼HDR-XR350E报6850'},
#  {'text': '潮流时尚闪存式DV 佳能FS200仅售2260元'},
#  {'text': '男子一个月报171次假警被拘'},
#  {'text': '5月22日奥林匹克花园10城联动开启绿色低碳生活月'},
#  {'text': '个人经营性贷款走俏 银行悄然抢滩'},
#  {'text': '高清大屏谁主沉浮 7寸大屏MP4对比导购'},
#  {'text': '证监会召开基金产品创新会议 '},
#  {'text': '基金系QDII单位净值8月创新低 '},
#  {'text': '俄图160轰炸机连飞23小时创同类机巡航新记录'},
#  {'text': '七旬老母为20万元赡养费状告儿子'},
#  {'text': '艺校报考：有评委的地方就有潜规则？'},
#  {'text': '10倍光学变焦镜头 柯达Z915仅售998元'},
#  {'text': '迪士尼获《钢铁侠3》与《复仇者》全球发行权'},
#  {'text': '具备5倍光学变焦 佳能G11最新价3680元'},
#  {'text': '拯救希腊迫在眉睫 德国态度是关键'},
#  {'text': '澳大利亚财政部官员警告房产泡沫'},
#  {'text': '夏日窗帘散发出的清凉(图)'},
#  {'text': '广电运通：再获中行2亿订单'},
#  {'text': '女大学生街头遇抢匪 市民联手擒飞贼(图)'},
#  {'text': '北京金隅融资近60亿港元'},
#  {'text': ' 实录：黄奕做客新浪 畅聊《竞雄女侠-秋瑾》'},
#  {'text': '《求生之路》第2部DLC名称与细节公布'},
#  {'text': '新湖中宝参与开发天津文化商贸园'},
#  {'text': '《盗梦空间》拍摄遍及全球 六国实景造奇幻梦境'},
#  {'text': 'NYMEX原油期货11日亚洲电子盘窄幅盘整'},
#  {'text': '选秀后阿联只剩一句台词？ 星爷电影告诉我们指示'},
#  {'text': '打铁10次投篮怒火仍然不熄 圣斗士也没他这么执着'},
#  {'text': '图文-火箭女郎拍摄新年挂历 风不小妆可别花了'},
#  {'text': '长丰汽车：轻型越野车龙头 调整到位'},
#  {'text': '阿尔斯通奔丧不成诈伤下场？老总：有失职业道德'},
#  {'text': '家用超薄卡片相机 索尼W290仅售1780元'},
#  {'text': '10倍光变 富士F75时代数码新年超值卖'},
#  ...]

# %%
Test_path='./data/data103654/test.txt'
from paddlenlp.datasets import MapDataset
batch_size=32

# 加载测试数据集
test_dataset=TestDataSet(Test_path)
print("1ok")
test_set = MapDataset(test_dataset)
print("2ok")
test_data_loader = create_dataloader02(
    test_set,
    batch_size=batch_size,
    batchify_fn=batchify_fn,
    trans_fn=trans_func02
)
print("3ok")
# test_loader = paddle.io.DataLoader(test_dataset, batch_size=64, drop_last=True)
# 将该模型及其所有子层设置为预测模式
loaded_model.eval()
# Out:
# 1ok
# 2ok
# 进入了create_dataloader02
# 3ok

# %%
import paddle.nn.functional as F

def predict(data, batch_size=32):
    examples = []
    # 数据处理
    for text in data:
        input_ids, segment_ids = convert_example02(
            text,
            tokenizer,
            max_seq_length=128)
        examples.append((input_ids, segment_ids))

    batchify_fn = lambda samples, fn=Tuple(
        Pad(axis=0, pad_val=tokenizer.pad_token_id),  # input id
        Pad(axis=0, pad_val=tokenizer.pad_token_id),  # segment id
    ): fn(samples)

    # 将数据按照batch_size进行切分
    batches = []
    one_batch = []
    for example in examples:
        one_batch.append(example)
        if len(one_batch) == batch_size:
            batches.append(one_batch)
            one_batch = []
    if one_batch:
        batches.append(one_batch)

    # 使用模型预测数据，并返回结果
    results = []
    loaded_model.eval()
    for batch in batches:
        input_ids, segment_ids = batchify_fn(batch)
        input_ids = paddle.to_tensor(input_ids)
        segment_ids = paddle.to_tensor(segment_ids)
        logits = loaded_model(input_ids, segment_ids)
        probs = F.softmax(logits, axis=1)
        idx = paddle.argmax(probs, axis=1).numpy()
        idx = idx.tolist()
        # labels = [id2label[i] for i in idx]
        results.extend(idx)
    return results
# Out:
# 5,进入了test:
# [2]

# %%
with open(Test_path,'r',encoding='utf-8') as f:
    test_data=f.readlines

# %%
with open(Test_path,'r',encoding='utf-8') as f:
            data=f.readlines()
            data_dict_list=[]
            for line in data:
                message=line.strip('\n')
                text=message
                temp={'text':text}
                data_dict_list.append(temp)

# %%
data_dict_list
# Out:
# [{'text': '北京君太百货璀璨秋色 满100省353020元'},
#  {'text': '教育部：小学高年级将开始学习性知识'},
#  {'text': '专业级单反相机 佳能7D单机售价9280元'},
#  {'text': '星展银行起诉内地客户 银行强硬客户无奈'},
#  {'text': '脱离中国的实际 强压人民币大幅升值只能是梦想'},
#  {'text': '内城土地稀缺 对开发商提出更高要求(组图)'},
#  {'text': '亚欧首脑会议举行第二次全体会议(组图)'},
#  {'text': '荷兰主帅球迷面前表决心耍酷 罗本不在范佩西成一哥'},
#  {'text': '搭配18-105VR镜头 尼康D90带票7109元'},
#  {'text': '百盛购物中心美罗城店 同一专柜花120得200'},
#  {'text': '陈水扁获释后首次出庭控告他人诽谤(图)'},
#  {'text': '为艺术喝彩 索尼推出限量珍藏NWD-W202'},
#  {'text': '新一轮价格战的开端？昂达VX530仅299元'},
#  {'text': '三星数码相框迎圣诞送好礼活动促销中'},
#  {'text': '魔兽33+11魔术克尼克斯 雷霆压爵士捍卫赛区榜首'},
#  {'text': '杭州经济适用房被曝质量问题'},
#  {'text': '欧元区在希腊援助条款上出现分歧'},
#  {'text': '入门级单反相机 尼康D3100促销价4060元'},
#  {'text': '盖特纳：解决希腊问题时间所剩无几'},
#  {'text': '骗子冒充北京干部骗财24万'},
#  {'text': '2010年韩国影展开幕 观众可体验“4D”效果(图)'},
#  {'text': '亨通光电：行业景气下滑 未来仍有看点'},
#  {'text': '美媒：内内下份合同值5000万 留在掘金能打大前锋'},
#  {'text': '刘明康：严格实施二套房政策 防范房产金融风险'},
#  {'text': '莎拉-杰西卡-帕克有意拍摄《欲望都市3》'},
#  {'text': '带伤大郅仍是江苏头号公敌 主帅：防住了他就能赢'},
#  {'text': '全国5.6万名军队转业干部安置完成'},
#  {'text': '法国总理菲永称希望修复对华关系'},
#  {'text': '欧洲三大股市下跌 英国股市跌0.18%'},
#  {'text': '2.8英寸液晶屏 iriver E200仅699'},
#  {'text': '美国3月ISM制造业指数为59.6 前值为56.5 '},
#  {'text': '台股全日跌2.4%'},
#  {'text': '纽约黄金期货收盘上涨1% 期铜大涨7%'},
#  {'text': '将浴缸里的水排尽(图)'},
#  {'text': '精钢打造，金属质感迈德克斯MS-830'},
#  {'text': '支持10倍光变 松下MD10000GK仅售6899'},
#  {'text': '前瞻-苏粤大战NBA外援成变数 郭艾伦对位马布里'},
#  {'text': '芝加哥影评人协会奖提名《社交网战》一家独大'},
#  {'text': '美国6月ISM制造业指数为56.2% 前值为59.7 '},
#  {'text': '美国上周初请失业金人数为55.4万 '},
#  {'text': '老师罚14岁女生做200个下蹲 称让其锻炼身体'},
#  {'text': '棕榈园林：积极稳健的踏上园林综合发展之路'},
#  {'text': '招商银行：贷款稳增 同业资产大幅增加'},
#  {'text': '门是以雕花作为造型(图)'},
#  {'text': '环球雅思张永琪：留学“增值服务”特色(组图)'},
#  {'text': '西班牙新宠克服离家恐惧症 25岁新星至今不敢考驾照'},
#  {'text': '揭密芙蓉姐姐的家(组图)'},
#  {'text': '华锐铸钢：风电竞争激烈 锻件刚刚开始'},
#  {'text': '澳际明日之星：有梦想你就是天才'},
#  {'text': '浙江阳光：业绩略低于预期 节能照明推广加速'},
#  {'text': '英媒评出：15位最具影响力的80后(组图)'},
#  {'text': '现场：魔术轻松破百只用三节 希尔也惹上犯规麻烦'},
#  {'text': '奇才vs热火首发：布莱切因伤缺席 白魔鬼担任替补'},
#  {'text': '时光漫步 三星WB2000镜头下的上海'},
#  {'text': '简洁大方的指导思想(图)'},
#  {'text': '热火防守彪悍双方盛赞 韦德：第一节我就知道要赢'},
#  {'text': '台媒体曝林志杰新季身价 野兽：我想要200万年薪'},
#  {'text': '合生创展涨3% 瑞信升目标价四成至7.43元'},
#  {'text': '高校简介：Middle Tennessee State University'},
#  {'text': '轻巧标头 佳能50mm f1.4USM售2550元'},
#  {'text': '发改委规定正部至科级官员办公室面积'},
#  {'text': '图文-火箭慈善活动 斯科拉和爱妻'},
#  {'text': '买单反不再是奢侈 六款套机周末推荐'},
#  {'text': '吉他英雄《World Tour》将登陆手机平台'},
#  {'text': 'APS-C画幅旗舰级单反 佳能7D单机9480元'},
#  {'text': '新基金销售依然冷飕飕'},
#  {'text': '西部倒数第2下课铃响 阿帅20年成也固执败也固执'},
#  {'text': '经典橱柜 优雅与精致并存(组图)'},
#  {'text': '卫生部要求各地防治手足口病消除恐慌'},
#  {'text': 'PC独占《猎杀潜航5》公布 预告片放出'},
#  {'text': '英国科学家计划打通地壳直接获取地幔物质(图)'},
#  {'text': '品鉴前门最后一片居住区 前门前8月推出百万私产'},
#  {'text': '具备5倍光学变焦 三星PL70仅售1180元'},
#  {'text': '5倍光学变焦镜头 宾得W80仅售1580元'},
#  {'text': '英国渔民展示3米长巨无霸海鳗 '},
#  {'text': '警员在警署内强奸19岁报案女子'},
#  {'text': '高清相机出西施 富士Z71捕捉瞬间之美'},
#  {'text': '希腊气若游丝 财长称不施救将崩盘'},
#  {'text': '《单身男女》古天乐再战情场 大展浪漫攻势(图)'},
#  {'text': '当家花旦实惠多 COWON J3购机还有好礼赠'},
#  {'text': '美元跌破低点 加剧新兴市场货币升值压力'},
#  {'text': '名校展现场报道：德意志学术交流中心(图)'},
#  {'text': '全线Full HD 索尼四款全新单反谍报曝光'},
#  {'text': '最被低估强队并非无解 江苏低调战东莞先得抗感冒'},
#  {'text': '《波斯王子5：遗忘沙漠》砂雕欣赏'},
#  {'text': '《2011：城市漫游》――从城市看刘伟强电影'},
#  {'text': '世界杯巴萨球员最多共13名 切尔西饱受伤病影响只12人'},
#  {'text': '欧洲著名十大牛校：巴黎高师等(组图)'},
#  {'text': '宁波银行：息差继续大幅反弹 增持'},
#  {'text': '瑞芯微将支持Android2.1 图片视频曝光'},
#  {'text': '詹俊足彩火线：巴萨曼联势稳 国米利物浦皇马防平'},
#  {'text': '皇帝现在投篮有绝望感觉 韦德夺冠我们还有6年'},
#  {'text': '图文-[总决赛IV]热火83-86小牛 诺维茨基突破上篮'},
#  {'text': '香川照之为拉贝婉拒南京？ 陆川称毫不知情(图)'},
#  {'text': '一个最值得信赖的避风港(图)'},
#  {'text': '美版犀利哥蹿红网络 NBA和媒体争相聘用(组图)'},
#  {'text': '5名空姐超重被禁飞状告航空公司'},
#  {'text': '花大虫用早期乔丹激励罗斯：没有队友你不会成功'},
#  {'text': '债基唱主角 新基金发行再现高潮'},
#  {'text': '《欧洲空战英雄》体验二战空战史诗感'},
#  {'text': '快讯：印度央行上调回购利率25个基点至8.25%'},
#  {'text': '立讯精密：三季报符合预期'},
#  {'text': '全手动定焦 卡尔蔡司501.4 ZF2爆4649'},
#  {'text': '两市总市值升上22万亿'},
#  {'text': '香江控股：关注大股东注资和再融资进程'},
#  {'text': '坚固大方 奥林巴斯μTOUGH-8000欲破2K'},
#  {'text': '彩虹精化：成熟品牌收购 竞争力强劲'},
#  {'text': '80GB硬盘高清DV机 索尼XR100E送备用电池'},
#  {'text': '《皇家刺青》海报曝光 9月30日全国公映(附图)'},
#  {'text': '驻美领馆参赞：首批留学生的窘迫生活'},
#  {'text': '瑞旗家园200余业主收房'},
#  {'text': '皖维高新：突破围城实现跨越发展'},
#  {'text': '另辟蹊径掘金重组：大股东减持暗藏升机'},
#  {'text': '杨洁篪会见联合国秘书长潘基文'},
#  {'text': '最年轻MVP面临最尴尬数据 罗斯：我必须拿出侵略性'},
#  {'text': '张纪中要拍3D《美猴王》 中国编剧写不好孙悟空'},
#  {'text': '跨界合作 破解房地产品质与效益博弈困局'},
#  {'text': '英国女子打算在珠穆朗玛峰上空跳伞'},
#  {'text': '《贫民》小童星回国 被高高举起似英雄凯旋(图)'},
#  {'text': '政策模糊 二套房贷利率或现竞争性下浮'},
#  {'text': '8G仅299 驰为1080P新品P7nano即将上市'},
#  {'text': '一场失利为热火敲响警钟 真的季后赛这才刚开始！'},
#  {'text': '模拟真实驾驶!《无限试驾2》初步细节'},
#  {'text': '恋人因感情遭家长反对欲跳楼殉情(图)'},
#  {'text': '6款圣诞狠降数码相机盘点：理光GX200'},
#  {'text': '嫦娥二号飞离月球奔向150万公里深空'},
#  {'text': '热火客场取关键胜利 特制红色战靴助詹韦升空(图)'},
#  {'text': '开元控股：产品结构调整 业绩略超预期'},
#  {'text': '华商在工行开通基智定投业务 '},
#  {'text': '纽约黄金期货价格周四收盘小幅下跌'},
#  {'text': '现场：10比2高潮马丁一人制造 基德妙手演空接好戏'},
#  {'text': '28mm广角镜头 佳能IXUS110仅售1899元'},
#  {'text': '美CPI数据为QE2奠基铺路 美元涨势暂歇 '},
#  {'text': '张学友拍戏吃苦头 与汤唯茶餐厅坐足10小时(图)'},
#  {'text': '男子半夜遭劫身中9刀后被好心人搭救(图)'},
#  {'text': '马丁：球队输球自己得高分无意义 没想特意造犯规'},
#  {'text': '2010年澳洲技术移民政策重大调整'},
#  {'text': '选手gych7300换仓苏州固锝 挽回损失'},
#  {'text': '联储降息预期推动油价大涨6.5%'},
#  {'text': '招商银行(600036)：行业龙头二次拉升'},
#  {'text': '中牧股份：狂犬疫苗获批 参股企业上市'},
#  {'text': '研究称古埃及美女王后长鹰钩鼻不美艳(图)'},
#  {'text': '微距镜头新宠 腾龙602仅售3490还送UV镜'},
#  {'text': '中国将同阿拉伯国家加强能源合作机制建设'},
#  {'text': '彩色橱柜 帮你大展厨艺(组图)'},
#  {'text': '三五互联：内延和外延两手抓'},
#  {'text': '人民币对美元汇率升破6.53 再创汇改以来新高'},
#  {'text': '创业板指涨0.10% 个股涨跌互现'},
#  {'text': '超长焦距加高清摄像 尼康P100套装2980元'},
#  {'text': '易建联：今天打马刺全力以赴 黑人范范来看我比赛'},
#  {'text': '金属质感超值售价 三星PL50节前特价'},
#  {'text': '真情菜百 “�福结婚金饰”演绎婚庆新思维'},
#  {'text': '孙红雷回应争议：给自己打20分 是还有进步空间'},
#  {'text': '最悲催卫冕冠军湖人仅第5 07热火亦难敌后乔丹沦陷'},
#  {'text': '美国货车行程逾百万里程表上重归零'},
#  {'text': '证券通盈利和评级综合调整一览表'},
#  {'text': '印度计划再从俄罗斯采购42架苏-30MKI战机(图)'},
#  {'text': '亚鹏和王菲的是别墅区最大A1户型(图)'},
#  {'text': '中信证券：金种子酒业绩符合预期 维持增持评级'},
#  {'text': '日股全日升6点或0.07%'},
#  {'text': '时髦外套：香奈儿演绎中性美'},
#  {'text': '东莞主场轻取吉林保持不败 后场核心爆发砍下27分'},
#  {'text': 'HDMI输出全格式高清 昂达VX575HD曝光'},
#  {'text': '奥斯卡头号种子《贫民富翁》在印度遭抗议(图)'},
#  {'text': '两万元装修的时尚两居室(组图)'},
#  {'text': '传闻中国可能马上加息'},
#  {'text': '佳能IXUS105沈阳热销 多彩不容错过'},
#  {'text': '澳移民政策收紧恐引发“多米诺”效应'},
#  {'text': '格里芬这个夏天很充实 苦练投篮强化防守变全能战士'},
#  {'text': '《阿凡达》全球大卖 续集或探阿尔法星系'},
#  {'text': '教育部透露文理是否分科有望八月敲定'},
#  {'text': '《爱情左灯右行》将上映 林嘉欣与12位男星搭档'},
#  {'text': '时尚家用卡片相机 索尼WX1售价1739元'},
#  {'text': '3D全景扫描小资生活 索尼TX9为您添情趣'},
#  {'text': '湖人指挥15+11+7想夸但不得不骂 硬一回咋那么难'},
#  {'text': '青年刺死女友后自杀未遂被判死缓'},
#  {'text': '美国7月商业库存月率为-1.0% 前值为-1.1% '},
#  {'text': '银监会将与央行联手严查无贸易背景票据贴现'},
#  {'text': '货币战争：人民币亚洲发力'},
#  {'text': '民政部成立社会福利和慈善事业促进司'},
#  {'text': '瑞士央行16日料按兵不动 且不会恢复干预'},
#  {'text': '蔡英文首次提出希望21日与马英九对话'},
#  {'text': '3月05日十六机构荐黑马股'},
#  {'text': '比利时妖星：我们比荷兰更强 奥运会有信心战胜中国'},
#  {'text': '公交车门夹伤老汉引发群殴'},
#  {'text': '体育总局局长因赛艇夺金兴奋险落水'},
#  {'text': '好友称吴淑珍在龙潭购地案中收取2亿新台币'},
#  {'text': '周迅诠释争议人物南子 时间有限考验演技'},
#  {'text': '女售票员拼死抵住车门拦下小偷'},
#  {'text': '欧佩克原油周一跌1.35美元报每桶70.37美元'},
#  {'text': '节日推荐 时尚索尼TX1南宁仅2180元'},
#  {'text': '泸州老窖000568：持续增长任重而道远'},
#  {'text': '老鹰锁定东部季后赛席位 约翰逊伤退至少休战一场'},
#  {'text': '水瓶都是孤寂的天使(图)'},
#  {'text': '42倍光学变焦镜头 松下H48GK仅售2500元'},
#  {'text': '欧洲央行3月利率会议几大猜想'},
#  {'text': '黄奕：我也想有一个肩膀依靠 没考虑过生子问题'},
#  {'text': '辽宁主帅揭秘为何双裁外援 1个能力太差1个没纪律'},
#  {'text': '一电影竟有十几监制 三地导演呼吁重视电影监制'},
#  {'text': '开来资讯每日板块热点透析'},
#  {'text': '29+6小霸王无愧东部首发 堪与勒布朗比肩舍他其谁'},
#  {'text': '高鸿股份：铁公鸡定增反蹊跷涨停 '},
#  {'text': '欧锦赛-科斯蒂奇23分特奥9助攻 塞尔维亚轻取2连胜'},
#  {'text': '火箭40+俱乐部又添新人 马丁更强数据填补休城空白'},
#  {'text': '英国首相布朗预计英央行将进一步降息  '},
#  {'text': '全时音乐陪伴！COWON X7音界新领主'},
#  {'text': '彩民周刊双色球09006期专家组：重号可能再度热出'},
#  {'text': '蓝军铁主力三朝功与过 里皮卡佩罗是否都高估了他？'},
#  {'text': '调查：你关注本届青龙奖什么以及最大冷门是？'},
#  {'text': '银行理财产品火爆态势能否持续'},
#  {'text': '纽曼XD60时尚录音笔 断电犹存“耳”留余音'},
#  {'text': '篮协禁令令DJ仍有漏洞可钻 客队进攻时他放大悲咒'},
#  {'text': '明日最具爆发力六大牛股'},
#  {'text': '公司员工携起爆器登机被截获 办理托运后放行'},
#  {'text': '欧洲市场黄金周四走低'},
#  {'text': 'HD7打压安卓价格 DesireHD惊爆3799元'},
#  {'text': '10月足彩日历周末胜负彩双猜 英德组合周3晚开售'},
#  {'text': '银轮股份002126：汽车散热器行业的龙头'},
#  {'text': '豹子头林冲打头阵《水浒》好汉竞相上银幕(图)'},
#  {'text': '世界十大最古老树木：4800岁地狐尾松问鼎(图)'},
#  {'text': '值班室烧炭取暖引发一氧化碳中毒致1死1伤'},
#  {'text': '山东连胜背后隐患正扩大 本土头号得分手休战一周'},
#  {'text': '华鲁恒升：一体化程度提高稳定业绩'},
#  {'text': '初中生遭同学围殴后开始报复他人(图)'},
#  {'text': '25X光变高清闪存 索尼CX150E降至3960'},
#  {'text': '范德法特射门扭伤脖子 荷兰绞肉机训练赛踢伤两大将'},
#  {'text': '金价半年内可上1300美元'},
#  {'text': '4款尼康相机再降价 降幅最多达400元'},
#  {'text': '15倍光变长焦！高清富士S2000仅1880'},
#  {'text': '曾文鼎已与上海队签订四年合同 本季出场希望渺茫'},
#  {'text': '希尔刺眼数据把火箭扎得好疼 难道他真扶不起来？'},
#  {'text': '梅开二度射失点球逃过法眼 比利亚包揽所有故事'},
#  {'text': '《袁崇焕》看片会 于魁智不避谈欠缺(组图)'},
#  {'text': '刘嘉玲北京验收五千万豪宅(组图)'},
#  {'text': '刘建宏：不在现场也光荣 张斌一直是节目负责人'},
#  {'text': '罗斯驳斥与韦德不和传闻：我连他电话号码都没有!'},
#  {'text': '实惠送到家 佳能500D小套特价4688元'},
#  {'text': '防总针对北方旱情启动抗旱Ⅳ级应急响应'},
#  {'text': '欧锦赛-大加两双纳瓦罗26分 西班牙灭斯队进四强'},
#  {'text': '最适合中国学生申请的十所国外名校'},
#  {'text': '冯小刚感慨《温故》遇贵人 曝与李雪健十年之约'},
#  {'text': '王胜俊：法院须把实现人民新要求作为工作标准'},
#  {'text': '预告：25日视频直播电影《将爱》发布会'},
#  {'text': '3D拍摄小DC性能王 索尼WX5C仅售2280元'},
#  {'text': '香港零售商店七月七日起对塑胶购物袋收费'},
#  {'text': '英国人争端公务员“铁饭碗”(组图)'},
#  {'text': '宫崎骏工作室年底推出新动画《动物农场》(图)'},
#  {'text': '德拉吉获欧洲央行行长正式提名 鹰派立场利好欧元'},
#  {'text': '对话《战国》作曲神思者：创作中我非常脆弱'},
#  {'text': '巴西政府出台进一步措施遏制雷亚尔升值 '},
#  {'text': '上海机场：未来国际航线高增长的最大受益者'},
#  {'text': '第13届釜山电影节开幕 参展影片创历史新高(图)'},
#  {'text': '热销实用“色”无穷 尼康S3000现售1300'},
#  {'text': '荣信股份：关注电网市场开拓进程'},
#  {'text': '广发证券：中期业绩符合预期'},
#  {'text': '冰岛真相报告 曝光经济崩溃元凶'},
#  {'text': '美债头上利剑高悬 投行热议违约后果'},
#  {'text': '欧美经济患上慢性病 意大利接棒希腊成吊尾车'},
#  {'text': '詹姆斯：波什受伤所幸赛程松 祝中国球迷新年快乐'},
#  {'text': '《十月围城》深圳看片会 王学圻甄子丹受好评'},
#  {'text': '教师救溺水少年未成功 死者家属指责其为杀人犯'},
#  {'text': '实力机构周末荐股精选'},
#  {'text': '“会讲故事的童装” DADIDA打造童装第一品牌'},
#  {'text': '数据谈：皮尔斯一战创52年历史 热火难称精英球队'},
#  {'text': '早产女婴患18种疾病被救活'},
#  {'text': '隆多亲口确认戴护具出战第四场：那东西会很难看！'},
#  {'text': '澳洲联储对经济较乐观 澳元反弹触及1.0240'},
#  {'text': '丰田子公司大发汽车将在日本召回逾27万辆汽车'},
#  {'text': '历届获奖者将会师金鸡颁奖礼 夏雨袁泉夫妻同行'},
#  {'text': '《变形金刚塞伯坦之战》增加女机器人'},
#  {'text': '世界杯T台上演制服诱惑 德国教头创立男人着装范本'},
#  {'text': '马英九向救灾殉职飞行员颁褒扬令(图)'},
#  {'text': '陈水扁夫妇新旧情书细节曝光 回忆私奔称不爱钱'},
#  {'text': '货币四角将横盘震荡 人民币升值压力仍在'},
#  {'text': '送原装电池带包 索尼XR150E套装售价4950元'},
#  {'text': '美眉说藏：小本票独树一帜'},
#  {'text': '孟广美无悔爱错郎 自曝前男友仍天天示爱(图)'},
#  {'text': '依然是那么时尚创新(图)'},
#  {'text': '超薄家用卡片相机 尼康S620仅售1870元'},
#  {'text': '四只基金接近清盘线'},
#  {'text': '全明星微博征文明日启动 更多奖品等你来拿！'},
#  {'text': '海鸥卫浴：低谷爬起 奋起直追'},
#  {'text': '美多颗卫星太空密切监视飓风艾琳动向(图)'},
#  {'text': '欧元区1月工业产出环比增1.7% 创20年最高增幅'},
#  {'text': '四劲旅盯上掘金1300万核心 经理他比安东尼先离队 '},
#  {'text': '08销量已超去年：体福彩差距缩小 即开票为增长点'},
#  {'text': '一批券商个股最新评级及推金股'},
#  {'text': '亚太地区主要股市多数上涨'},
#  {'text': '中学生游泳溺水身亡 同伴相约隐瞒实情'},
#  {'text': '孙菲菲再战银幕 《人皇伏羲》演女娲传递爱(图)'},
#  {'text': '申华控股：创投风能汽车三概念'},
#  {'text': '16G闪存高清DV 松下TM200促销6499元'},
#  {'text': '格力电器：内销保持10%左右的增长速度'},
#  {'text': '老鹰一招打中热火七寸 现在知道他有多珍贵了吧！'},
#  {'text': '埃利斯24分勇士轻取骑士 6人上双76人阻止步行者'},
#  {'text': '从精英到草根：成功留学“两步走”'},
#  {'text': '太阳篮板不利欲补强力中锋 凤凰城盯上火箭弃签之人'},
#  {'text': '赵建民接任台当局“陆委会副主委”职务'},
#  {'text': '《麻辣空姐》开机 解密空姐空少浪漫爱情(组图)'},
#  {'text': '《星际2》港版可能采用月卡收费模式'},
#  {'text': '舒斯特尔：德国球风已翻天覆地 巴拉克受伤仍难弥补 '},
#  {'text': '专访《生死朗读》导演：温斯莱特实在很出色'},
#  {'text': '《画壁》新浪官网启动 闫妮掌控情欲法则(组图)'},
#  {'text': '快讯：日本股市午盘上涨1.53%'},
#  {'text': '佳能兔年新岁 60D套机降价促销迎新春!'},
#  {'text': '6月16日美股专家坐堂实录'},
#  {'text': '佛罗里达上演蟒蛇吞食鳄鱼大战(组图)'},
#  {'text': '渣打银行个贷宣传轰炸 月薪3000元可贷20万'},
#  {'text': '《幻想三国志4》预计1月16日上市(图)'},
#  {'text': '480光年外疑发现火山行星：温度达2200度(图)'},
#  {'text': '巴黎CAC40股指28日报收于3693.14点'},
#  {'text': '实录：冯小刚刘震云王中磊做客聊《温故1942》'},
#  {'text': '外国央行增持美国公债'},
#  {'text': '图文-海耶斯中国行访男篮 面露笑容轻松应付投篮'},
#  {'text': '香港女子被卷入车底致盆骨和右大腿被辗裂'},
#  {'text': '阿根廷队长详解失球：是“呜呜祖拉”给韩国人的助攻'},
#  {'text': '奥运焰火脚印设计者自曝曾想出家(图)'},
#  {'text': '蜘蛛人坠下12楼全身骨折奇迹生还'},
#  {'text': '小语种国：中国留意大利学生近四千'},
#  {'text': '《夺魂索》男星法利-格兰杰纽约逝世 享年85岁'},
#  {'text': 'ICOO 4.7英寸屏高清新品M100HD曝光'},
#  {'text': '科学家揭开埃及挣扎尖叫状木乃伊之谜(组图)'},
#  {'text': '苏有朋无缘开幕式 坦言做好工作就是支持奥运'},
#  {'text': '孤狼现身北京八达岭被麻醉捕获'},
#  {'text': '《让子弹飞》主题曲酿全家福 葛优嘉玲确认开嗓'},
#  {'text': '穆迪：地震或令日本面临二次衰退'},
#  {'text': '净赎回连续两季居高 易方达三基金失意投资人'},
#  {'text': '裘德-洛男扮女装反串名模 被指酷似其前妻(图)'},
#  {'text': '商家悄然隐瞒 揪出不靠谱的MP3参数'},
#  {'text': '益佰制药战略清晰 步入快速发展期'},
#  {'text': '奥运男足观战指南：看超男如何带领国奥突出重围'},
#  {'text': '美国11月成屋销售月率为7.4% 前值为10.1%  '},
#  {'text': '美菱电器：业绩增长态势良好 '},
#  {'text': '皇帝满分领衔最佳阵容1队 科比9度入选平现役纪录'},
#  {'text': '俄央行六周内第三次降息以刺激经济增长'},
#  {'text': '我国已成为世界恐龙研究重要一极'},
#  {'text': '司机开车时未照明将睡觉工人碾死'},
#  {'text': '备受消费者青睐 佳能550D带票5283元'},
#  {'text': '9+10+6!达拉斯之魂已到极限 38岁真神拿灵魂拼冠军'},
#  {'text': 'IMF前总裁卡恩重获自由 或参选总统大选'},
#  {'text': '3D希腊神话新作《惊天战神》11月登陆内地(图)'},
#  {'text': 'IEF09电子竞技大赛郑州赛区完美落幕'},
#  {'text': '阿帅：交易后人人挺身而出 全新轮转已经趋于稳定'},
#  {'text': '欧洲三大股市上升 英国股市升1.07% '},
#  {'text': '经典老画在国外也热起来了'},
#  {'text': '重卡销售进入景气上行区域'},
#  {'text': '最后一款复杂结构产品离场 银行理财走低风险路'},
#  {'text': '热火裁掉阿罗约就为签毕比 LBJ早就渴望与他合作'},
#  {'text': '巴西试图利用主权基金遏止雷亚尔涨势'},
#  {'text': '股市井喷 基金排名未见大变'},
#  {'text': '贵族奢侈再次袭来 徕卡S2套机最新疯狂价'},
#  {'text': 'iPhone4骤降 全新美版机狂跌近2000元'},
#  {'text': '刷新纪录：09年留英学生签证再创新高'},
#  {'text': '皇帝阿杜赛后用伟大互赞 KD：这次我尝试了新动作'},
#  {'text': '历史冰点价 手动旗舰佳能G12震撼价3630'},
#  {'text': '水瓶男爱上你的表现揭秘(图)'},
#  {'text': '央行连续三周净投放 7天回购利率创2年多新高 '},
#  {'text': '蔡英文称5月19日决定是否发动罢免马英九'},
#  {'text': '隆多缺阵绿衫军狂胜篮网 小霸王31分16板镇压猛龙'},
#  {'text': '台当局称两岸即将合拍电视剧'},
#  {'text': '女子拒绝让座遭指责 邀情夫将无辜乘客打死'},
#  {'text': '首相萨帕特罗：西班牙也将需要援助'},
#  {'text': '美国8月核心消费者物价指数年率为1.4% '},
#  {'text': '美元再涨 纽约金价跌破1040美元'},
#  {'text': '中国将在2016年前发射空间实验室'},
#  {'text': '强心针仍难激活欧美需求'},
#  {'text': '液态奶第八次抽样检测未检出三聚氰胺'},
#  {'text': 'DC也可“美急？且看富士F85的变身术'},
#  {'text': '中端专业好选择 佳能60D单反套机售9800'},
#  {'text': '专家：海外投资移民巨变下六大新机遇'},
#  {'text': '雷霆vs掘金前瞻V威少需减少得分 掘金罚球太逆天'},
#  {'text': '盘点世界高空观景台：上海世博和谐塔上榜(图)'},
#  {'text': '恩师称皇帝是乔丹魔术师合体他一辈子都是胜利者'},
#  {'text': '美国首次使用激光击落运动中飞机(图)'},
#  {'text': '10月7日国际财经焦点提示'},
#  {'text': '新生珍稀小狐猴将泰迪熊当妈妈(组图)'},
#  {'text': '“yzr100127310”投资组合获利了结两股'},
#  {'text': '今年上半年对冲基金资产创6年最小增幅  '},
#  {'text': '台股全日升114点或1.62%'},
#  {'text': '兼具时下热门功能 英利普YDP612热卖'},
#  {'text': '要低价不要山寨！MP3播放器网购指南'},
#  {'text': '透视国际油价变局 油价飙升背离正常供需'},
#  {'text': '康美药业：四头并进确保较快增长'},
#  {'text': '中国电影爱上日本配乐 国内电影配乐人才稀缺 '},
#  {'text': 'DOTA2表演赛英雄出场及胜率统计'},
#  {'text': '一种揉和了蓝色绿色的奇妙组合(图)'},
#  {'text': '纽约金价高收1.2% 盘中突破940美元'},
#  {'text': '麦蒂5大火箭时刻：羞辱多少巨星 只留22胜在人间'},
#  {'text': '女子患肌肉骨化症身体僵直如棍子(图)'},
#  {'text': '梅根-盖尔要演神奇女侠 碧昂斯欲抢角色(图)'},
#  {'text': '女子衣着太暴露遭丈夫暴打'},
#  {'text': '中国五地首发中医药堂邮票 '},
#  {'text': 'CPL赛事总监sky三年后涅�重生 '},
#  {'text': '赵一苇：哈佛录取生的“传奇经历”(图)'},
#  {'text': '张曼玉秀男友又抱又牵 不敌李宇春场面火爆(图)'},
#  {'text': '汇川技术：强烈推荐 目标价115.85元'},
#  {'text': '法国希望在G20框架内推动征收金融交易税方案 '},
#  {'text': '东北证券：业绩符合预期 份额持续攀升'},
#  {'text': '图文-火箭常规训练 阿帅不忘关心下姚明'},
#  {'text': '美国4月ISM非制造业指数为55.4 前值为55.4 '},
#  {'text': '创新推播放器新品ZEN Style系列'},
#  {'text': '留学莫斯科：一年只需4万元人民币'},
#  {'text': '放贷人条例加快制定 个人可望成为放贷人'},
#  {'text': '图文-火箭常规训练 小布目视何处？'},
#  {'text': '标普下调爱尔兰主权信用评级 '},
#  {'text': '双屏自拍仅2台 三星PL100曝999+送礼'},
#  {'text': '欧元创两周最大涨幅 后市走势依然偏空'},
#  {'text': '格里芬队友考虑来中国打球：我喜欢那的球迷气氛'},
#  {'text': '全国检察机关举报网络和电话统一化'},
#  {'text': '平煤股份：未来受益于高弹性和资源整合'},
#  {'text': '证券通强势个股最新估值'},
#  {'text': '全球竞争力下滑 奥巴马就业市场开刀'},
#  {'text': '热火当家控卫3分命中率联盟第3 三巨头让他放轻松'},
#  {'text': '《风声》票房达1.5亿 口碑支持长线上映(图)'},
#  {'text': '魔鬼训练上海队长腿跑断 刘炜：客场很难打你懂的'},
#  {'text': 'NASA开始准备最后一次哈勃太空维修(图)'},
#  {'text': '台特侦组下周将连续两天传唤吴淑珍'},
#  {'text': '支持4倍光学变焦 奥林巴斯FE4020仅售999元'},
#  {'text': '正在视频直播太阳vs火箭 小布洛瑞谁是休城第一控'},
#  {'text': '儿子无钱葬母含泪将遗体装袋沉河'},
#  {'text': '配24-85mm镜头 尼康新品D7000套机降'},
#  {'text': '新黄浦：期货业务处于高增长期'},
#  {'text': '15X光变高清摄像 富士S2000送卡1699元'},
#  {'text': '篮网盯上骑士第四签位 萨沙看到希望急抱老板大腿'},
#  {'text': '华宇时尚购物中心 时尚零距离百余品牌齐亮相'},
#  {'text': '分析师：美元反弹难以变成趋势性反转行情 '},
#  {'text': '每日晚间实力机构点评热门个股精选'},
#  {'text': '便携的1080P 爱国者AHD-S1闪存DV售1890'},
#  {'text': '热火内线支柱两战判若两人 他若昏头詹韦还能依靠谁'},
#  {'text': 'Pimco：全球金融市场为何血流成河'},
#  {'text': '配18-105mm镜头 尼康D90套机售价7100'},
#  {'text': '天宫一号可能推迟至本月下旬发射'},
#  {'text': '21岁女子嫁给6旬富翁获赠豪宅轿车'},
#  {'text': '男子为逃过路费冒充记者(图)'},
#  {'text': '纽约黄金期货收盘上涨0.3% 报1622.30美元'},
#  {'text': '凯迪电力：业绩增长超预期 转型生物质发电'},
#  {'text': '胜负彩08100期彩果：拉齐奥主场取胜 销量2000万'},
#  {'text': '油价受美元走低推动突破72美元'},
#  {'text': '刘韬：吴泓先生安息 一路走好'},
#  {'text': '图文-[常规赛]凯尔特人104-102奇才 篮下死磕'},
#  {'text': '实用旋转屏 搭18-200mm镜佳能60D仅9799'},
#  {'text': '股市暴跌催热金市 银行争推保证金炒金业务'},
#  {'text': '山猫狂人七号秀登陆再受阻 旧合同在身FIBA拒放人'},
#  {'text': '图文-奇才举行媒体见面会 改头换面的大将军'},
#  {'text': '日本财相将于G20峰会敦促欧洲大规模支持银行业'},
#  {'text': '《子弹》首映笑声掌声全收 周润发答谢姜文(图)'},
#  {'text': '今日数据趣谈：勒夫赢数据输比赛 篮网成加时专家'},
#  {'text': '热火vs火箭首发：三巨头来势汹汹 蝙蝠侠对位皇帝'},
#  {'text': '华光股份：业务结构不如预期 但订单欣欣向荣'},
#  {'text': '是电话还是电子书毕升500T活动热销中'},
#  {'text': '国际投行坐庄零和游戏 银行对赌通吃投资者'},
#  {'text': '日经指数低开重挫逼近8000点'},
#  {'text': '汤姆-汉克斯暗示《玩具总动员》将拍摄第四部 '},
#  {'text': '中端入门级相机 宾得K7单机现价6199元'},
#  {'text': '揭秘电影版《武林外传》 佟掌柜成钉子户'},
#  {'text': '熊市基金经理怕见持有人'},
#  {'text': '车祸受害人赔偿执行难 法官资助事主七年'},
#  {'text': '警惕网银五大陷阱 冒名网站往往一字之差'},
#  {'text': '《生化危机4》热拍 米拉-乔沃维奇网上曝剧情'},
#  {'text': '兴业叫板浦发信用卡 贷款市场暗战'},
#  {'text': '胜利股份：明年还看生物产业发展'},
#  {'text': '科学家捕捉到两颗恒星合二为一精彩瞬间(图)'},
#  {'text': '5倍光学变焦镜头 松下FX580最新价1980元'},
#  {'text': '陈水扁用法国大革命的巴士底监狱譬喻自己入狱'},
#  {'text': '湖人将帅不在意登顶西部榜首 全能王：只要总冠军'},
#  {'text': '牛津剑桥模拟面试题雷倒山东考生'},
#  {'text': '亨利进谏要求与萨科奇面谈 足协：要揪出元凶制裁'},
#  {'text': '温家宝：任何国家不能对人民币升值或贬值施压'},
#  {'text': '受澳校倒闭影响中国留学生安置获新进展'},
#  {'text': '中国和哥斯达黎加启动自由贸易区谈判'},
#  {'text': '总决赛那些事(5)：詹韦卧膝长谈 牛仔永不言败'},
#  {'text': '投不进球防守被詹韦爆 公牛玉面射手坦言很受打击'},
#  {'text': '超酷的变形金刚沙发(组图)'},
#  {'text': '研究显示大规模岩浆喷发或导致生命大灭绝'},
#  {'text': '火箭选秀夜修修补补只为一个空缺 真正交易远未结束'},
#  {'text': '超龄也门助阿联酋入世少赛 国少冤案揭示双重标准'},
#  {'text': '湖人首战竟死于洛城人之手 诺天王：我最爱就是他'},
#  {'text': '长安福特举行“2008城市英雄时尚盛典”(图)'},
#  {'text': '月最佳教练马刺老帅夺最佳战绩 绿军教头称霸东部'},
#  {'text': '10X光变长焦 富士F85特价促销仅1580元'},
#  {'text': '[彩民周刊]何明09002期双色球：谨防一区开出连号'},
#  {'text': '英国12月CPI同比上升2.9% 高于预期'},
#  {'text': '一批券商个股最新评级及推荐金股'},
#  {'text': '经济前景不明 澳央行维持利率不变'},
#  {'text': '公务员拖欠前妻9万元拒绝还款被拘'},
#  {'text': '3背光学变焦镜头 佳能IXUS100仅售1698元'},
#  {'text': '《肩上蝶》7月8日公映 魔幻爱情进军暑期档'},
#  {'text': '图文：ELS美国教育中心中国区总裁观看比赛'},
#  {'text': '长阳半岛贯彻标准化设计'},
#  {'text': '夫妻婚床布满水银 一家三口汞中毒(图)'},
#  {'text': '趣味数据：波什尴尬19年未有 杰弗森神勇堪比马龙'},
#  {'text': '新品鉴：给你的鞋子戴套 一双变十双'},
#  {'text': '日剧《暗金丑岛君》拍电影版 山田孝之继续主演'},
#  {'text': '杨洁篪与欧盟轮值主席国捷克外长通电话'},
#  {'text': '啊哈！小霸王其乐无穷啊 MVP表现他已早忘记纳什'},
#  {'text': '辽宁彩民大复式擒获965万 双色球亿元加奖仅余9期'},
#  {'text': '环球科学：聪明药惹质疑(组图)'},
#  {'text': '哥白尼遗骨500年后在波兰重新下葬(图)'},
#  {'text': '西川和久佳能7D人像样张合集'},
#  {'text': '美国4月PCE物价指数月率为0.1% 前值为0.0%'},
#  {'text': '3届MVP遭主场球迷嘘声 效力十年到底谁伤了谁的心'},
#  {'text': '新疆众和：09年年报点评'},
#  {'text': '出示爱国者相机,观看公益摄影展'},
#  {'text': '广角卡片机 索尼T99C售1570还送4G卡'},
#  {'text': '具备1200万像素 松下FX580仅售2100元'},
#  {'text': '11月5日晚间实力机构荐股精选'},
#  {'text': '周穗安：瑞士是西班牙的试金石 更看好南非胜乌拉圭'},
#  {'text': '隔断处的花艺屏风(图)'},
#  {'text': '海富通稳健添利下周一起发行'},
#  {'text': '英国富翁涉嫌枪杀妻女潜逃欧洲'},
#  {'text': '美国4月房屋价格指数月率为0.8% 前值为0.3%  '},
#  {'text': '量子高科：十年磨一剑 专注健康事业'},
#  {'text': '中文系大二学生花40余万元拍电影'},
#  {'text': '证券通盈利和评级综合调整一览表'},
#  {'text': '科比半场23+8+2闪耀麦迪逊 布朗两次扣篮全场惊呼'},
#  {'text': '房子有了让人眷恋的风景(图)'},
#  {'text': '2011搞笑诺贝尔奖公布：甲虫会和酒瓶交配'},
#  {'text': '身价的含量 威宝移动硬盘PK黄金组装盘'},
#  {'text': '中国大型油气田及煤层气开发重大专项启动'},
#  {'text': '温网第1金童玉女秀恩爱 莎娃为萨沙擦额头汗水(图)'},
#  {'text': '私人开发无人岛调查：没有一亿不用做岛主梦'},
#  {'text': '在港澳工作大陆人士可赴台自由行'},
#  {'text': '憋了两场的郁闷今天发泄 这一战中国KG终赢回最严'},
#  {'text': '花鸟图案的壁纸搭配格纹桌布(图)'},
#  {'text': '马钢股份：等待动车轮加速'},
#  {'text': '组图：第47届百想大赏 汤唯亮相红毯彩裙飘逸'},
#  {'text': '远洋天著解密 距CBD最近的东五环别墅价值几何'},
#  {'text': '勿忘老用户 汉王电纸书N518功能大升级'},
#  {'text': '诈骗分子通过电话骗走市民220万元'},
#  {'text': '澳驻华使馆：政府公布多项国际教育新规'},
#  {'text': '潘震宇做客乐居揭秘东方太阳城热销原因(组图)'},
#  {'text': '《谍影重重》有望拍摄前传 马特-达蒙不再主演'},
#  {'text': '《建党伟业》在京试映 毛泽东感情戏受认可(图)'},
#  {'text': '奥巴马访华：美国留学将出现爆发式增长'},
#  {'text': '英国开发读心软件解读人类思维 成功率近五成'},
#  {'text': '孩子姓氏归属权拆散恩爱小夫妻'},
#  {'text': '五部委：全程监督检查新增千亿投资落实情况'},
#  {'text': '联盟杯积分榜：米兰胜仍未登顶 死亡之组谁可逃生'},
#  {'text': '人怕出名猪怕壮 盘点遭敲诈的好莱坞明星(组图)'},
#  {'text': '周杰伦筹拍《秘密2》 女主角“换血”(图)'},
#  {'text': '摄影师抓拍到松鼠手举椰子壳吃椰肉照片(图)'},
#  {'text': '卫生部调查天津蓟县5名婴儿感染致死事件(图)'},
#  {'text': '大叔巫刚恋上小萝莉 《绑架》导演延续同性元素'},
#  {'text': '神火股份：煤炭产量翻番 电解铝走向盈利'},
#  {'text': '文隽：香港电影90%的影响都来自李小龙'},
#  {'text': '谢霆锋和容祖儿去首都体育馆观看中国女排比赛'},
#  {'text': '《追影》横店热拍 吴镇宇钦点谢娜演“镇花”'},
#  {'text': '1200万像素家用！索尼W210标配1350'},
#  {'text': '中年夫妻相互指责对方不忠当街打成一团'},
#  {'text': '南方基金：降息意味着从紧货币政策结束'},
#  {'text': '组图：大会评委雨中红毯亮相 张静初恬静秀美背'},
#  {'text': '大学生情侣租房内煤气中毒身亡 房东为避责焚尸'},
#  {'text': '让你在快乐和安静的世界里遨游(图)'},
#  {'text': '专业级广角相机 佳能S90带票套装仅售3500'},
#  {'text': 'IMF：欧盟需对巴塞尔协议执行法案作修订'},
#  {'text': 'ESPN：火箭不卖钻石就要亏本 阿根廷人成清洗对象'},
#  {'text': '纽约油价周一涨至每桶40美元以上'},
#  {'text': '4G容量MP3仅售199元 昂达VX363到货广州'},
#  {'text': '欧美经济前景迷离 美元趋弱非美短暂反弹'},
#  {'text': '《画壁》广州首映 邓超被女学生问第三者问题'},
#  {'text': '拼死拼活就是不降 细数七款价格坚挺相机'},
#  {'text': '组图：杨紫琼亮相《昂山素季》釜山发布会'},
#  {'text': '“风中的承诺”持股维科精华 浮盈超30%'},
#  {'text': '青岛啤酒：市场份额指标将提上考核议程'},
#  {'text': '武圣携好友被捕 两人联手殴打男子或惹牢狱之灾？'},
#  {'text': '名师教你塑造个性家居风格(组图)'},
#  {'text': '10岁女孩不满父母减少零花钱离家出走卖花'},
#  {'text': '陈水扁再次申请停止羁押遭法院驳回'},
#  {'text': '抢个篮板差点膝盖报销 以为要退役麦蒂当场泪纵横'},
#  {'text': '吴伯雄7月将出席两岸经贸文化论坛'},
#  {'text': '证券通每日板块热点透析'},
#  {'text': '高考生持刀抢劫因抗震有功被免诉'},
#  {'text': '可怕惯性压垮钢制战车 胜负怎能让他末节一人担？'},
#  {'text': '“谋女儿”大揭秘 借光张艺谋曾得李安推荐(图)'},
#  {'text': '英国森林深处惊现巨头雕塑(图)'},
#  {'text': '最高法要求为经济平稳较快发展提供司法保障'},
#  {'text': '让音乐来说话 ipod shuffle3仅售558'},
#  {'text': '30G带光学防抖 松下H288套装仅3450元'},
#  {'text': '红圈经典头 佳能24-105mmF4促销6800元'},
#  {'text': '5.0英寸高清显示屏 酷比魔方H600HD仅499元'},
#  {'text': '图文-火箭队常规训练 巴丁格向小布取经'},
#  {'text': '全国已有11.3亿人参加基本医保'},
#  {'text': '超强六防设计 奥林巴斯μTough6010到'},
#  {'text': '南极巨型冰架崩塌 面积与纽约相当(组图)'},
#  {'text': '图文-[总决赛IV]热火vs小牛 詹姆斯运球强突'},
#  {'text': '埃夫隆与史泰龙争烂片影帝 Rain新片获四项提名'},
#  {'text': '客车自燃烧成空架子 20余名乘客逃生(图)'},
#  {'text': '阿联一扣二后还有快攻怒扣 三大步启动他飞了好久'},
#  {'text': '赴美留学签证申请3月1日起改网上递交'},
#  {'text': '地下非法彩票刊物案件告破 印发六合彩码报达两年'},
#  {'text': '观察：新富海外移民显示出的“忧患”'},
#  {'text': '全智贤因拍戏爱上运动 称拍打戏苦不堪言(图)'},
#  {'text': '男子刺死女学生后送医院谎称见义勇为'},
#  {'text': '南方队也有新星正在升起 何忠勉道出东莞提升原因'},
#  {'text': '暑期火爆热销中 佳能A490您最佳的选择'},
#  {'text': '英格兰队面临背水一战 卡佩罗先紧急整风再变阵'},
#  {'text': '天生无四肢青年已在12国演讲1600场'},
#  {'text': '西方国家让人匪夷所思的四大禁忌(组图)'},
#  {'text': '男子为求暗恋女生欢心重伤舍友被判14年'},
#  {'text': '填写官方申请表格 有机会获得DOTA2测试邀请'},
#  {'text': '口述：大龄剩女的穿着苦恼'},
#  {'text': '中国支付清算协会成立 第三方支付牌照发放爽约'},
#  {'text': '外交部发言人就印尼酒店爆炸案答问'},
#  {'text': '相机摇身变投影 尼康S1000pj特价售1800'},
#  {'text': '下周重要经济事件提示(11月9日-11月15日)'},
#  {'text': '小伙因经济拮据发帖转让女友'},
#  {'text': '高清MP4送乐扣水杯 爱国者PM5966仅619'},
#  {'text': '开来资讯天天涨幅榜背景大揭秘 '},
#  {'text': '搭配QA：破洞牛仔裤咋搭最时髦'},
#  {'text': '商务部：支持流通企业做大降低成本扩大消费'},
#  {'text': '专访《第四号》男主角亚历克斯：我不追名逐利'},
#  {'text': '新浪正在视频直播热火vs老鹰 鹰王放水闪电侠？'},
#  {'text': '辨别真伪：学校越“野鸡”名头越吓人'},
#  {'text': '舒淇演技遭质疑当场曝粗口 自觉表演很内在(图)'},
#  {'text': '4X光变广角机 索尼W310破千还送2G卡'},
#  {'text': '长焦DC巅峰之作 富士HS11报价3380元'},
#  {'text': '陈水扁律师公布侦讯录影带指控检方教唆伪证'},
#  {'text': '林青霞复出王家卫随时量身打造角色(图)'},
#  {'text': '中国最强神虫聚首 F91登顶冠军宝座'},
#  {'text': '江苏周日主场搬往奥体 高层解释突然“试水”原因'},
#  {'text': '欧洲进入冰川时代仅用6个月速度为预计20倍'},
#  {'text': '美科学家坚信发现外星生命只是时间问题'},
#  {'text': '易宪容：银行反价纠纷不可避免'},
#  {'text': '格林讽刺火箭防守 巴蒂尔：我们的表现已经是进步'},
#  {'text': '美元能否厚积薄发 焦点转向本周关键数据'},
#  {'text': '捷波朗亚太区发布降噪蓝牙耳麦Jabra GO660'},
#  {'text': '时尚超薄卡片相机 佳能IXUS300仅售2200元'},
#  {'text': '男子当街连砸20多辆汽车车窗玻璃'},
#  {'text': '阿帅：赛程让训练得不到保证 防守端我们没尽全力'},
#  {'text': '《假戏真作》影射名导 彭浩翔30分钟搞定黄立行'},
#  {'text': '澳洋顺昌：产能扩张 多元化经营引领增长'},
#  {'text': '《连线》杂志：人类百米跑速度远未接近极限'},
#  {'text': 'NBA编年史之1986-87红衣主教失策 绿军入黑暗期'},
#  {'text': '康强电子：封装材料龙头 蓄势待发'},
#  {'text': '多重大礼相送 4GB三星YP-R0现售659元'},
#  {'text': '2008-2024：冥王星魔羯座的大时代(图)'},
#  {'text': '英国对语言学校“网开一面” 签证时间放宽'},
#  {'text': '《非诚勿扰》北京庆功 冯小刚进3亿俱乐部(图)'},
#  {'text': '成飞集成：航空数控加工 汽车模具业务增长明确'},
#  {'text': '人均债务721万日元 日本面临债务危机总爆发'},
#  {'text': '调查：美国5月个人消费支出或微幅上升'},
#  {'text': '澳洋顺昌：下游行业景气恢复 小额贷款收益增加'},
#  {'text': '严宽视大学生为偶像 与刘烨同台拼人气(组图)'},
#  {'text': '三部委要求中小学严格控制暑期作业量'},
#  {'text': '媒体指楼市存三团迷雾 成房价上涨隐形翅膀'},
#  {'text': 'ECL战火点燃七月 S2总决赛决战郑州'},
#  {'text': '谁与争锋 8G苹果iPod touch4大泻报1800'},
#  {'text': '新债基全是红苗 弱市中优势明显'},
#  {'text': '日股全日升51点或0.57%'},
#  {'text': '日股全日下跌93.4点或1.07%'},
#  {'text': '10大最受喜爱球员：坏小子变慈世平 魔兽乃沙克2.0'},
#  {'text': '全触摸控制 苹果iPod nano 6报价1200元'},
#  {'text': '新研究发现恐龙暴脾气或与虱子骚扰有关'},
#  {'text': '传递摄影的乐趣 圆角佳能IXUS110IS热售'},
#  {'text': '“白领地摊族”的新乐活方式(图)'},
#  {'text': '火卫一数百万年后可能撞上火星(图)'},
#  {'text': '1210W像智能对焦 索尼W310促销价1089元'},
#  {'text': '简单生活特别企划：瓶里盛满大海一样的简单爱'},
#  {'text': 'QE2的终结对美元意味着什么'},
#  {'text': '东华能源：再生资源第一股 新能源概念突出'},
#  {'text': '美国6月里奇蒙德联储制造业指数为23 '},
#  {'text': '两院院士评出2009国内外十大科技进展'},
#  {'text': '天源迪科：BSS系统是业务突破口'},
#  {'text': '中方在苏丹被绑架人员仍有2人失踪'},
#  {'text': '纽约油价跌收2.8% 报51.05美元'},
#  {'text': '时代周刊2008十大医学突破揭晓(组图)'},
#  {'text': '虎年你最红! 喜庆红色系IT产品推荐-相机篇'},
#  {'text': '谢霆锋哭戏酝酿20天 当了爸爸更懂照顾小孩(图)'},
#  {'text': '1220万像时尚卡片 三星st45仅千元出头'},
#  {'text': '英国研发出有助治疗腭裂新材料'},
#  {'text': '全画幅重量级单反！尼康D700售14500元'},
#  {'text': '渣打银行调查显示四成小企业靠民间借贷度日'},
#  {'text': '房地产泡沫 有还是没有'},
#  {'text': '2010年四季度机构龙虎榜全景'},
#  {'text': '《秋瑾》片花黄奕挥鞭抗敌 郑嘉颖全靠妻子保护'},
#  {'text': '詹俊足彩推荐：英超又见“和风”吹 博胆首选曼联'},
#  {'text': '银行疯狂收费让人吓一跳：打印一张纸需要40元'},
#  {'text': '鳄鱼邓迪保罗-霍根涉嫌逃税禁止离澳(图)'},
#  {'text': '送原装备用电池 索尼XR550套装10480元'},
#  {'text': '《额吉》母亲节公映 民族史诗抒写深情传奇'},
#  {'text': '4款造型花洒 沐浴多功能体验(组图)'},
#  {'text': '《变3》记者会梅根“抢戏” 赤裸植入广告被批'},
#  {'text': '美国上周EIA蒸馏油库存变化为+120万桶'},
#  {'text': '美联储暗示经济复苏 日元兑欧元创三周最高跌幅'},
#  {'text': '图文-热火小牛备战总决赛 老基德踏入训练馆'},
#  {'text': '爱尔兰借贷成本飙升 欧盟做好援救准备'},
#  {'text': '小法：能为西班牙踢球甘当替补 梅西已是阿根廷一哥'},
#  {'text': '每日之星：勒布朗科比何不同 皇帝两月命中率近六成'},
#  {'text': '陕国投A：未来提升空间大 逢低关注'},
#  {'text': '《失恋33天》做客快乐大本营 文章被赞绝种好男'},
#  {'text': '金发碧眼看中国：雄伟壮丽的长城(组图)'},
#  {'text': '解读留学各国艺术类院校的招生规则'},
#  {'text': '图文-火箭常规训练 伤不好，洛瑞很苦恼'},
#  {'text': '专家：加索尔做到5点可重生 找科比沟通帮安猪防守'},
#  {'text': '日本核泄漏危机 金融市场大动荡'},
#  {'text': '陈水扁妻子吴淑珍坦承教唆子女作伪证'},
#  {'text': '男工帮女同事换光管被误为情敌遭砍手'},
#  {'text': '大提琴女孩与《甜蜜乐章》约定曲试听'},
#  {'text': '男子强奸幼女后潜逃 贩毒时被抓'},
#  {'text': '中方教练抛弃杜伊嫡系球员 日本专家：中国足球完了'},
#  {'text': '十款最具发展前景机器人智能社交机器人会互动'},
#  {'text': '奇才vs开拓者首发：阿联继续先发 沃尔挑战老米勒'},
#  {'text': '生活中的趣味数学：同一天生日概率有多大'},
#  {'text': '每月跌400元 猴票领跌邮市呼唤交易新机制'},
#  {'text': '55分之夜马布里为何会疯狂 最爱之人正在天上看他'},
#  {'text': '职工向女同事发黄色图片引发75万经济损失案'},
#  {'text': '国资委：央企须建安全生产组织机构'},
#  {'text': '亨通光电：全年业绩将低于预期 关注明后年增长'},
#  {'text': '《国家代表》连续4周蝉联韩国票房冠军(图)'},
#  {'text': '独特的装饰方式(图)'},
#  {'text': '哈利-波特要玩速老术 收官片出动四百群众演员'},
#  {'text': '证券通盈利和评级综合调整一览表'},
#  {'text': '宫本制作所将发售徕卡多款NEX用转接环'},
#  {'text': 'MO&Co. De Paris 冬季装备 强势姿态'},
#  {'text': '米卢VS奎罗斯：世界杯是梦想成真 C罗能改变胜负'},
#  {'text': '罗本抵达约堡与荷兰队汇合 主帅坚持首战雪藏爱将'},
#  {'text': '商业地产1号基金：工商联中信证券锁定温州资本'},
#  {'text': '布拉德-皮特密会安妮斯顿 重戴前妻定情项链'},
#  {'text': '圣农发展：鸡肉量价齐升 全年业绩翻番'},
#  {'text': '拥有1211万有效像素 松下GF1带票仅售4850元'},
#  {'text': '工行状告三名信用卡负翁 信用记录列为禁入'},
#  {'text': '超热入门新单反 尼康D3000套机促销中'},
#  {'text': '时尚高性价比卡片DC 佳能IXUS105仅售1450元'},
#  {'text': '《狄仁杰》观影调查揭晓 九成观众对电影满意'},
#  {'text': '老汉在地下室私藏树脂被炸飞(图)'},
#  {'text': '揭黑记者被控三周内犯三项罪 疑遭打击报复'},
#  {'text': '一定要给床上增添几种布艺床品(图)'},
#  {'text': '开启数码影像次时代 理光岁末发布GXR'},
#  {'text': '“岁月流沙，变幻与永恒”的经典概念'},
#  {'text': '以蓝色为中心 让人感觉舒畅(图)'},
#  {'text': '5�1280P蓝光ICOO E900P 8GB 499元'},
#  {'text': '东西之间：给老外送礼的“潜规则”(图)'},
#  {'text': '欧洲银行压力测试有点儿不靠谱'},
#  {'text': '意大利戴黑纱悼念传奇英雄 如此表现怎能告慰英灵？'},
#  {'text': '全球评级市场几乎被完全垄断 谁来给穆迪评级'},
#  {'text': '双头套机最新低价 松下GF1送包7500元'},
#  {'text': '兰多夫挺工会宁可赛季取消 自称要追随小加赴海外'},
#  {'text': '瑞典将向非欧盟国家留学生提高奖学金额'},
#  {'text': '辰州矿业：金锑钨三大产品价格均大幅上涨'},
#  {'text': '关小刀火线解盘：霍芬海姆取连胜 维拉主场奏凯歌'},
#  {'text': '火箭客场失利命悬一线 黄蜂苦战过关锁定季后门票'},
#  {'text': '伤病编年史：8年两度骨折5次手术 左脚是姚明噩梦'},
#  {'text': '广东野兽还没达到期望值 他不缺天赋只是缺少血性'},
#  {'text': '北京回迁户选号逾千人排队 现场开门时挤倒数人'},
#  {'text': '在美华人摆脱单身秘诀：约会要直截了当'},
#  {'text': '12星座之住宅风水 解密星座与住宅(组图)'},
#  {'text': '女大学生埋怨男友不给暖脚拨110报警'},
#  {'text': '太极股份002368：三热点给力公司转型'},
#  {'text': '丰原生化：燃料乙醇价大涨 产业整合犹存'},
#  {'text': '福耀玻璃：连续7日上涨 股价创今年反弹新高'},
#  {'text': '科学家首次目睹超大质量黑洞吞噬高温气体(图)'},
#  {'text': '太委屈 四大行逆势招聘惹争议'},
#  {'text': '知情人士称银行税不会纳入第二轮希腊援助计划'},
#  {'text': '太空之眼：八具最伟大空间望远镜(组图)'},
#  {'text': '人大常委会第9次会议首次审议海岛保护法等'},
#  {'text': '现场-德罗西后场传球被断 斯洛伐克死角破门1-0领先'},
#  {'text': '广发证券：各业务竞争力强 融资推动增长'},
#  {'text': '卫生部：今年将推广免费婚检和婚育健康咨询'},
#  {'text': '新西兰央行27日预计按兵不动'},
#  {'text': '成龙：卡梅隆牛，可他是我的影迷(图)'},
#  {'text': '纽约油价跌破80美元关 三连阴重挫10.5%'},
#  {'text': '死扛2245点等待明确信号 基金仍不愿意做多'},
#  {'text': '爱尔眼科：全国布局的协同效应将显现'},
#  {'text': '设计师很费了一番气力(图)'},
#  {'text': 'ICOO高清Widget触摸黑色版E500P上市热卖'},
#  {'text': '海协会副会长访台被绿营支持者推倒在地(组图)'},
#  {'text': '西川和久宾得K7人像样张合集'},
#  {'text': '欧洲央行重新考虑货币退出政策时间表'},
#  {'text': '古井贡酒：再造一个古井指日可待'},
#  {'text': '咨询站：GRE成绩不够申请名校机会渺茫'},
#  {'text': '8%新生儿父母为非法移民 美落地国籍或废除'},
#  {'text': '抢匪受伤后报警谎称被打劫'},
#  {'text': '发布会“明谢”创意来自姚明 发言稿经四次修改成型'},
#  {'text': '盘点美华人家暴：谁说男人不是受害者(图)'},
#  {'text': '业主拖欠237万管理费与物业公司打官司7年'},
#  {'text': '林志玲《决战刹马镇》饰演老板娘拒说娃娃音'},
#  {'text': '厨房位于西方 能带来财运(图)'},
#  {'text': '吸血鬼征服银幕 《嗜血破晓》公布新款海报(图)'},
#  {'text': '震撼：考上美国名校一年竟花了60万(图)'},
#  {'text': '犹如顺水而下的金砂 就买错杀股'},
#  {'text': '胜负彩08072期差异指数火线：临场升半球勒沃完胜'},
#  {'text': '组图：李孝利华丽街头风 加点运动更性感'},
#  {'text': '味觉诱惑：不可错过的阿根廷美食(组图) '},
#  {'text': '调查-您如何看待火箭新帅 大姚是否会受到他影响'},
#  {'text': '原道G85 TOUCH VIVA半价试用招募中'},
#  {'text': '完美蜕变的开始？佳能60D套机火热促销'},
#  {'text': '周口店遗址新馆10月开建预计明年完工'},
#  {'text': '曾志伟深圳筹款建校 证实尹志强流鼻血入院'},
#  {'text': '新品鉴：2010冬季最犀利单品 逗趣保暖胡须帽'},
#  {'text': '《欧洲空战英雄》预览视频'},
#  {'text': '猕猴遭雷劈截肢两次 获名猴巨强(图)'},
#  {'text': '延续D90辉煌 中端单反尼康D7000首发评测'},
#  {'text': '一种浪漫而精致的气质(图)'},
#  {'text': '宁静自曝曾放弃绿卡：我很顽固！'},
#  {'text': '欧洲留学大探营：法德荷强势专业推荐'},
#  {'text': '宝哥五要素：过往交锋沙尔克全胜 阿森纳遭遇克星'},
#  {'text': '住建部今年严查保障房质量 开展监督执法检查'},
#  {'text': '日本央行再度注资3万亿日元 总额达18万亿'},
#  {'text': '欧洲三大股市上升 英国股市升0.69%'},
#  {'text': '《阿里郎》一种关注单获元奖 金基德现场高歌'},
#  {'text': '中国医药：受益于达菲收储及经销'},
#  {'text': '开发商跟物业公司究竟有没有关系'},
#  {'text': '士兰微：筹备多芯片高压功率模块 买入'},
#  {'text': '专业级手动广角相机 佳能S90仅售2980元'},
#  {'text': '日媒金狼24岁第一射真爽 德新社这是开赛来最大冷门'},
#  {'text': '疱丁解牛：山东黄金 金价上涨诱发反弹'},
#  {'text': '六色炫彩美颜机 轻薄卡西欧Z90送好礼'},
#  {'text': '澳大利亚将对迷途幼鲸实施安乐死(图)'},
#  {'text': '潘石屹无缘前门改造项目 17.7亿收购商业物业'},
#  {'text': '搞怪手绘 营造幽默家居气氛(组图)'},
#  {'text': '国青球员中超生存报告 再揭足坛内部不团结之本质'},
#  {'text': '峨眉山A：有待进内外因驱动下成长提速期'},
#  {'text': '720P平民超值相机！富士jv155仅999元'},
#  {'text': '《家有喜事》爆笑剧照：黄飞鸿大战李铁梅(图)'},
#  {'text': '美研制僵尸昆虫飞行器电极植入大脑操控(图)'},
#  {'text': '将一整块窗帘布裁剪成两半(图)'},
#  {'text': '400余人齐聚公司讨工资和材料费'},
#  {'text': '小店店主闯入市容大队暴打城管队员及警察'},
#  {'text': '阿帅对手仨大个子真要命 巴丁格我们尽力战斗了'},
#  {'text': '纽约原油期货周五收盘下跌0.9%'},
#  {'text': '雅居乐地产全年业绩增160%'},
#  {'text': '高品质诱惑机型 松下GF1套机仅售3K8'},
#  {'text': '海外视角：美国饭桌上培养独立能力'},
#  {'text': '好莱坞影片垄断暑期档 5.43亿人次14年观众最少'},
#  {'text': '新研究称埃及狮身人面像最初有狮头(组图)'},
#  {'text': '冯小刚首次透露：新片无法回避汶川大地震(图)'},
#  {'text': '卫星图片显示北半球冬季地表温度异常(组图)'},
#  {'text': '美国新书展示海洋鱼类：皇带鱼长达6米(图)'},
#  {'text': '热火悲剧天不助or人作孽 为什么为什么不传韦德'},
#  {'text': '全触屏卡片机 佳能IXUS 210跌百杀低价'},
#  {'text': '这个夏季注定是美元与欧元的较量'},
#  {'text': '澳洋顺昌：短期强劲 长期稳健'},
#  {'text': '格力地产最后一搏'},
#  {'text': '《变形金刚2》PC版今夏也可能推出DLC'},
#  {'text': '组图：宋慧乔刘亦菲谁是迷你女王'},
#  {'text': '电视台女主播车内遭劫 歹徒被包围后开枪自杀'},
#  {'text': '中国在英近10万学生买假文凭 中介造假一条龙'},
#  {'text': '亚姐“赛”身材 浩沙“展”实力'},
#  {'text': '上海银行备战IPO 员工持股问题待解'},
#  {'text': '杜兰特66分征服洛克公园 神奇表演中断比赛(视频)'},
#  {'text': '《加勒比海盗4》减预算 杰克船长少下海多上陆'},
#  {'text': '水井坊：精细化营销新气象'},
#  {'text': '揭秘子宫里的动物：小袋鼠仅软糖大小(组图)'},
#  {'text': '随意DIY 首款可换壳DC宾得RS1000上市'},
#  {'text': '《龙腾世纪：起源》浏览器版游戏上线'},
#  {'text': '留学途径：哪条大路能到“罗马”？'},
#  {'text': '1420W像素5倍光变 三星ES75仅售899'},
#  {'text': '澳移民削减计划瞄准留学生遭业界反对'},
#  {'text': '火箭夏季首笔出价目标曝光 反对派笑他似斯威夫特'},
#  {'text': '中国精英移民潮：北京买房不如移民'},
#  {'text': '时尚同样强大 卡西欧EX-H15售1790元'},
#  {'text': '社保基金新进44股 青睐五行业'},
#  {'text': '现场：热火狂攻力争结束连败 主帅不满判罚吃技犯'},
#  {'text': '特锐德：受益高铁快速增长'},
#  {'text': '澳门将拨款逾30亿澳门元发放现金'},
#  {'text': '药监局将增加食品卫生安全监管职责'},
#  {'text': '现场：阿联策动3点1线进攻 奇才铁血防守成功反超'},
#  {'text': '欧元愁云惨淡万里凝 花旗看空至1.40下方'},
#  {'text': '北美票房综述：《超级反派》力压唐尼夺冠(图)'},
#  {'text': '褶皱灯设计 饰家小生灵(组图)'},
#  {'text': '超大光圈轻薄机身 佳能S95特价2830元'},
#  {'text': '账户资料人证物证指向吴淑珍 检方再传2人应讯'},
#  {'text': '极端天气今年为何频发：高空喷射气流是祸首'},
#  {'text': '物虽稀但真贵 徕卡D-LUX4限量版12300元'},
#  {'text': '加拿大媒体评出2010年度佳片 《海上传奇》上榜'},
#  {'text': '国奥开房门再起波澜 知情人透露主角韩鹏周海滨'},
#  {'text': '曝奥尼尔恐已无缘常规赛 大鲨鱼当务之急是季后赛'},
#  {'text': '技嘉TopGamer联赛总决赛时间变更'},
#  {'text': '圣诞礼物数码化 绿屋推出可爱雪人U盘'},
#  {'text': '中煤能源：3月份产量增长减速'},
#  {'text': '《观音山》走进北大 陈柏霖愿与房祖名演情人'},
#  {'text': '专家详析火箭潜力新秀：莫里斯难比甜瓜难成巨星'},
#  {'text': '中国大片七年鉴：忽悠到靠谱 空壳到实质(图)'},
#  {'text': '音质纯正自然MP3 艾利和E30仅349'},
#  {'text': '续约小巨人or签自由球员？ 姚明五大替身浮出水面'},
#  {'text': '勒夫生死战仍镇定自若 克林斯曼：德国队胜在稳定'},
#  {'text': '两男子街头持刀挟持人质 的哥将其困在后车厢内'},
#  {'text': '澳门有意引入换地权证制度'},
#  {'text': '湖人出售奥多姆换2号签遭拒 舍全能王只为得1菜鸟'},
#  {'text': '英央行行长面临最严峻危机 有必要重启量化宽松'},
#  {'text': '北京4家房企销售违规遭处罚'},
#  {'text': '下一部《刺客信条》Ezio将重返罗马'},
#  {'text': '网友发帖曝民工夫妇养家还债照片获关注'},
#  {'text': '本周分析师最看好的股票'},
#  {'text': '《南京南京》长春赶拍逢瑞雪 导演陆川抢拍雪景'},
#  {'text': '一周重要经济事件提示(10月11日-10月17日)'},
#  {'text': '泰豪科技：未来两年增长有保障'},
#  {'text': 'NBA编年史之1958-59：贝勒入主洛城 绿军王朝揭幕'},
#  {'text': '购房员工未签合同 中石油支付团购预付款'},
#  {'text': '台电性感MM升级 支持HiFi新品T51图赏'},
#  {'text': '英格兰出局经济损失至少10亿镑 进决赛可收入20亿'},
#  {'text': 'IPO因素继续影响债市 国债认购倍数创年内新低 '},
#  {'text': '台湾性工作者团体赴内政部门要求不罚娼'},
#  {'text': '杰克逊谩骂裁判被罚5万 苛刻判罚或是船长暴怒原因'},
#  {'text': '横跨卡片单反 五款性能诱人新机强力推荐'},
#  {'text': '基大叔VS赵大叔：本山幽默大胜 基德球技扳回一城'},
#  {'text': '真彩触控屏设计 OPPO S33现售550元'},
#  {'text': '24mm广角双重防抖 三星WB1000旗舰DC'},
#  {'text': '尽展清晰画质 佳能S95数码相机沈阳热卖'},
#  {'text': '蔡淑臻晒出丁字线耍性感 爱大自然也爱健康(图)'},
#  {'text': '毕淑敏作品被刊载状告淮北实验高中一审败诉'},
#  {'text': '大卫-芬奇解构《返老还童》 称绝不拍《8宗罪》'},
#  {'text': '26岁女画家用新浪微博拍卖画作救助白血病患者'},
#  {'text': '雷霆被裁判送进第二轮! 15.4秒这生死改判对or错'},
#  {'text': '最便宜广角高清 三星ST60卖价不足900'},
#  {'text': '韦德缺席令詹皇发挥更舒服 波什一战重拾龙王自信'},
#  {'text': '折射的是异域风格的金色灯罩(图)'},
#  {'text': '《全城热恋》前导海报曝光 大牌演员均不见(图)'},
#  {'text': '李宇春登英国杂志封面 成娱乐圈标志性人物'},
#  {'text': '部分城市楼价暴涨引高层关注 中央部署调研'},
#  {'text': '解读2011春夏男装时髦词汇'},
#  {'text': '[北京]大降数百元 佳能大马三特价开卖'},
#  {'text': '战略模拟《前线任务》新作将有PC版本'},
#  {'text': '清新纯色系 理想家居装修之欧美风(组图)'},
#  {'text': '飞声音效高频通透 飞利浦MIXⅡ现225元'},
#  {'text': 'Grubby Tod星际争霸2比赛再相逢 '},
#  {'text': '发达国家二次衰退风险加大'},
#  {'text': '专业级单反相机 佳能500D双头套机售5999'},
#  {'text': '价格无限诱惑 尼康D3000套机仅3380元'},
#  {'text': '极具性价比 2GB忆捷R30录音笔仅售299元'},
#  {'text': '粤水电：风电及拟增发项目将成为未来看点'},
#  {'text': '中建前8月房地产销售达328亿'},
#  {'text': '10倍光变时尚长焦 索尼H20售价降至2099'},
#  {'text': '高盛：美国经济二次衰退几率25%至30%'},
#  {'text': '雨天尽享音乐时光 索尼NWZ-W252现539元'},
#  {'text': '欧盟或采取激进措施防止新的泛欧信贷紧缩'},
#  {'text': '传奥林巴斯于今年推出4支M43镜头'},
#  {'text': '原道G82HD升级版到货 8GB容量报价399元'},
#  {'text': '季后赛首战险创生涯一新低 皇帝：我从不是得分手'},
#  {'text': '联盟数据统计出现严重疏漏？ 扣篮王追回3次封盖'},
#  {'text': '患重病女子偷病友13600元 6天后自首'},
#  {'text': '[上海]简约而紧凑 索尼W320现售1350元'},
#  {'text': '纽约油价高收1.6% 本月上涨0.4%'},
#  {'text': '今晚“金马”最八卦 蔡康永要给大S“闪婚卡”'},
#  {'text': '8月21日十六机构荐黑马股'},
#  {'text': '《就是这样》北美首映日入账220万美元(图)'},
#  {'text': '国家防总冬麦旱区旱情得到缓和'},
#  {'text': '专家称购买意债符合中国长远利益'},
#  {'text': '送摄像头！东芝320G移动硬盘仅299元'},
#  {'text': '图文-热火举行新赛季媒体日 三巨头低调上路'},
#  {'text': '热门入门单反！佳能500D套机售4700'},
#  {'text': '多位经济学家认为美联储年内不会加息'},
#  {'text': '量子物理学引发奇谈怪论：薛定谔的猫(组图)'},
#  {'text': '绿城已实现销售破百亿 御园将成华北战略重点'},
#  {'text': '六大特色南极科考站：英国科考站似巨型野营车'},
#  {'text': '《秋瑾》曝群星谱 黄奕演绎传奇女人史诗(图)'},
#  {'text': '《刀见笑》未映先热 乌尔善将导《画皮2》(图)'},
#  {'text': '4倍光学变焦镜头 索尼W350售价1500元'},
#  {'text': '《肩上蝶》亮相美国电影市场展 陈坤赞导演浪漫'},
#  {'text': '马苏亮相金鸡百花电影节 红毯大秀好身材(图)'},
#  {'text': '台北股市5年来收盘首破5000点'},
#  {'text': '禅师呼吁良性竞争莫谈仇恨 硝烟未起暴力T恤先大卖'},
#  {'text': '章鱼帝传奇：无法识别颜色的色盲(图)'},
#  {'text': '鲁比尼：美元一旦走强将致使资产泡沫破裂'},
#  {'text': '世界杯-韩国2-2险平尼日利亚 晋级16强将战乌拉圭'},
#  {'text': '电竞比赛遭禁 德国玩家街头游行抗议'},
#  {'text': '胡锦涛称希望中韩经济界全面深化互利合作'},
#  {'text': 'Laurendia land首家旗舰店进驻三里屯SOHO(图)'},
#  {'text': '揭秘美国沙漠火星基地：一切遵循太空规则'},
#  {'text': 'NBA官网：奇才可选臂展7尺7神人 他现在是一个谜'},
#  {'text': '采用5倍光学变焦 佳能G12带票仅售3879元'},
#  {'text': '日本干预犯下致命错误 日高官称其愚蠢至极'},
#  {'text': '贾庆林主持全国政协第十一次主席会议'},
#  {'text': '两岸航运组织正积极磋商海运直航'},
#  {'text': '公安部已向19个国家派驻30名警务联络官'},
#  {'text': '西安民生：持续发展来自股本进步做大做强'},
#  {'text': '组图：《母亲》三项大奖称霸韩国电影青龙奖'},
#  {'text': '主人气质和大厅气派的家居沙发(图)'},
#  {'text': '广角防抖G镜头 索尼HDR-XR350E报6850'},
#  {'text': '潮流时尚闪存式DV 佳能FS200仅售2260元'},
#  {'text': '男子一个月报171次假警被拘'},
#  {'text': '5月22日奥林匹克花园10城联动开启绿色低碳生活月'},
#  {'text': '个人经营性贷款走俏 银行悄然抢滩'},
#  {'text': '高清大屏谁主沉浮 7寸大屏MP4对比导购'},
#  {'text': '证监会召开基金产品创新会议 '},
#  {'text': '基金系QDII单位净值8月创新低 '},
#  {'text': '俄图160轰炸机连飞23小时创同类机巡航新记录'},
#  {'text': '七旬老母为20万元赡养费状告儿子'},
#  {'text': '艺校报考：有评委的地方就有潜规则？'},
#  {'text': '10倍光学变焦镜头 柯达Z915仅售998元'},
#  {'text': '迪士尼获《钢铁侠3》与《复仇者》全球发行权'},
#  {'text': '具备5倍光学变焦 佳能G11最新价3680元'},
#  {'text': '拯救希腊迫在眉睫 德国态度是关键'},
#  {'text': '澳大利亚财政部官员警告房产泡沫'},
#  {'text': '夏日窗帘散发出的清凉(图)'},
#  {'text': '广电运通：再获中行2亿订单'},
#  {'text': '女大学生街头遇抢匪 市民联手擒飞贼(图)'},
#  {'text': '北京金隅融资近60亿港元'},
#  {'text': ' 实录：黄奕做客新浪 畅聊《竞雄女侠-秋瑾》'},
#  {'text': '《求生之路》第2部DLC名称与细节公布'},
#  {'text': '新湖中宝参与开发天津文化商贸园'},
#  {'text': '《盗梦空间》拍摄遍及全球 六国实景造奇幻梦境'},
#  {'text': 'NYMEX原油期货11日亚洲电子盘窄幅盘整'},
#  {'text': '选秀后阿联只剩一句台词？ 星爷电影告诉我们指示'},
#  {'text': '打铁10次投篮怒火仍然不熄 圣斗士也没他这么执着'},
#  {'text': '图文-火箭女郎拍摄新年挂历 风不小妆可别花了'},
#  {'text': '长丰汽车：轻型越野车龙头 调整到位'},
#  {'text': '阿尔斯通奔丧不成诈伤下场？老总：有失职业道德'},
#  {'text': '家用超薄卡片相机 索尼W290仅售1780元'},
#  {'text': '10倍光变 富士F75时代数码新年超值卖'},
#  ...]

# %%
results = predict(data_dict_list[:10])
print(results)
# Out:
# 47161,进入了test:
# 47162,进入了test:
# 47163,进入了test:
# 47164,进入了test:
# 47165,进入了test:
# 47166,进入了test:
# 47167,进入了test:
# 47168,进入了test:
# 47169,进入了test:
# 47170,进入了test:
# 47171,进入了test:
# 47172,进入了test:
# 47173,进入了test:
# 47174,进入了test:
# 47175,进入了test:
# 47176,进入了test:
# 47177,进入了test:
# 47178,进入了test:
# 47179,进入了test:
# 47180,进入了test:
# 47181,进入了test:
# 47182,进入了test:
# 47183,进入了test:
# 47184,进入了test:
# 47185,进入了test:
# 47186,进入了test:
# 47187,进入了test:
# 47188,进入了test:
# 47189,进入了test:
# 47190,进入了test:
# 47191,进入了test:
# 47192,进入了test:
# 47193,进入了test:
# 47194,进入了test:
# 47195,进入了test:
# 47196,进入了test:
# 47197,进入了test:
# 47198,进入了test:
# 47199,进入了test:
# 47200,进入了test:
# 47201,进入了test:
# 47202,进入了test:
# 47203,进入了test:
# 47204,进入了test:
# 47205,进入了test:
# 47206,进入了test:
# 47207,进入了test:
# 47208,进入了test:
# 47209,进入了test:
# 47210,进入了test:
# 47211,进入了test:
# 47212,进入了test:
# 47213,进入了test:
# 47214,进入了test:
# 47215,进入了test:
# 47216,进入了test:
# 47217,进入了test:
# 47218,进入了test:
# 47219,进入了test:
# 47220,进入了test:
# 47221,进入了test:
# 47222,进入了test:
# 47223,进入了test:
# 47224,进入了test:
# 47225,进入了test:
# 47226,进入了test:
# 47227,进入了test:
# 47228,进入了test:
# 47229,进入了test:
# 47230,进入了test:
# 47231,进入了test:
# 47232,进入了test:
# 47233,进入了test:
# 47234,进入了test:
# 47235,进入了test:
# 47236,进入了test:
# 47237,进入了test:
# 47238,进入了test:
# 47239,进入了test:
# 47240,进入了test:
# 47241,进入了test:
# 47242,进入了test:
# 47243,进入了test:
# 47244,进入了test:
# 47245,进入了test:
# 47246,进入了test:
# 47247,进入了test:
# 47248,进入了test:
# 47249,进入了test:
# 47250,进入了test:
# 47251,进入了test:
# 47252,进入了test:
# 47253,进入了test:
# 47254,进入了test:
# 47255,进入了test:
# 47256,进入了test:
# 47257,进入了test:
# 47258,进入了test:
# 47259,进入了test:
# 47260,进入了test:
# 47261,进入了test:
# 47262,进入了test:
# 47263,进入了test:
# 47264,进入了test:
# 47265,进入了test:
# 47266,进入了test:
# 47267,进入了test:
# 47268,进入了test:
# 47269,进入了test:
# 47270,进入了test:
# 47271,进入了test:
# 47272,进入了test:
# 47273,进入了test:
# 47274,进入了test:
# 47275,进入了test:
# 47276,进入了test:
# 47277,进入了test:
# 47278,进入了test:
# 47279,进入了test:
# 47280,进入了test:
# 47281,进入了test:
# 47282,进入了test:
# 47283,进入了test:
# 47284,进入了test:
# 47285,进入了test:
# 47286,进入了test:
# 47287,进入了test:
# 47288,进入了test:
# 47289,进入了test:
# 47290,进入了test:
# 47291,进入了test:
# 47292,进入了test:
# 47293,进入了test:
# 47294,进入了test:
# 47295,进入了test:
# 47296,进入了test:
# 47297,进入了test:
# 47298,进入了test:
# 47299,进入了test:
# 47300,进入了test:
# 47301,进入了test:
# 47302,进入了test:
# 47303,进入了test:
# 47304,进入了test:
# 47305,进入了test:
# 47306,进入了test:
# 47307,进入了test:
# 47308,进入了test:
# 47309,进入了test:
# 47310,进入了test:
# 47311,进入了test:
# 47312,进入了test:
# 47313,进入了test:
# 47314,进入了test:
# 47315,进入了test:
# 47316,进入了test:
# 47317,进入了test:
# 47318,进入了test:
# 47319,进入了test:
# 47320,进入了test:
# 47321,进入了test:
# 47322,进入了test:
# 47323,进入了test:
# 47324,进入了test:
# 47325,进入了test:
# 47326,进入了test:
# 47327,进入了test:
# 47328,进入了test:
# 47329,进入了test:
# 47330,进入了test:
# 47331,进入了test:
# 47332,进入了test:
# 47333,进入了test:
# 47334,进入了test:
# 47335,进入了test:
# 47336,进入了test:
# 47337,进入了test:
# 47338,进入了test:
# 47339,进入了test:
# 47340,进入了test:
# 47341,进入了test:
# 47342,进入了test:
# 47343,进入了test:
# 47344,进入了test:
# 47345,进入了test:
# 47346,进入了test:
# 47347,进入了test:
# 47348,进入了test:
# 47349,进入了test:
# 47350,进入了test:
# 47351,进入了test:
# 47352,进入了test:
# 47353,进入了test:
# 47354,进入了test:
# 47355,进入了test:
# 47356,进入了test:
# 47357,进入了test:
# 47358,进入了test:
# 47359,进入了test:
# 47360,进入了test:
# 47361,进入了test:
# 47362,进入了test:
# 47363,进入了test:
# 47364,进入了test:
# 47365,进入了test:
# 47366,进入了test:
# 47367,进入了test:
# 47368,进入了test:
# 47369,进入了test:
# 47370,进入了test:
# 47371,进入了test:
# 47372,进入了test:
# 47373,进入了test:
# 47374,进入了test:
# 47375,进入了test:
# 47376,进入了test:
# 47377,进入了test:
# 47378,进入了test:
# 47379,进入了test:
# 47380,进入了test:
# 47381,进入了test:
# 47382,进入了test:
# 47383,进入了test:
# 47384,进入了test:
# 47385,进入了test:
# 47386,进入了test:
# 47387,进入了test:
# 47388,进入了test:
# 47389,进入了test:
# 47390,进入了test:
# 47391,进入了test:
# 47392,进入了test:
# 47393,进入了test:
# 47394,进入了test:
# 47395,进入了test:
# 47396,进入了test:
# 47397,进入了test:
# 47398,进入了test:
# 47399,进入了test:
# 47400,进入了test:
# 47401,进入了test:
# 47402,进入了test:
# 47403,进入了test:
# 47404,进入了test:
# 47405,进入了test:
# 47406,进入了test:
# 47407,进入了test:
# 47408,进入了test:
# 47409,进入了test:
# 47410,进入了test:
# 47411,进入了test:
# 47412,进入了test:
# 47413,进入了test:
# 47414,进入了test:
# 47415,进入了test:
# 47416,进入了test:
# 47417,进入了test:
# 47418,进入了test:
# 47419,进入了test:
# 47420,进入了test:
# 47421,进入了test:
# 47422,进入了test:
# 47423,进入了test:
# 47424,进入了test:
# 47425,进入了test:
# 47426,进入了test:
# 47427,进入了test:
# 47428,进入了test:
# 47429,进入了test:
# 47430,进入了test:
# 47431,进入了test:
# 47432,进入了test:
# 47433,进入了test:
# 47434,进入了test:
# 47435,进入了test:
# 47436,进入了test:
# 47437,进入了test:
# 47438,进入了test:
# 47439,进入了test:
# 47440,进入了test:
# 47441,进入了test:
# 47442,进入了test:
# 47443,进入了test:
# 47444,进入了test:
# 47445,进入了test:
# 47446,进入了test:
# 47447,进入了test:
# 47448,进入了test:
# 47449,进入了test:
# 47450,进入了test:
# 47451,进入了test:
# 47452,进入了test:
# 47453,进入了test:
# 47454,进入了test:
# 47455,进入了test:
# 47456,进入了test:
# 47457,进入了test:
# 47458,进入了test:
# 47459,进入了test:
# 47460,进入了test:
# 47461,进入了test:
# 47462,进入了test:
# 47463,进入了test:
# 47464,进入了test:
# 47465,进入了test:
# 47466,进入了test:
# 47467,进入了test:
# 47468,进入了test:
# 47469,进入了test:
# 47470,进入了test:
# 47471,进入了test:
# 47472,进入了test:
# 47473,进入了test:
# 47474,进入了test:
# 47475,进入了test:
# 47476,进入了test:
# 47477,进入了test:
# 47478,进入了test:
# 47479,进入了test:
# 47480,进入了test:
# 47481,进入了test:
# 47482,进入了test:
# 47483,进入了test:
# 47484,进入了test:
# 47485,进入了test:
# 47486,进入了test:
# 47487,进入了test:
# 47488,进入了test:
# 47489,进入了test:
# 47490,进入了test:
# 47491,进入了test:
# 47492,进入了test:
# 47493,进入了test:
# 47494,进入了test:
# 47495,进入了test:
# 47496,进入了test:
# 47497,进入了test:
# 47498,进入了test:
# 47499,进入了test:
# 47500,进入了test:
# 47501,进入了test:
# 47502,进入了test:
# 47503,进入了test:
# 47504,进入了test:
# 47505,进入了test:
# 47506,进入了test:
# 47507,进入了test:
# 47508,进入了test:
# 47509,进入了test:
# 47510,进入了test:
# 47511,进入了test:
# 47512,进入了test:
# 47513,进入了test:
# 47514,进入了test:
# 47515,进入了test:
# 47516,进入了test:
# 47517,进入了test:
# 47518,进入了test:
# 47519,进入了test:
# 47520,进入了test:
# 47521,进入了test:
# 47522,进入了test:
# 47523,进入了test:
# 47524,进入了test:
# 47525,进入了test:
# 47526,进入了test:
# 47527,进入了test:
# 47528,进入了test:
# 47529,进入了test:
# 47530,进入了test:
# 47531,进入了test:
# 47532,进入了test:
# 47533,进入了test:
# 47534,进入了test:
# 47535,进入了test:
# 47536,进入了test:
# 47537,进入了test:
# 47538,进入了test:
# 47539,进入了test:
# 47540,进入了test:
# 47541,进入了test:
# 47542,进入了test:
# 47543,进入了test:
# 47544,进入了test:
# 47545,进入了test:
# 47546,进入了test:
# 47547,进入了test:
# 47548,进入了test:
# 47549,进入了test:
# 47550,进入了test:
# 47551,进入了test:
# 47552,进入了test:
# 47553,进入了test:
# 47554,进入了test:
# 47555,进入了test:
# 47556,进入了test:
# 47557,进入了test:
# 47558,进入了test:
# 47559,进入了test:
# 47560,进入了test:
# 47561,进入了test:
# 47562,进入了test:
# 47563,进入了test:
# 47564,进入了test:
# 47565,进入了test:
# 47566,进入了test:
# 47567,进入了test:
# 47568,进入了test:
# 47569,进入了test:
# 47570,进入了test:
# 47571,进入了test:
# 47572,进入了test:
# 47573,进入了test:
# 47574,进入了test:
# 47575,进入了test:
# 47576,进入了test:
# 47577,进入了test:
# 47578,进入了test:
# 47579,进入了test:
# 47580,进入了test:
# 47581,进入了test:
# 47582,进入了test:
# 47583,进入了test:
# 47584,进入了test:
# 47585,进入了test:
# 47586,进入了test:
# 47587,进入了test:
# 47588,进入了test:
# 47589,进入了test:
# 47590,进入了test:
# 47591,进入了test:
# 47592,进入了test:
# 47593,进入了test:
# 47594,进入了test:
# 47595,进入了test:
# 47596,进入了test:
# 47597,进入了test:
# 47598,进入了test:
# 47599,进入了test:
# 47600,进入了test:
# 47601,进入了test:
# 47602,进入了test:
# 47603,进入了test:
# 47604,进入了test:
# 47605,进入了test:
# 47606,进入了test:
# 47607,进入了test:
# 47608,进入了test:
# 47609,进入了test:
# 47610,进入了test:
# 47611,进入了test:
# 47612,进入了test:
# 47613,进入了test:
# 47614,进入了test:
# 47615,进入了test:
# 47616,进入了test:
# 47617,进入了test:
# 47618,进入了test:
# 47619,进入了test:
# 47620,进入了test:
# 47621,进入了test:
# 47622,进入了test:
# 47623,进入了test:
# 47624,进入了test:
# 47625,进入了test:
# 47626,进入了test:
# 47627,进入了test:
# 47628,进入了test:
# 47629,进入了test:
# 47630,进入了test:
# 47631,进入了test:
# 47632,进入了test:
# 47633,进入了test:
# 47634,进入了test:
# 47635,进入了test:
# 47636,进入了test:
# 47637,进入了test:
# 47638,进入了test:
# 47639,进入了test:
# 47640,进入了test:
# 47641,进入了test:
# 47642,进入了test:
# 47643,进入了test:
# 47644,进入了test:
# 47645,进入了test:
# 47646,进入了test:
# 47647,进入了test:
# 47648,进入了test:
# 47649,进入了test:
# 47650,进入了test:
# 47651,进入了test:
# 47652,进入了test:
# 47653,进入了test:
# 47654,进入了test:
# 47655,进入了test:
# 47656,进入了test:
# 47657,进入了test:
# 47658,进入了test:
# 47659,进入了test:
# 47660,进入了test:
# 47661,进入了test:
# 47662,进入了test:
# 47663,进入了test:
# 47664,进入了test:
# 47665,进入了test:
# 47666,进入了test:
# 47667,进入了test:
# 47668,进入了test:
# 47669,进入了test:
# 47670,进入了test:
# 47671,进入了test:
# 47672,进入了test:
# 47673,进入了test:
# 47674,进入了test:
# 47675,进入了test:
# 47676,进入了test:
# 47677,进入了test:
# 47678,进入了test:
# 47679,进入了test:
# 47680,进入了test:
# 47681,进入了test:
# 47682,进入了test:
# 47683,进入了test:
# 47684,进入了test:
# 47685,进入了test:
# 47686,进入了test:
# 47687,进入了test:
# 47688,进入了test:
# 47689,进入了test:
# 47690,进入了test:
# 47691,进入了test:
# 47692,进入了test:
# 47693,进入了test:
# 47694,进入了test:
# 47695,进入了test:
# 47696,进入了test:
# 47697,进入了test:
# 47698,进入了test:
# 47699,进入了test:
# 47700,进入了test:
# 47701,进入了test:
# 47702,进入了test:
# 47703,进入了test:
# 47704,进入了test:
# 47705,进入了test:
# 47706,进入了test:
# 47707,进入了test:
# 47708,进入了test:
# 47709,进入了test:
# 47710,进入了test:
# 47711,进入了test:
# 47712,进入了test:
# 47713,进入了test:
# 47714,进入了test:
# 47715,进入了test:
# 47716,进入了test:
# 47717,进入了test:
# 47718,进入了test:
# 47719,进入了test:
# 47720,进入了test:
# 47721,进入了test:
# 47722,进入了test:
# 47723,进入了test:
# 47724,进入了test:
# 47725,进入了test:
# 47726,进入了test:
# 47727,进入了test:
# 47728,进入了test:
# 47729,进入了test:
# 47730,进入了test:
# 47731,进入了test:
# 47732,进入了test:
# 47733,进入了test:
# 47734,进入了test:
# 47735,进入了test:
# 47736,进入了test:
# 47737,进入了test:
# 47738,进入了test:
# 47739,进入了test:
# 47740,进入了test:
# 47741,进入了test:
# 47742,进入了test:
# 47743,进入了test:
# 47744,进入了test:
# 47745,进入了test:
# 47746,进入了test:
# 47747,进入了test:
# 47748,进入了test:
# 47749,进入了test:
# 47750,进入了test:
# 47751,进入了test:
# 47752,进入了test:
# 47753,进入了test:
# 47754,进入了test:
# 47755,进入了test:
# 47756,进入了test:
# 47757,进入了test:
# 47758,进入了test:
# 47759,进入了test:
# 47760,进入了test:
# 47761,进入了test:
# 47762,进入了test:
# 47763,进入了test:
# 47764,进入了test:
# 47765,进入了test:
# 47766,进入了test:
# 47767,进入了test:
# 47768,进入了test:
# 47769,进入了test:
# 47770,进入了test:
# 47771,进入了test:
# 47772,进入了test:
# 47773,进入了test:
# 47774,进入了test:
# 47775,进入了test:
# 47776,进入了test:
# 47777,进入了test:
# 47778,进入了test:
# 47779,进入了test:
# 47780,进入了test:
# 47781,进入了test:
# 47782,进入了test:
# 47783,进入了test:
# 47784,进入了test:
# 47785,进入了test:
# 47786,进入了test:
# 47787,进入了test:
# 47788,进入了test:
# 47789,进入了test:
# 47790,进入了test:
# 47791,进入了test:
# 47792,进入了test:
# 47793,进入了test:
# 47794,进入了test:
# 47795,进入了test:
# 47796,进入了test:
# 47797,进入了test:
# 47798,进入了test:
# 47799,进入了test:
# 47800,进入了test:
# 47801,进入了test:
# 47802,进入了test:
# 47803,进入了test:
# 47804,进入了test:
# 47805,进入了test:
# 47806,进入了test:
# 47807,进入了test:
# 47808,进入了test:
# 47809,进入了test:
# 47810,进入了test:
# 47811,进入了test:
# 47812,进入了test:
# 47813,进入了test:
# 47814,进入了test:
# 47815,进入了test:
# 47816,进入了test:
# 47817,进入了test:
# 47818,进入了test:
# 47819,进入了test:
# 47820,进入了test:
# 47821,进入了test:
# 47822,进入了test:
# 47823,进入了test:
# 47824,进入了test:
# 47825,进入了test:
# 47826,进入了test:
# 47827,进入了test:
# 47828,进入了test:
# 47829,进入了test:
# 47830,进入了test:
# 47831,进入了test:
# 47832,进入了test:
# 47833,进入了test:
# 47834,进入了test:
# 47835,进入了test:
# 47836,进入了test:
# 47837,进入了test:
# 47838,进入了test:
# 47839,进入了test:
# 47840,进入了test:
# 47841,进入了test:
# 47842,进入了test:
# 47843,进入了test:
# 47844,进入了test:
# 47845,进入了test:
# 47846,进入了test:
# 47847,进入了test:
# 47848,进入了test:
# 47849,进入了test:
# 47850,进入了test:
# 47851,进入了test:
# 47852,进入了test:
# 47853,进入了test:
# 47854,进入了test:
# 47855,进入了test:
# 47856,进入了test:
# 47857,进入了test:
# 47858,进入了test:
# 47859,进入了test:
# 47860,进入了test:
# 47861,进入了test:
# 47862,进入了test:
# 47863,进入了test:
# 47864,进入了test:
# 47865,进入了test:
# 47866,进入了test:
# 47867,进入了test:
# 47868,进入了test:
# 47869,进入了test:
# 47870,进入了test:
# 47871,进入了test:
# 47872,进入了test:
# 47873,进入了test:
# 47874,进入了test:
# 47875,进入了test:
# 47876,进入了test:
# 47877,进入了test:
# 47878,进入了test:
# 47879,进入了test:
# 47880,进入了test:
# 47881,进入了test:
# 47882,进入了test:
# 47883,进入了test:
# 47884,进入了test:
# 47885,进入了test:
# 47886,进入了test:
# 47887,进入了test:
# 47888,进入了test:
# 47889,进入了test:
# 47890,进入了test:
# 47891,进入了test:
# 47892,进入了test:
# 47893,进入了test:
# 47894,进入了test:
# 47895,进入了test:
# 47896,进入了test:
# 47897,进入了test:
# 47898,进入了test:
# 47899,进入了test:
# 47900,进入了test:
# 47901,进入了test:
# 47902,进入了test:
# 47903,进入了test:
# 47904,进入了test:
# 47905,进入了test:
# 47906,进入了test:
# 47907,进入了test:
# 47908,进入了test:
# 47909,进入了test:
# 47910,进入了test:
# 47911,进入了test:
# 47912,进入了test:
# 47913,进入了test:
# 47914,进入了test:
# 47915,进入了test:
# 47916,进入了test:
# 47917,进入了test:
# 47918,进入了test:
# 47919,进入了test:
# 47920,进入了test:
# 47921,进入了test:
# 47922,进入了test:
# 47923,进入了test:
# 47924,进入了test:
# 47925,进入了test:
# 47926,进入了test:
# 47927,进入了test:
# 47928,进入了test:
# 47929,进入了test:
# 47930,进入了test:
# 47931,进入了test:
# 47932,进入了test:
# 47933,进入了test:
# 47934,进入了test:
# 47935,进入了test:
# 47936,进入了test:
# 47937,进入了test:
# 47938,进入了test:
# 47939,进入了test:
# 47940,进入了test:
# 47941,进入了test:
# 47942,进入了test:
# 47943,进入了test:
# 47944,进入了test:
# 47945,进入了test:
# 47946,进入了test:
# 47947,进入了test:
# 49971,进入了test:
# 49972,进入了test:
# 49973,进入了test:
# 49974,进入了test:
# 49975,进入了test:
# 49976,进入了test:
# 49977,进入了test:
# 49978,进入了test:
# 49979,进入了test:
# 49980,进入了test:
# 49981,进入了test:
# 49982,进入了test:
# 49983,进入了test:
# 49984,进入了test:
# 49985,进入了test:
# 49986,进入了test:
# 49987,进入了test:
# 49988,进入了test:
# 49989,进入了test:
# 49990,进入了test:
# 49991,进入了test:
# 49992,进入了test:
# 49993,进入了test:
# 49994,进入了test:
# 49995,进入了test:
# 49996,进入了test:
# 49997,进入了test:
# 49998,进入了test:
# 49999,进入了test:
# 50000,进入了test:
# 50001,进入了test:
# 50002,进入了test:
# 50003,进入了test:
# 50004,进入了test:
# 50005,进入了test:
# 50006,进入了test:
# 50007,进入了test:
# 50008,进入了test:
# 50009,进入了test:
# 50010,进入了test:
# 50011,进入了test:
# 50012,进入了test:
# 50013,进入了test:
# 50014,进入了test:
# 50015,进入了test:
# 50016,进入了test:
# 50017,进入了test:
# 50018,进入了test:
# 50019,进入了test:
# 50020,进入了test:
# 50021,进入了test:
# 50022,进入了test:
# 50023,进入了test:
# 50024,进入了test:
# 50025,进入了test:
# 50026,进入了test:
# 50027,进入了test:
# 50028,进入了test:
# 50029,进入了test:
# 50030,进入了test:
# 50031,进入了test:
# 50032,进入了test:
# 50033,进入了test:
# 50034,进入了test:
# 50035,进入了test:
# 50036,进入了test:
# 50037,进入了test:
# 50038,进入了test:
# 50039,进入了test:
# 50040,进入了test:
# 50041,进入了test:
# 50042,进入了test:
# 50043,进入了test:
# 50044,进入了test:
# 50045,进入了test:
# 50046,进入了test:
# 50047,进入了test:
# 50048,进入了test:
# 50049,进入了test:
# 50050,进入了test:
# 50051,进入了test:
# 50052,进入了test:
# 50053,进入了test:
# 50054,进入了test:
# 50055,进入了test:
# 50056,进入了test:
# 50057,进入了test:
# 50058,进入了test:
# 50059,进入了test:
# 50060,进入了test:
# 50061,进入了test:
# 50062,进入了test:
# 50063,进入了test:
# 50064,进入了test:
# 50065,进入了test:
# 50066,进入了test:
# 50067,进入了test:
# 50068,进入了test:
# 50069,进入了test:
# 50070,进入了test:
# 50071,进入了test:
# 50072,进入了test:
# 50073,进入了test:
# 50074,进入了test:
# 50075,进入了test:
# 50076,进入了test:
# 50077,进入了test:
# 50078,进入了test:
# 50079,进入了test:
# 50080,进入了test:
# 50081,进入了test:
# 50082,进入了test:
# 50083,进入了test:
# 50084,进入了test:
# 50085,进入了test:
# 50086,进入了test:
# 50087,进入了test:
# 50088,进入了test:
# 50089,进入了test:
# 50090,进入了test:
# 50091,进入了test:
# 50092,进入了test:
# 50093,进入了test:
# 50094,进入了test:
# 50095,进入了test:
# 50096,进入了test:
# 50097,进入了test:
# 50098,进入了test:
# 50099,进入了test:
# 50100,进入了test:
# 50101,进入了test:
# 50102,进入了test:
# 50103,进入了test:
# 50104,进入了test:
# 50105,进入了test:
# 50106,进入了test:
# 50107,进入了test:
# 50108,进入了test:
# 50109,进入了test:
# 50110,进入了test:
# 50111,进入了test:
# 50112,进入了test:
# 50113,进入了test:
# 50114,进入了test:
# 50115,进入了test:
# 50116,进入了test:
# 50117,进入了test:
# 50118,进入了test:
# 50119,进入了test:
# 50120,进入了test:
# 50121,进入了test:
# 50122,进入了test:
# 50123,进入了test:
# 50124,进入了test:
# 50125,进入了test:
# 50126,进入了test:
# 50127,进入了test:
# 50128,进入了test:
# 50129,进入了test:
# 50130,进入了test:
# 50131,进入了test:
# 50132,进入了test:
# 50133,进入了test:
# 50134,进入了test:
# 50135,进入了test:
# 50136,进入了test:
# 50137,进入了test:
# 50138,进入了test:
# 50139,进入了test:
# 50140,进入了test:
# 50141,进入了test:
# 50142,进入了test:
# 50143,进入了test:
# 50144,进入了test:
# 50145,进入了test:
# 50146,进入了test:
# 50147,进入了test:
# 50148,进入了test:
# 50149,进入了test:
# 50150,进入了test:
# 50151,进入了test:
# 50152,进入了test:
# 50153,进入了test:
# 50154,进入了test:
# 50155,进入了test:
# 50156,进入了test:
# 50157,进入了test:
# 50158,进入了test:
# 50159,进入了test:
# 50160,进入了test:
# 50161,进入了test:
# 50162,进入了test:
# 50163,进入了test:
# 50164,进入了test:
# 50165,进入了test:
# 50166,进入了test:
# 50167,进入了test:
# 50168,进入了test:
# 50169,进入了test:
# 50170,进入了test:
# 50171,进入了test:
# 50172,进入了test:
# 50173,进入了test:
# 50174,进入了test:
# 50175,进入了test:
# 50176,进入了test:
# 50177,进入了test:
# 50178,进入了test:
# 50179,进入了test:
# 50180,进入了test:
# 50181,进入了test:
# 50182,进入了test:

# %%
print('hello,world')
# Out:
# hello,world

# %%
results = predict(data_dict_list[:10])
print(results)
# Out:
# 83605,进入了test:
# 83606,进入了test:
# 83607,进入了test:
# 83608,进入了test:
# 83609,进入了test:
# 83610,进入了test:
# 83611,进入了test:
# 83612,进入了test:
# 83613,进入了test:
# 83614,进入了test:
# [10, 9, 10, 8, 8, 3, 9, 5, 10, 3]
